# %% [markdown]
# # Install packages

# %%
# %pip install mujoco
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /opt/homebrew/lib/python3.11/site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import packages

# %%
# Core imports
from typing import Callable, Optional, Union, List
import math
import time
import copy

# MuJoCo env packages
import os
import subprocess
import sys

from IPython.display import clear_output
import mediapy as media
import mujoco

# solver, plot packages
import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
import numpy.typing as npt

# %% [markdown]
# # MacOS setting for hardware acceleration

# %%
def setup_macos_environment() -> None:
    # Set environment variable to use software rendering with MuJoCo
    print(">> Setting environment variable to use OpenGL rendering:")
    os.environ["MUJOCO_GL"] = "glfw"

    try:
        print("Checking that the installation succeeded:")
        mujoco.MjModel.from_xml_string("<mujoco/>")
    except Exception as e:
        raise RuntimeError(
            "Something went wrong during installation. Check the error message below for more information."
        ) from e

    print(">> Installation successful.")

    def install_ffmpeg_and_mediapy():
        try:
            subprocess.run(["ffmpeg", "-version"], check=True)
        except (subprocess.CalledProcessError, FileNotFoundError):
            print(">> Installing ffmpeg:")
            subprocess.run(["brew", "install", "ffmpeg"], check=True)

        print(">> Installing mediapy:")
        subprocess.run([sys.executable, "-m", "pip", "install", "mediapy"], check=True)

    install_ffmpeg_and_mediapy()

    # More legible printing from numpy
    np.set_printoptions(precision=3, suppress=True, linewidth=100)
    clear_output()
    print(">> Setup complete.")


def setup_colab_environment() -> None:
    if subprocess.run("nvidia-smi").returncode:
        raise RuntimeError(
            "Cannot communicate with GPU. "
            "Make sure you are using a GPU Colab runtime. "
            "Go to the Runtime menu and select Choose runtime type."
        )

    # Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
    # This is usually installed as part of an Nvidia driver package, but the Colab
    # kernel doesn't install its driver via APT, and as a result the ICD is missing.
    # (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
    NVIDIA_ICD_CONFIG_PATH = "/usr/share/glvnd/egl_vendor.d/10_nvidia.json"
    if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
        with open(NVIDIA_ICD_CONFIG_PATH, "w") as f:
            f.write("""{
        "file_format_version" : "1.0.0",
        "ICD" : {
            "library_path" : "libEGL_nvidia.so.0"
        }
    }
    """)

    # Configure MuJoCo to use the EGL rendering backend (requires GPU)
    print("Setting environment variable to use GPU rendering:")
    # %env MUJOCO_GL=egl

    # Check if installation was successful.
    try:
        print("Checking that the installation succeeded:")
        mujoco.MjModel.from_xml_string("<mujoco/>")
    except Exception as e:
        raise e from RuntimeError(
            "Something went wrong during installation. Check the shell output above "
            "for more information.\n"
            "If using a hosted Colab runtime, make sure you enable GPU acceleration "
            'by going to the Runtime menu and selecting "Choose runtime type".'
        )

    print("Installation successful.")

    # Graphics and plotting.
    print("Installing mediapy:")
    # !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
    # !pip install -q mediapy

    # More legible printing from numpy.
    np.set_printoptions(precision=3, suppress=True, linewidth=100)

    clear_output()

############### Main setup function ###############

if sys.platform == "darwin":
    setup_macos_environment()
else:
    setup_colab_environment()
# Out:
# >> Setup complete.

# %% [markdown]
# # `MuJoCo`: An Advanced Physics Engine
#
# - `MuJoCo`, which stands for Multi-Joint dynamics with Contact, is a cutting-edge physics engine designed to aid in research and development in various fields, including robotics, biomechanics, graphics, and animation.
#
# - It is renowned for its speed, accuracy, and powerful modeling capabilities, making it a valuable tool for both academic and practical applications.

# %% [markdown]
# ## Setup the `MuJoCo` environment for simulating and visualizing a Panda robot model.
#
# ### `XML`
# - `model` => Used to instantiate an `MjModel`.
# - Create an `MjData` which holds the simulation state, and an instance of the `Renderer` class defined above.
#
# ### `model` = `mujoco.MjModel`.`from_xml_string(xml)`
# - XML로부터 mujoco model을 생성함.
# -  **physical properties** -> `kinematics`, and `dynamics`, `Inertia`, `stiffness`, ... of the Panda robot
#
# ### `mujoco.MjData(model)`
# - Initializes `MuJoCo data object` associated with the model.
# - Contains `simulation state`, including `positions`, `velocities`, `forces`, and other dynamic properties.
#
# ### `mujoco.Renderer(model)`:
# - Initializes the renderer object for visualizing the MuJoCo model.
# - Handle the rendering of the model's simulation in a 3D graphical window.

# %% [markdown]
# # Load and Render the Franka Emika Panda

# %%
# Clone the repository containing the Panda robot model and related assets
# !git clone https://github.com/SouthColumn76/panda_mjcf

# Copy the assets directory from the cloned repository to the current working directory
# !cp -r panda_mjcf/assets ./assets

# Open and read the XML file defining the Panda robot model
MODEL_FILE = "panda_mjcf/panda.xml"
FINAL_MODEL_FILE = "panda_mjcf/panda_4cube.xml"

with open(FINAL_MODEL_FILE, "r") as fp:
    model_xml = fp.read()
# Out:
# fatal: destination path 'panda_mjcf' already exists and is not an empty directory.

# %% [markdown]
# # 1. Initialize `Mujoco` Model

# %%
# 1. Model은 Mujoco의 물리 객체 모델
MODEL = mujoco.MjModel.from_xml_string(model_xml)

# 2. Data는 Model의 physical state를 나타내는 객체
MODEL_DATA = mujoco.MjData(MODEL)

# 3. Renderer는 Model을 3D 렌더링하는 객체
renderer = mujoco.Renderer(MODEL)

# %% [markdown]
# The state in the `data` object is in the default configuration. Let's invoke the forward dynamics to populate all the derived quantities (like the positions of geoms in the world), update the scene and render it:
#
# ### `mujoco`.`mj_forward(model, data)` `-> None`
# - computes the **forward dynamics** of the model.
# - **updates the state** of the simulation based on the current `positions`, `velocities`, and `forces` acting on the model.
# - Advances the simulation **by one time step**, considering the physics and constraints defined in the model.
# - Call by reference를 사용함, model, data를 직접 수정함.
#
# > `mj_forward`를 호출하면 다음 `time_step`에서의 모델 forward kinematics를 계산함
#
# ### `renderer`.`update_scene(data)`
# - Updates the renderer with the latest simulation data.
# - Prepares the scene for rendering by incorporating the current state of the simulation (positions, orientations, etc.) into the graphical representation.
#
# ### `renderer`.`render()`:
# - Renders the current scene, generating an `image` based on the updated simulation data.
# - Produces a visual representation of the model and its environment as defined by the current state.
# > 현재 model의 상태 `Image`를 return함
#
# ### `media`.`show_image(renderer.render() = Image)`:
# - Displays the rendered image using a media display tool.
# - Takes the image produced by `renderer.render()`
# - Shows it in an appropriate viewer, **making the simulation's visual output accessible to the user.**

# %%
def test_environment_configuration():
    # Perform a forward dynamics computation to update the simulation state
    mujoco.mj_forward(MODEL, MODEL_DATA)

    # Update the renderer with the current simulation data
    renderer.update_scene(MODEL_DATA)

    # Render the current scene and display the resulting image
    media.show_image(renderer.render())


test_environment_configuration()
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# # 2. Camera of `XML` model
#
# Because it is far away, the robot cannot be seen in detail.
#
# `Mujoco` **can use multiple cameras**.
#
# Check the cameras currently in this XML and render using each one.

# %%
for i in range(MODEL.ncam):
    print(MODEL.camera(i).name)
    renderer.update_scene(MODEL_DATA, camera=i)
    media.show_image(renderer.render())
# Out:
# frontview
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# birdview
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# agentview
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# sideview
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# targetview
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# When specifying a camera, we can use not only the number but also the name.

# %%
renderer.update_scene(MODEL_DATA, camera="sideview")
media.show_image(renderer.render())
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# # 3. Actuator Control

# %% [markdown]
# ### `mj_resetDataKeyframe` can be used to load them. Let's see what they look like:
#
# 1. `Keyframes`: **predefined states of the model**
# 2. `Model`: comes with some built-in `Keyframes` which are saved simulation states.
#
# ### `mujoco`.`mj_resetDataKeyframe(model, data, key)`
# - Resets simulation data: **to match the state defined by the specified `Keyframe`**.
# - Sets the simulation to these states: one by one, as the loop iterates.

# %%
def test_view():
    for key in range(MODEL.nkey):
        mujoco.mj_resetDataKeyframe(MODEL, MODEL_DATA, key)
        mujoco.mj_forward(MODEL, MODEL_DATA)
        renderer.update_scene(MODEL_DATA, camera="sideview")
        media.show_image(renderer.render())


test_view()
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# Now let's simulate the physics and render to make a video.

# %%
def test_video():
    DURATION = 3  # seconds
    FRAMERATE = 60  # Hz

    # Initialize pose.
    mujoco.mj_resetDataKeyframe(MODEL, MODEL_DATA, 0)

    frames = []
    while MODEL_DATA.time < DURATION:
        # Step the simulation.
        mujoco.mj_step(MODEL, MODEL_DATA)

        # Render and save frames.
        if len(frames) < MODEL_DATA.time * FRAMERATE:
            renderer.update_scene(MODEL_DATA, camera="sideview")
            pixels = renderer.render()
            frames.append(pixels)

    # Display video.
    media.show_video(frames, fps=FRAMERATE)


test_video()
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# Since the model is defined as built-in torque actuators, without control, the posture cannot be maintained due to gravity.
#
# we can use to drive the robot's joints by setting the `data.ctrl` vector.

# %% [markdown]
# # 4. `joint` and `actuator`
#
# ## Find the relationship between joint, actuator

# %% [markdown]
# In `XML`, not only robots but all movable objects have joints.
#
# Among them, the only `joints` that **can be controlled are those connected to the `actuator`**.
#
# To find out which joints an actuator can control, **check the actuator's `transmission type` and `ID`**.

# %%
def test_actuator():
    # actuator에 대한 정보를 담고 있음
    first_actuator = MODEL.actuator(0)
    print(first_actuator.name, first_actuator.trntype, first_actuator.trnid)
    MODEL.actuator(0).trntype, MODEL.actuator(0).trnid


test_actuator()
# Out:
# actuator1 [0] [ 4 -1]

# %% [markdown]
# ## Helper function

# %%
def test_id():
    body_id = MODEL.body("link1").id
    joint_id = MODEL.body_jntadr[body_id]
    print(body_id, joint_id)

    for body_id in range(MODEL.nbody):
        print(MODEL.body(body_id).name)


test_id()


def get_body_ids(model: mujoco.MjModel, eef: str | int) -> list[int]:
    """
    Get the body ids of the kinematics chain

    Args:
        model (mujoco.MjModel): mujoco model
        eef (str | int): end effector name or id
    """
    eef_id = model.body(eef).id
    body_ids = [eef_id]
    body_id = eef_id
    tree_id = model.body_treeid[eef_id]
    for _ in range(model.nbody):
        parent_id = model.body(body_id).parentid[0]
        if model.body_treeid[parent_id] == tree_id:
            body_ids.append(parent_id)
            body_id = body_ids[-1]
        else:
            break
    else:
        raise ValueError(f"body {eef_id} not in tree of kinematics chain.")
    body_ids.reverse()
    return body_ids


def get_qpos_adrs(model: mujoco.MjModel, body_ids: list[int]) -> list[int]:
    """
    Get the qpos addresses of the kinematics chain

    Qpos = position of the joint
    ```python
    qpos_adrs = model.jnt_qposadr[jnt_ids]
    ```
    """
    jnt_ids = model.body_jntadr[body_ids]
    jnt_ids = [id for id in jnt_ids if id != -1]
    qpos_adrs = model.jnt_qposadr[jnt_ids]
    return qpos_adrs


def get_qvel_adrs(model: mujoco.MjModel, body_ids: list[int]) -> list[int]:
    """
    Get the qvel addresses of the kinematics chain

    Qvel = velocity of the joint

    ```python
    qvel_adrs = model.jnt_dofadr[jnt_ids]
    ```
    """
    jnt_ids = model.body_jntadr[body_ids]
    jnt_ids = [id for id in jnt_ids if id != -1]
    dof_adrs = model.jnt_dofadr[jnt_ids]
    return dof_adrs


def test_helper() -> None:
    body_ids = get_body_ids(MODEL, eef="hand")
    qpos_adrs = get_qpos_adrs(MODEL, body_ids)
    qvel_adrs = get_qvel_adrs(MODEL, body_ids)
    print(f"\nEnd-effector hand -> qposes: {qpos_adrs}, qvels: {qvel_adrs}\n")
    print(
        "\n".join(
            [
                f"body name: {MODEL.body(body_id).name}, bodt id: {body_id} , qpos adress: {qpos_adrr}, qvel adress: {qvel_adrr}"
                for body_id, qpos_adrr, qvel_adrr in zip(body_ids, qpos_adrs, qvel_adrs)
            ]
        )
    )


test_helper()
# Out:
# 13 4
# world
# table
# red_cube
# blue_cube
# green_cube
# yellow_cube
# robot_fixed
# mount_base
# mount0_controller_box
# mount_pedestal_feet
# mount_torso
# mount_pedestal
# link0
# link1
# link2
# link3
# link4
# link5
# link6
# link7
# hand
# grasp_site
# left_finger
# right_finger
#
# End-effector hand -> qposes: [28 29 30 31 32 33 34], qvels: [24 25 26 27 28 29 30]
#
# body name: link1, bodt id: 13 , qpos adress: 28, qvel adress: 24
# body name: link2, bodt id: 14 , qpos adress: 29, qvel adress: 25
# body name: link3, bodt id: 15 , qpos adress: 30, qvel adress: 26
# body name: link4, bodt id: 16 , qpos adress: 31, qvel adress: 27
# body name: link5, bodt id: 17 , qpos adress: 32, qvel adress: 28
# body name: link6, bodt id: 18 , qpos adress: 33, qvel adress: 29
# body name: link7, bodt id: 19 , qpos adress: 34, qvel adress: 30

# %%
def test_configuration():
    MODEL.nu  # number of actuators/controls = dim(ctrl)

    joint_ids = []
    ctrl_adrs = []

    for actuator_id in range(MODEL.nu):
        transmission_type = MODEL.actuator(actuator_id).trntype[0]
        is_joint = transmission_type == mujoco.mjtTrn.mjTRN_JOINT

        if is_joint:
            model_joint = MODEL.actuator(actuator_id)
            model_joint_id = model_joint.trnid[0]

            joint_ids.append(model_joint_id)
            ctrl_adrs.append(actuator_id)

    qpos_adrs = MODEL.jnt_qposadr[joint_ids]
    print("Joint IDs:", joint_ids)
    print("Control IDs:", ctrl_adrs)
    print("QPOS(=Joint id) addresses:", qpos_adrs)


test_configuration()


def get_joint_actuator_ids_adress(model: mujoco.MjModel) -> tuple[list[int], list[int]]:
    """
    Get the `joint` IDs & `actuator` Address for the robot model
    """
    joint_ids: list[int] = []
    actuator_addresses: list[int] = []

    for actuator_id in range(model.nu):
        transmission_type = model.actuator(actuator_id).trntype[0]
        is_joint = transmission_type == mujoco.mjtTrn.mjTRN_JOINT

        if is_joint:
            model_joint = model.actuator(actuator_id)
            model_joint_id = model_joint.trnid[0]

            joint_ids.append(model_joint_id)
            actuator_addresses.append(actuator_id)

    return joint_ids, actuator_addresses


def get_joint_qpos_addresses(model: mujoco.MjModel, joint_ids: list[int]) -> list[int]:
    """
    Get the `qpos` = joint_pose addresses for the robot model

    Args:
        joint_ids: List of joint IDs

    Example:
    ```python
    # First, get the joint and actuator IDs
    joint_ids, actuator_ids = get_joint_actuator_ids()

    # Next, get the qpos addresses for the joint IDs
    qpos_adrs = get_joint_qpos_addresses(joint_ids)
    ```
    """
    qpos_adrs = model.jnt_qposadr[joint_ids]
    return qpos_adrs
# Out:
# Joint IDs: [4, 5, 6, 7, 8, 9, 10]
# Control IDs: [0, 1, 2, 3, 4, 5, 6]
# QPOS(=Joint id) addresses: [28 29 30 31 32 33 34]

# %% [markdown]
# ## In this `XML`
#
# 1. `mjTRN_JOINT`: transmission type of each joint of the robot
# 2. `mjTRN_TENDON`: the finger of the end-effector

# %%
# Joint의 종류
# 1. Revolute joint
# 2. Tendon joint
# 2가지는 gripper에 대한 디자인

mujoco.mjtTrn.mjTRN_JOINT, mujoco.mjtTrn.mjTRN_TENDON
# Out:
# (<mjtTrn.mjTRN_JOINT: 0>, <mjtTrn.mjTRN_TENDON: 3>)

# %% [markdown]
# # 5. `PID` Controller Class

# %% [markdown]
# Implement a PID (Proportional-Integral-Derivative) Controller class in Python to control a system. The PID controller should be capable of updating its control output based on the current state of the system, the target state, and the elapsed time. The controller should include features like anti-windup and output smoothing using Exponential Moving Average (EMA).
#
# **Specifications**:
#
# 1. Class Definition:
#   - Class Name: `PIDController`
# 2. Constructor Parameters:
#   - `k_p`: Proportional gain (default: 0.01)
#   - `k_i`: Integral gain (default: 0.0)
#   - `k_d`: Derivative gain (default: 0.001)
#   - `dt`: Time step (default: 0.01)
#   - `dim`: Dimensionality of the controller (default: 1)
#   - `dt_min`: Minimum time step to avoid division by zero (default: 1e-6)
#   - `out_min`: Minimum output value (default: -infinity)
#   - `out_max`: Maximum output value (default: infinity)
#   - `ANTIWU`: Boolean to enable or disable anti-windup (default: True)
#   - `out_alpha`: Smoothing factor for output EMA (default: 0.0)
# 3. Methods:
#   - `reset(self, t_curr=0.0)`: Resets the internal state of the controller.
#   - `update(self, x_curr, t_curr, x_trgt=None)`: Updates the controller state and computes the control output based on the current and target states and the current time.
#   - `out(self)`: Returns the current control output value.
# 4. Functional Requirements:
#
#   - The controller should compute the control output using the PID formula:
#
# ### $$u(t)=K_{p}e(t)+K_{i}\int e(t)dt+K_{d} \frac{de(t)}{dt}$$
#
#   - Implement anti-windup to prevent the integral term from accumulating excessively.
#   - Smooth the control output using an Exponential Moving Average (EMA) if out_alpha is greater than 0.
#   - Ensure the output value is clipped within the specified out_min and out_max range.

# %%
class PIDController:
    def __init__(
        self,
        k_p=0.01,
        k_i=0.0,
        k_d=0.001,
        dt=0.01,
        dim=1,
        dt_min=1e-6,
        out_min=-np.inf,
        out_max=np.inf,
        ANTIWU=True,  # anti-windup
        out_alpha=0.0,  # output EMA (0: no EMA)
    ) -> None:
        self.k_p = np.ones(shape=dim) * k_p
        self.k_i = np.ones(shape=dim) * k_i
        self.k_d = np.ones(shape=dim) * k_d
        self.dt = dt
        self.dim = dim
        self.dt_min = dt_min
        self.out_min = out_min
        self.out_max = out_max
        self.ANTIWU = ANTIWU
        self.out_alpha = out_alpha

        # Buffers
        self.reset()

    def reset(self, t_curr=0.0) -> None:
        self.cnt = 0
        self.x_trgt = np.zeros(shape=self.dim)
        self.x_curr = np.zeros(shape=self.dim)
        self.out_val = np.zeros(shape=self.dim)
        self.out_val_prev = np.zeros(shape=self.dim)
        self.t_curr = t_curr
        self.t_prev = t_curr
        self.err_curr = np.zeros(shape=self.dim)
        self.err_intg = np.zeros(shape=self.dim)
        self.err_prev = np.zeros(shape=self.dim)
        self.p_term = np.zeros(shape=self.dim)
        self.d_term = np.zeros(shape=self.dim)
        self.err_out = np.zeros(shape=self.dim)

    def update(self, x_curr, t_curr, x_trgt=None) -> None:
        """
        Update PID controller
        u(t) = K_p e(t) + K_i int e(t) {dt} + K_d {de}/{dt}
        """
        if x_trgt is not None:
            self.x_trgt = x_trgt
        if t_curr is not None:
            self.t_curr = t_curr
        if x_curr is not None:
            self.x_curr = x_curr
            # PID controller updates here
            self.dt = max(self.t_curr - self.t_prev, self.dt_min)
            self.err_curr = self.x_trgt - self.x_curr
            self.err_intg = self.err_intg + (self.err_curr * self.dt)
            self.err_diff = self.err_curr - self.err_prev

            if self.ANTIWU:  # anti-windup
                self.err_out = self.err_curr * self.out_val
                self.err_intg[self.err_out < 0.0] = 0.0

            if self.dt > self.dt_min:
                self.p_term = self.k_p * self.err_curr
                self.i_term = self.k_i * self.err_intg
                self.d_term = self.k_d * self.err_diff / self.dt
                self.out_val = np.clip(
                    a=self.p_term + self.i_term + self.d_term,
                    a_min=self.out_min,
                    a_max=self.out_max,
                )
                # Smooth the output control value using EMA
                self.out_val = (
                    self.out_alpha * self.out_val_prev
                    + (1.0 - self.out_alpha) * self.out_val
                )
                self.out_val_prev = self.out_val

            # Backup
            self.t_prev = self.t_curr
            self.err_prev = self.err_curr
        # Counter
        if (t_curr is not None) and (x_curr is not None):
            self.cnt = self.cnt + 1

    def out(self) -> npt.NDArray:
        return self.out_val

# %% [markdown]
# ### Current status of robot `joints` required to use the `PID controller` can be known through `data.qpos`.
#
# ### `data.qpos`: **state vector** of all joints in `XML`
#
# > need to find the `qpos` of the joints connected to the actuator.

# %%
def test_pid():
    DURATION = 2  # seconds
    FRAMERATE = 60  # Hz

    # !TODO: 완전히 초기화된 상태
    # Initialize pose.
    mujoco.mj_resetDataKeyframe(MODEL, MODEL_DATA, 0)

    joint_ids, actuator_addresses = get_joint_actuator_ids_adress(MODEL)
    qpos_adrs = get_joint_qpos_addresses(MODEL, joint_ids)

    # Initialize PID Controller
    PID = PIDController(
        k_p=1000,
        k_i=0.1,
        k_d=50,
        dim=7,
        out_min=MODEL.actuator_ctrlrange[actuator_addresses, 0],
        out_max=MODEL.actuator_ctrlrange[actuator_addresses, 1],
    )
    PID.x_trgt = MODEL_DATA.qpos[qpos_adrs].copy()
    PID.x_trgt = np.array([0, 0, 0, -1.571, 0, 4.71, -0.785])

    frames = []

    while MODEL_DATA.time < DURATION:
        # Step the simulation.
        x_curr = MODEL_DATA.qpos[qpos_adrs].copy()

        # Calculate the control
        PID.update(x_curr, MODEL_DATA.time)

        # Control the robot
        # !TODO: ctrl를 통해서 actuator를 제어한다.
        MODEL_DATA.ctrl[actuator_addresses] = PID.out()

        # Update robot state and simulate
        # !TODO: mj_step은 call-by-reference로 data를 다음 상태로 시뮬레이션 한다.
        mujoco.mj_step(MODEL, MODEL_DATA)

        # Render and save frames for video
        if len(frames) < MODEL_DATA.time * FRAMERATE:
            renderer.update_scene(MODEL_DATA, camera="sideview")
            pixels = renderer.render()
            frames.append(pixels)

    # Display video.
    media.show_video(frames, fps=FRAMERATE)


test_pid()
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# # 7. Path Planning
# # 7. Kinematics in `Mujoco`,
#
# Generate trajectory (`S` - `[0,1]`)

# %% [markdown]
# #### Robot `body` & `joint` are important in kinematics.
# #### Like actuators, `bodies` also **have a relationship with `joints`**.

# %% [markdown]
# Since `mujoco` **represent the relationship** between each `body` as a `kinematic tree`
#
# we can easily find the entire `body` and `joint` using the `body id` or `name` of the end-effector.

# %% [markdown]
# Three components are required to create an RRT* planner and a Cartesian planner.
#
# ### * `Sampler`:
#   #### `RRT*` is a sampling-based planner, so it requires the ability to generate random samples. Additionally, it serves to check whether the given state is valid.
# ### * `Collision Checker`:
#   #### It is necessary to check whether a conflict occurs in a given state.
# ### * `Kinematics`:
#   #### It is responsible for calculating forward and inverse kinematics.

# %% [markdown]
# # 7.1 `Sampler`
#
# #### Uniformly parsing `joint` configuration

# %%
class Sampler:
    """
    Sampling random configuration for mujoco model
    """

    def __init__(self, model: mujoco.MjModel, body_ids: list[int]) -> None:
        """
        Sampling configuration for mujoco model

        Args:
            model(`mujoco.MjModel`): mujoco model
            body_ids(`list[int]`): list of body ids
        """
        joint_mins = []
        joint_maxs = []
        for id in body_ids:
            joint_id = model.body(id).jntadr[0]
            if joint_id == -1:
                continue
            joint_range = model.joint(joint_id).range
            joint_mins.append(joint_range[0])
            joint_maxs.append(joint_range[1])

        self.joint_mins = np.array(joint_mins)
        self.joint_maxs = np.array(joint_maxs)

    def __call__(self) -> npt.NDArray:
        """
        Uniformly sample a random configuration
        RRT에서 사용할 random configuration을 샘플링한다.
        """
        return np.random.uniform(low=self.joint_mins, high=self.joint_maxs)

    def __contains__(self, item: npt.NDArray) -> bool:
        return np.all((item >= self.joint_mins) & (item <= self.joint_maxs))

# %%
def test_sampler() -> Sampler:
    body_ids = get_body_ids(MODEL, eef="hand")
    sampler = Sampler(MODEL, body_ids)

    # Call samples
    sample = sampler()
    print(sample)

    # Pick a random sample
    sample += np.random.normal(0, 1, sample.shape)
    print(sample in sampler)

    return sampler


test_sampler()
# Out:
# [ 1.943 -0.602 -2.127 -2.615 -2.891  1.155  0.876]
# False

# %% [markdown]
# ## Get image of position

# %%
def get_image_of_pos(qpos, camera: str | int = "frontview"):
    qpos_adrs = get_qpos_adrs(
        model=MODEL,
        body_ids=get_body_ids(MODEL, eef="hand"),
    )
    MODEL_DATA.qpos[qpos_adrs] = qpos
    mujoco.mj_kinematics(MODEL, MODEL_DATA)
    renderer.update_scene(MODEL_DATA, camera=camera)
    return renderer.render()


def test_image_of_pos():
    body_ids = get_body_ids(MODEL, eef="hand")
    sampler = Sampler(MODEL, body_ids)

    sample = sampler()
    sample += np.random.normal(0, 1, sample.shape)

    media.show_image(get_image_of_pos(sample))


test_image_of_pos()
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# # 7.2 `Collision Checker`

# %% [markdown]
# ### **Specifications**:
# #### 1. Class Definition:
# - Class Name: `CollisionChecker`
#
# #### 2. Constructor Parameters:
# - `model`: An instance of `mujoco`.`MjModel` representing the `MuJoCo` model.
# - `body_ids`: A list of `body IDs` to consider for collision checking.
# - `ignore_pairs`: An optional list of tuples, each containing `two geometry names` to **ignore during collision detection.**
#
# #### 3. Methods:
# - `__init__(self, model: mujoco.MjModel, body_ids: list[int], ignore_pairs: list[tuple] = None)`: Initializes the collision checker with the given model, body IDs, and ignore pairs.
# - `set_qpos(self, data: mujoco.MjData)`: Updates the internal state of the collision checker with the given simulation data.
# - `__call__(self, sample: npt.NDArray, print_col: bool = False) -> bool`: Checks for collisions given a sample configuration and optionally prints collision details.
#
# #### 4. Functional Requirements:
# - The collision checker should update the model's configuration using the provided sample.
# - Perform collision detection using MuJoCo's collision functions.
# - Optionally ignore specified pairs of geometries during collision detection.
# - Optionally print details of collisions if specified.
# - Return a boolean indicating whether a collision was detected (excluding ignored pairs).

# %%
class CollisionChecker:
    """
    Collision checker for `Mujoco` model
    """

    def __init__(
        self,
        model: mujoco.MjModel,
        body_ids: list[int],
        ignore_pairs: list[tuple] = None,
    ) -> None:
        """
        Mujoco model collision checker (Mujoco `API` based)

        Args:
            model(`mujoco.MjModel`): Mujoco model
            body_ids(`list[int]`): list of body ids
            ignore_pairs(`list[tuple]`): list of ignore pairs
        """
        # Initialize the model
        self.model = model
        # Initialize the data for the simulation
        self.model_data = mujoco.MjData(model)
        # Get the joint positions associated with the body IDs
        self.qpos_adrs = get_qpos_adrs(model, body_ids)
        # Initialize the ignore flag
        self.ignore = False
        # If ignore pairs are provided
        if ignore_pairs:
            # Set the ignore flag to True
            self.ignore = True
            # Convert ignore pairs to sets of geometry IDs
            self.ignore_pairs = [
                set((model.geom(first).id, model.geom(second).id))
                for first, second in ignore_pairs
            ]

    def set_qpos(self, data: mujoco.MjData) -> None:
        """
        Set the joint positions of the Mujoco model to the given data
        """
        self.model_data.qpos[:] = data.qpos.copy()

    def __call__(self, sample: npt.NDArray, print_col: bool = False) -> bool:
        """
        Check if the robot is in collision with the environment

        Args:
            sample(`npt.NDArray`): joint position, Panda 7JOINT (7DOF)
            print_col(`bool`): print collision details, default is `False`
        """
        # Set the joint positions to the given sample
        self.model_data.qpos[self.qpos_adrs] = sample

        # Perform kinematics computations
        mujoco.mj_kinematics(self.model, self.model_data)
        # Check for collisions
        mujoco.mj_collision(self.model, self.model_data)
        # Get the number of contacts
        number_of_contacts = self.model_data.ncon

        # Print collision details if requested
        if print_col:
            print(f"Contacted body counts: {number_of_contacts}")
            for contact in self.model_data.contact:
                print(
                    "Collied between",
                    f"{self.model.body(self.model.geom(contact.geom1).body).name} : {self.model.geom(contact.geom1).name} and",
                    f"{self.model.body(self.model.geom(contact.geom2).body).name} : {self.model.geom(contact.geom2).name}",
                )

        # If ignoring specific pairs of contacts
        if self.ignore:
            for contact in self.model_data.contact:
                pair = set((contact.geom1, contact.geom2))
                if pair in self.ignore_pairs:
                    number_of_contacts -= 1

        # Return True if there are any contacts, False otherwise
        return number_of_contacts != 0

# %% [markdown]
# ### Ignore pairs
#
# ```python
# ignore_pairs = [("object_collision", "table_collision")]
# ```
#
# 무시할 object를 정의할 수 있다.

# %%
def test_collision():
    ignore_pairs = [("object_collision", "table_collision")]
    body_ids = get_body_ids(MODEL, eef="hand")
    collision = CollisionChecker(MODEL, body_ids)
    # collision.ignore_pairs = ignore_pairs

    sampler = Sampler(MODEL, body_ids)
    sample = sampler()
    sample += np.random.normal(0, 1, sample.shape)

    print(sample, not collision(sample, print_col=True))


test_collision()
# Out:
# Contacted body counts: 0
# [ 0.716  0.445 -0.114 -1.243 -2.653  4.338 -0.621] True

# %% [markdown]
# # 7.3 `Kinematics`

# %% [markdown]
# Use jacobian when doing inverse. In this case, `dof_adrs` must be used, because the qpos size of the free joint is 7, but the qvel size is 6. mujoco jacobian uses dof adrs because it deals with velocity values.
# For reference, the total number of qpos is `model.nq` and the total number of qvel is `model.nv`.

# %%
def rot_to_omega(R, threshold):
    el = np.array([[R[2, 1] - R[1, 2]], [R[0, 2] - R[2, 0]], [R[1, 0] - R[0, 1]]])
    norm_el = np.linalg.norm(el)
    if norm_el > threshold:
        w = np.dot(np.arctan2(norm_el, np.trace(R) - 1) / norm_el, el)
    elif R[0, 0] > 0 and R[1, 1] > 0 and R[2, 2] > 0:
        w = np.zeros((3, 1))
    else:
        w = np.dot(np.pi / 2, np.array([[R[0, 0] + 1], [R[1, 1] + 1], [R[2, 2] + 1]]))
    return w


def calc_pose_error(target_pos, target_rot, current_pos, current_rot, threshold):
    pos_diff = target_pos - current_pos
    rot_diff = np.dot(current_rot.T, target_rot)
    w_err = np.dot(current_rot, rot_to_omega(rot_diff, threshold))
    return np.vstack((pos_diff.reshape([-1, 1]), w_err))


class Kinematics:
    """
    Kinematics class for forward and inverse kinematics
    """

    def __init__(self, model: mujoco.MjModel, body_ids: list[int]) -> None:
        """
        Kinematics class for forward

        Args:
            model (`mujoco.MjModel`): Mujoco model
            body_ids (`list[int]`): list of body ids
        """
        self.model = model
        self.body_ids = body_ids

    def forward(self, qpos: npt.NDArray, eef_id: int = None) -> npt.NDArray:
        """
        Forward kinematics solve call

        Args:
            qpos (`npt.NDArray`): joint position
            eef_id (`int`): end effector id
        """
        body_ids = self.body_ids
        if eef_id:
            body_ids = self.get_sub_body_ids(eef_id)
        qpos_adrs = get_qpos_adrs(self.model, body_ids)
        if len(qpos_adrs) != len(qpos):
            raise ValueError(
                f"shape mismatch: qpos array of shape {qpos.shape} could not be broadcast to qpos addresses of shape ({len(qpos_adrs)},)"
            )

        fk_data = mujoco.MjData(self.model)
        fk_data.qpos[qpos_adrs] = qpos

        mujoco.mj_forward(self.model, fk_data)

        pos = fk_data.body(body_ids[-1]).xpos.copy()
        quat = fk_data.body(body_ids[-1]).xquat.copy()
        rot = fk_data.body(body_ids[-1]).xmat.reshape([3, 3]).copy()

        return pos, quat, rot

    def inverse(
        self,
        init_qpos: npt.NDArray,
        goal_pos: npt.NDArray,
        goal_rot: npt.NDArray,
        eef_id: int = None,
        max_iter: int = 10,
        threshold: float = 1e-8,
    ) -> npt.NDArray:
        """
        Inverse kinematics solve call

        Args:
            init_qpos (`npt.NDArray`): initial joint position
            goal_pos (`npt.NDArray`): goal position
            goal_rot (`npt.NDArray`): goal rotation
            eef_id (`int`): end effector id
            max_iter (`int`): maximum iteration
            threshold (`float`): threshold value
        """
        body_ids = self.body_ids
        if eef_id:
            body_ids = self.get_sub_body_ids(eef_id)
        qpos_adrs = get_qpos_adrs(self.model, body_ids)
        if len(qpos_adrs) != len(init_qpos):
            raise ValueError(
                f"shape mismatch: qpos array of shape {init_qpos.shape} could not be broadcast to qpos addresses of shape ({len(qpos_adrs)},)"
            )
        # Jacobian address
        qvel_adrs = get_qvel_adrs(self.model, body_ids)

        dof = self.get_total_dof_of_body_ids(body_ids)
        nv = self.model.nv
        wn_pos = 1 / 0.3
        wn_ang = 1 / (2 * np.pi)
        We = np.diag([wn_pos, wn_pos, wn_pos, wn_ang, wn_ang, wn_ang])
        Wn = np.eye(dof)

        current_qpos = init_qpos.copy()
        ik_data = mujoco.MjData(self.model)
        ik_data.qpos[qpos_adrs] = current_qpos
        mujoco.mj_forward(self.model, ik_data)
        current_pos = ik_data.body(body_ids[-1]).xpos.copy()
        current_rot = ik_data.body(body_ids[-1]).xmat.copy().reshape([3, 3])
        err = calc_pose_error(goal_pos, goal_rot, current_pos, current_rot, threshold)
        Ek = np.dot(np.dot(err.T, We), err)[0][0]

        # Jacobian matrix store
        # 1. Position Jacobian
        jacp = np.zeros((3, nv))
        # 2. Rotation Jacobian
        jacr = np.zeros((3, nv))

        for _ in range(max_iter):
            lamb = Ek + 0.002

            # Compute Jacobian -> Mujoco API -> Save jacp, jacr
            mujoco.mj_jac(self.model, ik_data, jacp, jacr, current_pos, body_ids[-1])

            # Reshape Jacobian
            J = np.vstack(
                [
                    jacp[:, qvel_adrs[0] : qvel_adrs[0] + dof],
                    jacr[:, qvel_adrs[0] : qvel_adrs[0] + dof],
                ]
            )
            # Damped Least Squares Inverse
            JT = np.dot(np.dot(J.T, We), J)
            J_dls = JT + np.dot(np.diag(np.diag(JT)), lamb)

            gerr = np.dot(np.dot(J.T, We), err)
            dq = np.dot(np.linalg.inv(J_dls), gerr)
            current_qpos += dq.reshape([-1])

            ik_data.qpos[qpos_adrs] = current_qpos
            mujoco.mj_forward(self.model, ik_data)
            current_pos = ik_data.body(body_ids[-1]).xpos.copy()
            current_rot = ik_data.body(body_ids[-1]).xmat.copy().reshape([3, 3])
            err = calc_pose_error(
                goal_pos, goal_rot, current_pos, current_rot, threshold
            )
            Ek2 = np.dot(np.dot(err.T, We), err)[0][0]
            if Ek2 <= threshold:
                print(Ek)
                break
            elif Ek2 < Ek:
                Ek = Ek2
            else:
                current_qpos -= dq.reshape([-1])
                print(Ek)
                break
        else:
            current_qpos = None
        return current_qpos

    def get_sub_body_ids(self, eef_id: int) -> list[int]:
        """
        Get the body ids of the kinematics chain of the given `end-effector`'s `id`

        Args:
            ee_id (`int`): end-effector id

        Returns:
            `list[int]`: list of body ids
        """
        body_ids = [eef_id]
        body_id = eef_id
        for _ in range(self.model.nbody):
            parent_id = self.model.body(body_id).parentid
            body_ids.append(parent_id[0])
            body_id = body_ids[-1]
            if body_id == self.body_ids[0]:
                break
        else:
            raise ValueError(f"body {eef_id} not in tree of kinematics chain.")
        body_ids.reverse()
        return body_ids

    def get_total_dof_of_body_ids(self, body_ids: list[int]) -> int:
        """
        Get the total DOF of the given body ids

        Args:
            body_ids (`list[int]`): list of body ids

        Returns:
            `int`: total DOF
        """
        dof = 0
        for jnt_id in self.model.body_jntadr[body_ids]:
            if jnt_id == -1:
                continue
            jnt_type = self.model.jnt(jnt_id).type
            if jnt_type[0] == mujoco.mjtJoint.mjJNT_FREE.value:
                dof += 7
            elif jnt_type[0] == mujoco.mjtJoint.mjJNT_BALL.value:
                dof += 4
            else:
                dof += 1
        return dof

# %%
def test_kinematics():
    body_ids = get_body_ids(MODEL, eef="hand")
    kinematics = Kinematics(MODEL, body_ids)

    sampler = Sampler(MODEL, body_ids)
    sample = sampler()
    print(f"before: {sample}")

    pos, _, rot = kinematics.forward(sample)
    sample += np.random.normal(0, 0.1, sample.shape)

    if sample in sampler:
        inversed = kinematics.inverse(sample, pos, rot)
        print(f"after:  {inversed}")
    else:
        print("not in valid joint range")


test_kinematics()
# Out:
# before: [-0.574 -0.077  0.425 -2.84   0.443  2.235 -0.258]
# 4.439991437471404e-07
# after:  [-0.676 -0.081  0.529 -2.839  0.454  2.231 -0.267]

# %% [markdown]
# # 7.4 `RRT* Planner`
#
# ### `ETA` 를 감소시키면, `step_size`가 많아지므로, 부드러워진다. 중요함

# %% [markdown]
# ### **Specifications**:
#
# ### 1. **Class Definition**:
# - **Class Name**: `RRTStarPlanner`
#
# ### 2. **Constructor Parameters**:
# - `gamma`: A parameter that influences the **radius**(= Boundary of neighborhood) of the search for nearby nodes during the rewiring process.
# - `eta`: The maximum step size for the tree expansion.
# - `epsilon`: Probability of sampling the goal configuration directly.
# > `epsilon` 확률에 따라 random sample이 아닌 goal에 가까운 sampling point를 선택
#
# ### 3. **Methods**:
# - `__init__(self, gamma: float, eta: float, epsilon: float = 0.0)`: Initializes the planner with the given parameters.
# - `__call__(self, sampler: Sampler, collision: CollisionChecker, init_qpos: npt.NDArray, goal_qpos: npt.NDArray, max_iter: int = 1000, threshold: float = 0.5)`: Runs the RRT* algorithm to find a path from `init_qpos` to `goal_qpos`.
# - `steer(self, nearest: npt.NDArray, sample: npt.NDArray, distance: float) -> npt.NDArray`: Steers from the nearest configuration towards the sample configuration within the step size limit.
# - `path(self) -> list[npt.NDArray]`: Returns the found path as a list of configurations if a path has been found.
#
# ### 4. **Functional Requirements**:
# - The planner should sample configurations from the configuration space and check for collisions.
# - It should steer from the nearest node in the tree towards the sampled configuration, respecting the maximum step size.
# - It should rewire the tree to ensure the minimum-cost path.
# - It should handle both reaching the goal configuration and ensuring the path is within a specified threshold distance from the goal.

# %%
class RRTStarPlanner:
    def __init__(self, gamma: float, eta: float, epsilon: float = 0.0) -> None:
        """
        RRT* Path Planner

        Args:
            gamma (`float`): search boundary(radius)
            eta (`float`): maximum step size
            epsilon (`float`): probability of choosing the goal directly
        """
        # Initialize parameters
        self.gamma: float = gamma
        self.eta: float = eta
        self.epsilon: float = epsilon
        # Flag to check if path is ready,
        # [Initial -> Goal]이 가능한지 확인 하는 상태
        self.path_ready: bool = False

    def __call__(
        self,
        sampler: Sampler,
        collision: CollisionChecker,
        init_qpos: npt.NDArray,
        goal_qpos: npt.NDArray,
        max_iter: int = 1000,
        threshold: float = 0.5,
    ) -> None:
        """
        RRT* Path Planner solve

        Find path `init_qpos` to `goal_qpos`

        Args:
            sampler (`Sampler`): Sampler object
            collision (`CollisionChecker`): Collision checker object
            init_qpos (`npt.NDArray`): initial joint position
            goal_qpos (`npt.NDArray`): goal joint position
            max_iter (`int`): maximum iteration of RRt*, default is 1000
            threshold (`float`): goal threshold, if the distance is less than the threshold, the goal is reached
        """
        # Initialize data buffers, tree structures
        self.samples = np.array([init_qpos.copy()])
        self.parents = np.array([-1], dtype=np.int32)
        self.costs = np.array([0], dtype=np.float64)

        self.path_ready = False

        # Main loop for the planner
        for _ in range(max_iter):
            # Sampling
            if np.random.random() < self.epsilon:
                # 1. epsilon 확률 이하 -> goal을 sampling
                new_qpos = goal_qpos.copy()
            else:
                # 2. epsilon 확률 이상 -> random sampling을 Sampler를 통해 진행한다.
                new_qpos = sampler()

            ## 3. sampling한 qpos가 valid한지 확인
            if collision(new_qpos):
                ## 4. collision이 발생하면 다시 sampling
                continue

            ## 5. nearest sample을 찾고, 새로운 sample로 steer
            distances = np.linalg.norm(self.samples - new_qpos, axis=1)

            nearest_node_index = np.argmin(distances)

            new_qpos = self.steer(
                self.samples[nearest_node_index],
                new_qpos,
                distances[nearest_node_index],
            )

            if new_qpos not in sampler:
                continue
            if collision(new_qpos):
                continue

            ## 6. 이웃한 node들을 찾아서, radius(cost)를 계산하고, 최소 radius(cost) 가지는 node를 near_indices에 저장
            # Connect along a minimum-cost path
            distances = np.linalg.norm(self.samples - new_qpos, axis=1)
            card = len(self.samples) + 1
            radius: float = self.gamma * (
                (math.log(card) / card) ** (1 / len(new_qpos))
            )
            radius: float = min(radius, self.eta)
            near_indices = np.where(np.around(distances, decimals=5) <= radius)[0]

            # 7. Rewire the tree
            near_costs = distances[near_indices] + self.costs[near_indices]
            min_cost = np.min(near_costs)
            min_index = near_indices[np.argmin(near_costs)]
            self.samples = np.vstack((self.samples, new_qpos))
            self.parents = np.append(self.parents, min_index)
            self.costs = np.append(self.costs, min_cost)

            # 8. update all costs
            need_update = np.where(
                distances[near_indices] + min_cost < self.costs[near_indices]
            )[0]
            self.parents[need_update] = len(self.parents) - 1
            self.costs[need_update] = distances[need_update] + min_cost

        # 9. End 조건 Check: if the goal is reached within the threshold
        distances = np.linalg.norm(self.samples - goal_qpos, axis=1)

        goal_near_indices = np.where(distances <= threshold)[0]

        if goal_near_indices.size > 0:
            index = np.argmin(
                self.costs[goal_near_indices] + distances[goal_near_indices]
            )
            cost = (
                self.costs[goal_near_indices[index]]
                + distances[goal_near_indices[index]]
            )
            self.samples = np.vstack((self.samples, goal_qpos.copy()))
            self.parents = np.append(self.parents, goal_near_indices[index])
            self.costs = np.append(self.costs, cost)
            self.path_ready = True

    def steer(
        self, nearest: npt.NDArray, sample: npt.NDArray, distance: float
    ) -> npt.NDArray:
        """
        Steer the nearest point towards the sample

        Args:
            nearest (`npt.NDArray`): nearest point
            sample (`npt.NDArray`): sample point

        Returns:
            `npt.NDArray`: steered point
        ```md
        # TODO: 여기에 holonomic constraint를 추가할 수 있다.
        ```
        """
        # Check if the nearest point is the same as the sample
        if np.equal(nearest, sample).all():
            return sample
        # Compute the vector towards the sample
        vector = sample - nearest
        # Normalize the vector
        unit_vector = vector / distance
        # Compute the step size
        step = min(self.eta, distance)
        # Compute the steered position
        steered = nearest + step * unit_vector

        return steered

    @property
    def path(self) -> list[npt.NDArray]:
        """
        Get `RRT*` result path
        """
        # Initialize path list
        path: list[npt.NDArray] = []

        # Check if the path is ready
        if self.path_ready:
            index = len(self.parents) - 1
            while index > 0:
                # Append the sample to the path
                path.append(self.samples[index])
                # Move to the parent index
                index = self.parents[index]
            # Reverse the path to start from the initial position
            path.reverse()

        return path

# %%
def test_rrt_star_planner():
    init_qpos = None
    goal_qpos = None
    sampler = Sampler(
        model=MODEL,
        body_ids=get_body_ids(MODEL, eef="hand"),
    )
    collision_checker = CollisionChecker(
        model=MODEL,
        body_ids=get_body_ids(MODEL, eef="hand"),
    )

    while True:
        init_qpos = sampler()
        if not collision_checker(init_qpos):
            break
    while True:
        goal_qpos = sampler()
        if not collision_checker(goal_qpos):
            break

    print("Start qpos")
    media.show_image(get_image_of_pos(init_qpos))

    print("Goal qpos")
    media.show_image(get_image_of_pos(goal_qpos))

    # Initialize the RRT* planner
    planner_1 = RRTStarPlanner(gamma=0.5, eta=0.1, epsilon=0.1)
    planner_2 = RRTStarPlanner(gamma=0.5, eta=0.05, epsilon=0.1)

    # ETA가 작으면 더 정교한 path를 찾을 수 있다.
    planner_3 = RRTStarPlanner(gamma=0.5, eta=0.01, epsilon=0.1)

    planners = [planner_1, planner_2, planner_3]
    paths = []
    for index, rrt_planner in enumerate(planners):
        start = time.time()
        rrt_planner(
            sampler,
            collision_checker,
            init_qpos,
            goal_qpos,
            max_iter=10000,
            threshold=0.05,
        )
        end = time.time()
        if path := rrt_planner.path:
            print(
                f"Planner {index+1} :: Find trajectory with length {len(path)} in time {end - start}."
            )
            paths.append(path)
        else:
            print(
                f"Planner {index+1} :: Failed to find trajectory. time: {end - start}"
            )

    for path in paths:
        frames = [get_image_of_pos(path[0]) for _ in range(len(path) // 10)]
        frames = frames + [get_image_of_pos(pos) for pos in path]
        frames = frames + [get_image_of_pos(path[-1]) for _ in range(len(path) // 10)]

        media.show_video(frames, fps=len(path) / 5)


test_rrt_star_planner()
# Out:
# Start qpos
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# Goal qpos
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# Planner 1 :: Find trajectory with length 56 in time 2.7623040676116943.
# Planner 2 :: Find trajectory with length 102 in time 2.7494308948516846.
# Planner 3 :: Find trajectory with length 524 in time 2.712651014328003.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# The video above was *__not__* controlled using a PID controller.

# %% [markdown]
# # 7.5 `Cartesian Planner`

# %% [markdown]
# ### **Specifications**:
#
# #### 1. **Class Definition**:
# - **Class Name**: `CartesianPlanner`
#
# #### 2. **Constructor Parameters**:
# - `damping`: A damping factor used in the `Damped Least Squares (DLS)` method for `inverse kinematics` (default: `0.01`).
# - `goal_tolerance`: Tolerance for considering the goal position reached (default: `0.01`).
#
# #### 3. **Methods**:
# - `__init__(self, damping: float = 0.01, goal_tolerance: float = 0.01)`: Initializes the planner with the given parameters.
# - `__call__(self, sampler: Sampler, collision: CollisionChecker, kinematics: Kinematics, init_qpos: npt.NDArray, goal_pos: npt.NDArray, goal_rot: npt.NDArray, eef_id: int = None, resolution: int = 1, n_step: int = 100, max_iter: int = 10, threshold: float = 1e-12)`: Plans a path from the initial configuration to the goal pose.
# - `generate_waypoints(self, init_pos, init_rot, goal_pos, goal_rot, n_step, is_slerp=False) -> list[tuple[npt.NDArray, npt.NDArray]]`: Generates waypoints from the initial pose to the goal pose.
#
# #### 4. **Functional Requirements**:
# - The planner should generate waypoints from the initial pose to the goal pose.
# - It should use inverse kinematics to move the end-effector along the waypoints.
# - It should check for collisions and ensure the path is collision-free.
# - It should stop if the goal pose is reached within the specified tolerance.

# %%
def get_quaternion_from_matrix(R):
    # Ensure the input is a proper rotation matrix
    assert R.shape == (3, 3)

    # Calculate the trace of the matrix
    trace = np.trace(R)

    if trace > 0:
        s = 2.0 * np.sqrt(trace + 1.0)
        w = 0.25 * s
        x = (R[2, 1] - R[1, 2]) / s
        y = (R[0, 2] - R[2, 0]) / s
        z = (R[1, 0] - R[0, 1]) / s
    elif (R[0, 0] > R[1, 1]) and (R[0, 0] > R[2, 2]):
        s = 2.0 * np.sqrt(1.0 + R[0, 0] - R[1, 1] - R[2, 2])
        w = (R[2, 1] - R[1, 2]) / s
        x = 0.25 * s
        y = (R[0, 1] + R[1, 0]) / s
        z = (R[0, 2] + R[2, 0]) / s
    elif R[1, 1] > R[2, 2]:
        s = 2.0 * np.sqrt(1.0 + R[1, 1] - R[0, 0] - R[2, 2])
        w = (R[0, 2] - R[2, 0]) / s
        x = (R[0, 1] + R[1, 0]) / s
        y = 0.25 * s
        z = (R[1, 2] + R[2, 1]) / s
    else:
        s = 2.0 * np.sqrt(1.0 + R[2, 2] - R[0, 0] - R[1, 1])
        w = (R[1, 0] - R[0, 1]) / s
        x = (R[0, 2] + R[2, 0]) / s
        y = (R[1, 2] + R[2, 1]) / s
        z = 0.25 * s

    return np.array([w, x, y, z])


def get_matrix_from_quaternion(quat):
    w, x, y, z = quat
    R = np.array(
        [
            [2 * (w**2 + x**2) - 1, 2 * (x * y - w * z), 2 * (x * z + w * y)],
            [2 * (x * y + w * z), 2 * (w**2 + y**2) - 1, 2 * (y * z - w * x)],
            [2 * (x * z - w * y), 2 * (y * z + w * x), 2 * (w**2 + z**2) - 1],
        ]
    )
    return R


def get_linear_interpoation(postionA, postionB, step):
    postionA = np.asarray(postionA)
    postionB = np.asarray(postionB)
    return postionB * step + postionA * (1 - step)


def get_quaternion_inverse(quaternion):
    q = np.array(quaternion, dtype=np.float64, copy=True)
    np.negative(q[1:], q[1:])
    return q / np.dot(q, q)


def get_quaternion_slerp(qA, qB, t):
    if isinstance(qA, (np.ndarray, list)) and isinstance(qB, (np.ndarray, list)):
        qA = np.asarray(qA)
        qB = np.asarray(qB)
        if qA.shape != (4,):  # quaternion
            raise ValueError("Expecting the shape of the orientation to be (4,)")
        if qB.shape == (0,):
            qB = np.asarray([1.0, 0.0, 0.0, 0.0])

        a = qB * get_quaternion_inverse(qA)
        result = np.sign(a) * (np.abs(a)) ** t * qA
        return result

# %%
class CartesianPlanner:
    """
    Cartesian planner

    forward (theta) -> (x, y, z, qw, qx, qy, qz) -> inverse (x, y, z, qw, qx, qy, qz) -> (theta)

    ```md
    P0 --> delta P --> Pt
    R0 --> delta R --> Rt
    ```

    Args:
        damping (`float`): damping factor for the damped least squares
        goal_tolerance (`float`): tolerance for the goal position
    """

    def __init__(self, damping: float = 0.01, goal_tolerance: float = 0.01):
        """
        Initialize the Cartesian planner

        Args:
            damping (`float`): damping factor for the damped least squares
            goal_tolerance (`float`): tolerance for the goal position
        """
        self.damping = damping
        self.goal_tolerance = goal_tolerance
        self.path = []

    def __call__(
        self,
        sampler: Sampler,
        collision: CollisionChecker,
        kinematics: Kinematics,
        init_qpos: npt.NDArray,
        goal_pos: npt.NDArray,
        goal_rot: npt.NDArray,
        eef_id: int = None,
        resolution: int = 1,
        n_step: int = 100,
        max_iter: int = 10,
        threshold: float = 1e-12,
    ) -> None:
        """
        Args:
            sampler (`Sampler`): sampler for the joint positions
            collision (`CollisionChecker`): collision checker
            kinematics (`Kinematics`): kinematics solver
            init_qpos (`npt.NDArray`): initial joint positions
            goal_pos (`npt.NDArray`): goal position
            goal_rot (`npt.NDArray`): goal rotation
            eef_id (`int`): end-effector body id
            resolution (`int`): resolution for the path
            n_step (`int`): number of steps(point count) for the waypoints path, !! 많을수록 상세한 path가 생성된다.
            max_iter (`int`): maximum number of Jacobian computation iterations
            threshold (`float`): threshold for the error
        """
        self.path = []
        init_pos, _, init_rot = kinematics.forward(init_qpos, eef_id)

        # 갈 길에 대한 points 생성
        waypoints = self.generate_waypoints(
            init_pos, init_rot, goal_pos, goal_rot, n_step
        )

        nv = kinematics.model.nv
        body_ids = kinematics.body_ids
        joint_ids = kinematics.model.body_jntadr[body_ids]
        joint_ids = [id for id in joint_ids if id != -1]

        # qpos, qvel address
        # qpos = joint position, qvel = joint velocity
        qpos_adrs = kinematics.model.jnt_qposadr[joint_ids]
        qvel_adrs = kinematics.model.jnt_dofadr[joint_ids]

        # Initialize the Jacobian data
        jac_data = mujoco.MjData(kinematics.model)
        jac_data.qpos[:] = collision.model_data.qpos.copy()

        jacp = np.zeros((3, nv))
        jacr = np.zeros((3, nv))

        DOF = kinematics.get_total_dof_of_body_ids(body_ids)

        collision_flag = False

        # Jacobian computation using damped-least-squares
        damping = self.damping

        for _ in range(max_iter):
            current_qpos = init_qpos.copy()
            joint_path = [current_qpos]
            jac_data.qpos[qpos_adrs] = current_qpos
            mujoco.mj_forward(kinematics.model, jac_data)
            current_pos = jac_data.body(body_ids[-1]).xpos.copy()
            current_rot = jac_data.body(body_ids[-1]).xmat.copy().reshape([3, 3])

            for step, (pos, rot) in enumerate(waypoints):
                # 1. 현재 위치와 목표 위치의 차이를 계산
                err_pose = calc_pose_error(
                    pos, rot, current_pos, current_rot, threshold
                )

                # 2. Jacobian 계산 -> mujoco API -> jacp, jacr 저장
                mujoco.mj_jac(
                    kinematics.model, jac_data, jacp, jacr, current_pos, body_ids[-1]
                )
                J = np.vstack(
                    [
                        jacp[:, qvel_adrs[0] : qvel_adrs[0] + DOF],
                        jacr[:, qvel_adrs[0] : qvel_adrs[0] + DOF],
                    ]
                )
                J_dls = np.dot(
                    J.T, np.linalg.inv(np.dot(J, J.T) + damping**2 * np.identity(6))
                )
                # 3. dq 계산 -> dq = J_dls * err_pose
                dq = np.dot(J_dls, err_pose)
                # 4. dq를 현재 위치에 더한다.
                current_qpos = current_qpos + dq.reshape([-1])

                # 5. 현재 위치가 valid한지 확인
                if collision(current_qpos):
                    # 충돌 path라면 불가능
                    collision_flag = True
                    break

                # 6. 충돌 없는 현재 위치를 mujoco에 업데이트
                jac_data.qpos[qpos_adrs] = current_qpos

                # 7. mujoco forward -> 현재 위치와 자세를 업데이트
                mujoco.mj_forward(kinematics.model, jac_data)

                # 8. 현재 위치, 자세 가져옴
                current_pos = jac_data.body(body_ids[-1]).xpos.copy()
                current_rot = jac_data.body(body_ids[-1]).xmat.copy().reshape([3, 3])

                # 9. 현재 위치를 path에 추가
                if current_qpos in sampler:
                    # resolution에 따라 path를 추가
                    if step % (1 / resolution) == 0 or step == len(waypoints) - 1:
                        joint_path.append(current_qpos)
            else:
                err = np.linalg.norm(goal_pos - current_pos)
                if err < self.goal_tolerance:
                    break
            if collision_flag:
                joint_path = []
                break
        else:
            joint_path = []
        self.path = joint_path

    def generate_waypoints(
        self,
        init_pos,
        init_rot,
        goal_pos,
        goal_rot,
        n_step,
        is_slerp=False,
    ) -> list[tuple[npt.NDArray, npt.NDArray]]:
        """
        Generate waypoints for the path

        Args:
            init_pos (`npt.NDArray`): initial position
            init_rot (`npt.NDArray`): initial rotation
            goal_pos (`npt.NDArray`): goal position
            goal_rot (`npt.NDArray`): goal rotation
            n_step (`int`): number of waypoints steps
            is_slerp (`bool`): flag to use slerp
        """
        waypoints = []
        if is_slerp:
            init_ori = get_quaternion_from_matrix(init_rot)
            goal_ori = get_quaternion_from_matrix(goal_rot)

        for step in range(1, n_step + 1):
            delta_t = step / n_step
            pos = get_linear_interpoation(init_pos, goal_pos, delta_t)
            rot = init_rot
            if is_slerp:
                quat = get_quaternion_slerp(init_ori, goal_ori, delta_t)
                rot = get_matrix_from_quaternion(quat)
            waypoints.append((pos, rot))
        return waypoints

# %%
def test_cartesian_planner():
    # 1. Reset the model
    mujoco.mj_resetDataKeyframe(MODEL, MODEL_DATA, 0)
    mujoco.mj_forward(MODEL, MODEL_DATA)

    # 2. Get the body ids
    body_ids = get_body_ids(MODEL, eef="hand")
    # 3. Get the qpos address
    qpose_adress = get_qpos_adrs(MODEL, body_ids)
    # 4. Get the initial qpos
    initial_qpos = MODEL_DATA.qpos[qpose_adress]
    print("Init qpos")
    media.show_image(get_image_of_pos(initial_qpos, "sideview"))

    # 5. Initialize the kinematics, sampler, collision checker
    kinematics = Kinematics(MODEL, body_ids)
    sampler = Sampler(MODEL, body_ids)
    collision_checker = CollisionChecker(MODEL, body_ids)

    # 6. Get the cartesian goals
    cartesian_goals = []
    for axis in range(3):
        goal_pos, _, goal_rot = kinematics.forward(initial_qpos)
        goal_pos[axis] = goal_pos[axis] - 0.1
        cartesian_goal_qpos = kinematics.inverse(initial_qpos, goal_pos, goal_rot)
        if cartesian_goal_qpos is not None and cartesian_goal_qpos in sampler:
            cartesian_goals.append((goal_pos, goal_rot))

    # 7. Initialize the cartesian planner
    cartesian_planner = CartesianPlanner()

    founded_paths = []
    axis_name = ["X", "Y", "Z"]

    for index, (pos, rot) in enumerate(cartesian_goals):
        start = time.time()
        cartesian_planner(
            sampler,
            collision_checker,
            kinematics,
            initial_qpos,
            pos,
            rot,
            n_step=100,
            resolution=2,
        )
        end = time.time()
        if path := cartesian_planner.path:
            print(
                f"Path to move {axis_name[index]}-axis :: Find trajectory with length {len(path)} in time {end - start}."
            )
            founded_paths.append(path)
        else:
            print(
                f"Path to move {axis_name[index]}-axis :: Failed to find trajectory. time: {end - start}"
            )

    # 8. Show the path, result as video
    views = ["sideview", "frontview", "frontview"]

    for path, view in zip(founded_paths, views):
        frames = [get_image_of_pos(path[0], view) for _ in range(len(path) // 10)]
        frames = frames + [get_image_of_pos(pos, view) for pos in path]
        frames = frames + [
            get_image_of_pos(path[-1], view) for _ in range(len(path) // 10)
        ]

        media.show_video(frames, fps=len(path) / 5)


test_cartesian_planner()
# Out:
# Init qpos
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# 2.7627261656669226e-06
# 4.2705618513681985e-07
# 3.577702715365005e-07
# Path to move X-axis :: Find trajectory with length 101 in time 0.1340041160583496.
# Path to move Y-axis :: Find trajectory with length 101 in time 0.03286385536193848.
# Path to move Z-axis :: Find trajectory with length 101 in time 0.09295392036437988.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# The video above was *__not__* controlled using a PID controller.

# %% [markdown]
# # 8. Object Grasp Planning

# %% [markdown]
# # Problem 1. [10pt] Find an object's pose in MuJoCo environment
#
# In a MuJoCo simulation environment, you often need to retrieve the positions and orientations of various objects (bodies) within the simulation. This information is crucial for tasks such as control, visualization, and analysis. Given a list of body names, write a Python function that:
#
# Retrieves the body IDs for the given body names.
# Extracts the positions and orientations (quaternions) of these bodies.
# Stores and returns this information in a dictionary.
#
# 1. `get_body_names(model)`: Retrieves and returns a list of all body names in the MuJoCo model.
# 2. `get_body_poses(model, data, body_names)`: Takes a list of body names and returns a dictionary with their positions and orientations.

# %%
from typing import Literal
import mujoco


def get_body_names(model: mujoco.MjModel) -> list[str]:
    """
    Retrieve all body names from the MuJoCo model.

    Parameters:
        model: MuJoCo model object.

    Returns:
        List of body names.
    """
    body_names: list[str] = []
    for i in range(model.nbody):
        body_name = mujoco.mj_id2name(model, mujoco.mjtObj.mjOBJ_BODY, i)
        if body_name:
            body_names.append(body_name)
    return body_names


def get_body_poses(
    model: mujoco.MjModel, data: mujoco.MjData, body_names: list[str]
) -> dict[
    str,
    dict[
        Literal[
            "position",
            "orientation",
        ],
        npt.NDArray,
    ],
]:
    """
    Retrieve the positions and orientations of specified bodies.

    Parameters:
        model: MuJoCo model object.
        data: MuJoCo data object.
        body_names: List of body names to retrieve poses for.

    Returns:
        Dictionary with body names as keys and their poses as values.
    """
    poses: dict[
        str,
        dict[Literal["position", "orientation"], npt.NDArray],
    ] = {}
    for body_name in body_names:
        body_id = mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_BODY, body_name)
        if body_id != -1:
            position = data.xpos[body_id]  # world position of the body
            orientation = data.xquat[body_id]  # orientation of the body in quaternions
            poses[body_name] = {
                "position": position,
                "orientation": orientation,
            }

    return poses

# %% [markdown]
# ## Update model for final test

# %%
# Replace model
# Initialize the MuJoCo model and data
MODEL_PATH = (
    "./panda_mjcf/panda_4cube.xml"  # Provide the path to your MuJoCo model file
)
MODEL = mujoco.MjModel.from_xml_path(MODEL_PATH)
MODEL_DATA = mujoco.MjData(MODEL)

# Reset the data to the initial keyframe and forward the simulation to update the data
mujoco.mj_resetDataKeyframe(MODEL, MODEL_DATA, 0)
mujoco.mj_forward(MODEL, MODEL_DATA)

# %%
def test_problem1():
    # Retrieve all body names to potentially modify what is returned based on what is present in the model
    all_body_names = get_body_names(MODEL)

    print("All body names:")
    print(all_body_names)
    # Get the poses of the specified bodies
    initial_gripper_pose = get_body_poses(MODEL, MODEL_DATA, all_body_names)

    print(initial_gripper_pose)
    # Print the poses
    for body_name, pose in initial_gripper_pose.items():
        print(f"Pose of {body_name}:")
        print(f"  Position: {pose['position']}")
        print(f"  Orientation (quaternion): {pose['orientation']}")


test_problem1()
# Out:
# All body names:
# ['world', 'table', 'red_cube', 'blue_cube', 'green_cube', 'yellow_cube', 'robot_fixed', 'mount_base', 'mount0_controller_box', 'mount_pedestal_feet', 'mount_torso', 'mount_pedestal', 'link0', 'link1', 'link2', 'link3', 'link4', 'link5', 'link6', 'link7', 'hand', 'grasp_site', 'left_finger', 'right_finger']
# {'world': {'position': array([0., 0., 0.]), 'orientation': array([1., 0., 0., 0.])}, 'table': {'position': array([0.   , 0.   , 0.775]), 'orientation': array([1., 0., 0., 0.])}, 'red_cube': {'position': array([0.03 , 0.172, 0.85 ]), 'orientation': array([0.973, 0.   , 0.   , 0.23 ])}, 'blue_cube': {'position': array([-0.086,  0.113,  0.85 ]), 'orientation': array([0.92 , 0.   , 0.   , 0.392])}, 'green_cube': {'position': array([-0.093, -0.085,  0.85 ]), 'orientation': array([0.825, 0.   , 0.   , 0.565])}, 'yellow_cube': {'position': array([ 0.149, -0.012,  0.85 ]), 'orientation': array([0.747, 0.   , 0.   , 0.665])}, 'robot_fixed': {'position': array([-0.6 ,  0.  ,  0.75]), 'orientation': array([1., 0., 0., 0.])}, 'mount_base': {'position': array([-0.6 ,  0.  ,  0.76]), 'orientation': array([1., 0., 0., 0.])}, 'mount0_controller_box': {'position': array([-0.6 ,  0.  ,  0.76]), 'orientation': array([1., 0., 0., 0.])}, 'mount_pedestal_feet': {'position': array([-0.6 ,  0.  ,  0.76]), 'orientation': array([1., 0., 0., 0.])}, 'mount_torso': {'position': array([-0.6 ,  0.  ,  0.76]), 'orientation': array([1., 0., 0., 0.])}, 'mount_pedestal': {'position': array([-0.6 ,  0.  ,  0.76]), 'orientation': array([1., 0., 0., 0.])}, 'link0': {'position': array([-0.6 ,  0.  ,  0.75]), 'orientation': array([1., 0., 0., 0.])}, 'link1': {'position': array([-0.6  ,  0.   ,  1.083]), 'orientation': array([1., 0., 0., 0.])}, 'link2': {'position': array([-0.6  ,  0.   ,  1.083]), 'orientation': array([ 0.707, -0.707,  0.   ,  0.   ])}, 'link3': {'position': array([-0.6  ,  0.   ,  1.399]), 'orientation': array([1., 0., 0., 0.])}, 'link4': {'position': array([-0.518,  0.   ,  1.399]), 'orientation': array([ 0.5,  0.5,  0.5, -0.5])}, 'link5': {'position': array([-0.134, -0.   ,  1.482]), 'orientation': array([0.707, 0.   , 0.707, 0.   ])}, 'link6': {'position': array([-0.134, -0.   ,  1.482]), 'orientation': array([ 0.707,  0.707, -0.   ,  0.   ])}, 'link7': {'position': array([-0.046, -0.   ,  1.482]), 'orientation': array([-0.   ,  0.924,  0.383,  0.   ])}, 'hand': {'position': array([-0.046, -0.   ,  1.375]), 'orientation': array([-0.   ,  0.707,  0.707,  0.   ])}, 'grasp_site': {'position': array([-0.046,  0.   ,  1.27 ]), 'orientation': array([-0.   ,  0.707,  0.707,  0.   ])}, 'left_finger': {'position': array([-0.006, -0.   ,  1.316]), 'orientation': array([-0.   ,  0.707,  0.707,  0.   ])}, 'right_finger': {'position': array([-0.086,  0.   ,  1.316]), 'orientation': array([-0.   ,  0.707, -0.707, -0.   ])}}
# Pose of world:
#   Position: [0. 0. 0.]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of table:
#   Position: [0.    0.    0.775]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of red_cube:
#   Position: [0.03  0.172 0.85 ]
#   Orientation (quaternion): [0.973 0.    0.    0.23 ]
# Pose of blue_cube:
#   Position: [-0.086  0.113  0.85 ]
#   Orientation (quaternion): [0.92  0.    0.    0.392]
# Pose of green_cube:
#   Position: [-0.093 -0.085  0.85 ]
#   Orientation (quaternion): [0.825 0.    0.    0.565]
# Pose of yellow_cube:
#   Position: [ 0.149 -0.012  0.85 ]
#   Orientation (quaternion): [0.747 0.    0.    0.665]
# Pose of robot_fixed:
#   Position: [-0.6   0.    0.75]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of mount_base:
#   Position: [-0.6   0.    0.76]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of mount0_controller_box:
#   Position: [-0.6   0.    0.76]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of mount_pedestal_feet:
#   Position: [-0.6   0.    0.76]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of mount_torso:
#   Position: [-0.6   0.    0.76]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of mount_pedestal:
#   Position: [-0.6   0.    0.76]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of link0:
#   Position: [-0.6   0.    0.75]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of link1:
#   Position: [-0.6    0.     1.083]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of link2:
#   Position: [-0.6    0.     1.083]
#   Orientation (quaternion): [ 0.707 -0.707  0.     0.   ]
# Pose of link3:
#   Position: [-0.6    0.     1.399]
#   Orientation (quaternion): [1. 0. 0. 0.]
# Pose of link4:
#   Position: [-0.518  0.     1.399]
#   Orientation (quaternion): [ 0.5  0.5  0.5 -0.5]
# Pose of link5:
#   Position: [-0.134 -0.     1.482]
#   Orientation (quaternion): [0.707 0.    0.707 0.   ]
# Pose of link6:
#   Position: [-0.134 -0.     1.482]
#   Orientation (quaternion): [ 0.707  0.707 -0.     0.   ]
# Pose of link7:
#   Position: [-0.046 -0.     1.482]
#   Orientation (quaternion): [-0.     0.924  0.383  0.   ]
# Pose of hand:
#   Position: [-0.046 -0.     1.375]
#   Orientation (quaternion): [-0.     0.707  0.707  0.   ]
# Pose of grasp_site:
#   Position: [-0.046  0.     1.27 ]
#   Orientation (quaternion): [-0.     0.707  0.707  0.   ]
# Pose of left_finger:
#   Position: [-0.006 -0.     1.316]
#   Orientation (quaternion): [-0.     0.707  0.707  0.   ]
# Pose of right_finger:
#   Position: [-0.086  0.     1.316]
#   Orientation (quaternion): [-0.     0.707 -0.707 -0.   ]

# %% [markdown]
# # Problem 2. [20pt] Compute grasp poses to grasp an object in MuJoCo environment
#
# In this problem, you are required to compute the necessary poses for a robotic gripper to grasp an object in a MuJoCo simulation. The solution will involve:
#
# 1. Computing the grasp pose for the gripper.
# 2. Computing the pre-grasp and post-grasp poses.
# 3. Solving the inverse kinematics for the pre-grasp pose.
#
# ### A. Pre-Grasp Pose
# The pre-grasp pose is an intermediate pose where the gripper is positioned slightly above the object. This pose is used to ensure that the gripper can move down smoothly and accurately to the grasp pose. It helps avoid collisions and provides a controlled approach to grasping.
#
# ### B. Post-Grasp Pose
# The post-grasp pose is the pose that the gripper assumes immediately after successfully grasping the object. This pose is used to lift the object slightly to ensure it is securely held before any further manipulation or movement.
#
# ### 본문제 = Pre-grasp ~= Post-grasp grasp

# %%
def compute_gripper_pose_for_grasping_cube(
    cube_pos, cube_quat, gripper_quat, height_above_cube=0.12
):
    """
    Compute the gripper pose for grasping a cube.

    Parameters:
        cube_pos (array): Position of the cube [x, y, z].
        cube_quat (array): Orientation of the cube in quaternion [w, x, y, z].
        gripper_quat (array): Orientation of the gripper in quaternion [w, x, y, z].
        height_above_cube (float): Height above the cube for the gripper.

    Returns:
        tuple: Final gripper position, quaternion, and rotation matrix.
    """
    # Compute the new gripper position for grasping
    gripper_position = cube_pos.copy()
    # Adjust to a suitable height above the cube base
    gripper_position[2] += height_above_cube

    # Compute the relative rotation needed to align the gripper with the cube's orientation
    gripper_quaternion = gripper_quat.copy()
    rotation_matrix = get_matrix_from_quaternion(gripper_quaternion)

    # Combine the gripper's downward orientation with the cube's orientation
    # to align the gripper with the cube's orientation
    gripper_alignment = np.dot(get_matrix_from_quaternion(cube_quat), rotation_matrix)

    # Return the final gripper position, quaternion, and rotation matrix
    return gripper_position, gripper_quaternion, gripper_alignment

# %%
def test_problem2():
    body_poses = get_body_poses(
        MODEL,
        MODEL_DATA,
        get_body_names(MODEL),
    )

    # Retrieve the cube and gripper positions and orientations from the body poses
    cube_position = body_poses["red_cube"]["position"]
    cube_orientation = body_poses["red_cube"]["orientation"]

    hand_position = body_poses["hand"]["position"]
    hand_orientation = body_poses["hand"]["orientation"]

    # Compute the gripper pose for grasping the cube
    gripper_position, gripper_orientation, gripper_rot = (
        compute_gripper_pose_for_grasping_cube(
            cube_position, cube_orientation, hand_orientation
        )
    )

    # Compute the pre-grasp pose (slightly above the final grasp pose)
    pre_gripper_position, pre_gripper_orientation, pre_gripper_rot = (
        copy.deepcopy(gripper_position),
        copy.deepcopy(gripper_orientation),
        copy.deepcopy(gripper_rot),
    )
    pre_gripper_position[2] += 0.03

    # Reset the simulation data and forward the simulation to update the state
    mujoco.mj_resetDataKeyframe(MODEL, MODEL_DATA, 0)
    mujoco.mj_forward(MODEL, MODEL_DATA)

    # Initialize the kinematics solver with the MODEL and body IDs
    body_ids = get_body_ids(MODEL, eef="hand")

    # Sample the current joint positions
    qpos_adress = get_qpos_adrs(MODEL, body_ids)
    sample = MODEL_DATA.qpos[qpos_adress]

    # Solve the inverse kinematics for the pre-grasp pose
    kinematics = Kinematics(MODEL, body_ids)
    pre_grasp_qpos = kinematics.inverse(
        sample,
        pre_gripper_position,
        pre_gripper_rot,
        max_iter=200,
    )

    # Print the computed gripper poses
    print("Gripper Pose:")
    print(f"  Position: {gripper_position}")
    print(f"  Orientation (quaternion): {gripper_orientation}")
    print("Pre Gripper Pose:")
    print(f"  Position: {pre_gripper_position}")
    print(f"  Orientation (quaternion): {pre_gripper_orientation}")

    # Visualize the pre-grasp pose from different camera views
    views = ["sideview", "frontview"]
    for view in views:
        media.show_image(get_image_of_pos(pre_grasp_qpos, view))


test_problem2()
# Out:
# 3.2523701325882594e-08
# Gripper Pose:
#   Position: [0.03  0.172 0.97 ]
#   Orientation (quaternion): [-0.     0.707  0.707  0.   ]
# Pre Gripper Pose:
#   Position: [0.03  0.172 1.   ]
#   Orientation (quaternion): [-0.     0.707  0.707  0.   ]
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# # Problem 3. [30pt] Find a path from an initial pose to the grasp pose
#
# In this problem, you are required to plan a path to execute the grasping.
#
# ## Path Planning Recommendations:
#
# > 2번을 통해 유도한 `pre-grasp` 위치를 통해 `RRT*` 를 호출한다.
#
# #### 1. From the `initial` -> `pre-grasp` pose: Use `RRT*`(Rapidly-exploring Random Tree) for path planning.
# #### 2. From the pre-grasp pose to the grasp pose: Use `Cartesian planning` for a `straight-line` approach.
# #### 3. From the grasp pose to the post-grasp pose: Reverse the `Cartesian plan`.
# #### 4. From the post-grasp pose to the initial pose: Reverse the `RRT*` plan.

# %%
def get_grasp_path(
    model: mujoco.MjModel,
    model_data: mujoco.MjData,
    height_above_cube: float = 0.12,
    rrt_start_max_iter: int = 100,
    rr_start_threshold: float = 0.05,
    rrt_start_gamma: float = 0.5,
    rrt_start_eta: float = 0.1,
    rrt_start_epsilon: float = 0.1,
    cartesian_dls_damping: float = 0.01,
    cartesian_goal_tolerance: float = 0.01,
    cartesian_resolution: int = 1,
    cartesian_max_iter: int = 10,
    cartesian_threshold: float = 1e-12,
    cartesian_n_step: int = 500,
    log: bool = False,
) -> list[npt.NDArray]:
    """
    Args:
        model: MuJoCo model object
        model_data: MuJoCo data object
        height_above_cube: Height above the cube for the gripper
        rrt_start_max_iter: Maximum number of iterations
        rr_start_threshold: Goal threshold
        rrt_start_gamma: Gamma value, the search radius
        rrt_start_eta: Eta value, lower eta value for more detailed path
        rrt_start_epsilon: Epsilon value, the probability of choosing the goal
        cartesian_dls_damping: Damping factor for the damped least squares method
        cartesian_goal_tolerance: Goal tolerance for the Cartesian planner
        cartesian_resolution: Resolution for the Cartesian planner
        cartesian_max_iter: Maximum number of iterations for the Cartesian planner
        cartesian_threshold: Threshold for the Cartesian planner
        cartesian_n_step: Number of steps for the Cartesian planner
        log: Flag to enable logging
    """
    body_poses = get_body_poses(
        MODEL,
        model_data,
        get_body_names(MODEL),
    )

    # Retrieve the cube and gripper positions and orientations from the body poses
    cube_position = body_poses["red_cube"]["position"]
    cube_orientation = body_poses["red_cube"]["orientation"]

    hand_position = body_poses["hand"]["position"]
    hand_orientation = body_poses["hand"]["orientation"]

    # Compute the gripper pose for grasping the cube
    gripper_position, gripper_orientation, gripper_rot = (
        compute_gripper_pose_for_grasping_cube(
            cube_position, cube_orientation, hand_orientation
        )
    )

    # Compute the pre-grasp pose (slightly above the final grasp pose)
    pre_gripper_position, pre_gripper_orientation, pre_gripper_rot = (
        copy.deepcopy(gripper_position),
        copy.deepcopy(gripper_orientation),
        copy.deepcopy(gripper_rot),
    )
    pre_gripper_position[2] += height_above_cube

    # Reset the simulation data and forward the simulation to update the state
    mujoco.mj_resetDataKeyframe(model, model_data, 0)
    mujoco.mj_forward(model, model_data)

    # Initialize the kinematics solver with the MODEL and body IDs
    body_ids = get_body_ids(model, eef="hand")

    # Sample the initial joint positions, reset already done so current pos is the initial pos
    qpos_adress = get_qpos_adrs(model, body_ids)
    initial_qpos = model_data.qpos[qpos_adress]

    # Solve the inverse kinematics for the pre-grasp pose
    kinematics = Kinematics(model, body_ids)
    pre_grasp_qpos = kinematics.inverse(
        initial_qpos,
        pre_gripper_position,
        pre_gripper_rot,
        max_iter=1000,
    )
    collision_checker = CollisionChecker(model, body_ids)
    sampler = Sampler(model, body_ids)

    # Initialize Planners
    rrtstar_planner = RRTStarPlanner(
        gamma=rrt_start_gamma,
        eta=rrt_start_eta,
        epsilon=rrt_start_epsilon,
    )
    cartesian_planner = CartesianPlanner(
        damping=cartesian_dls_damping,
        goal_tolerance=cartesian_goal_tolerance,
    )

    # Compute pre-grasp pose based on previously defined function
    # Assume gripper_position, gripper_orientation from Problem 2 are known and correct

    # Plan path from initial to pre-grasp pose using RRT*
    rrtstar_planner(
        sampler=sampler,
        collision=collision_checker,
        init_qpos=initial_qpos,
        goal_qpos=pre_grasp_qpos,
        max_iter=rrt_start_max_iter,
        threshold=rr_start_threshold,
    )

    # Cartesian planning from pre-grasp to grasp pose
    # Assuming that Cartesian planning also handles orientations
    cartesian_planner(
        sampler=sampler,
        collision=collision_checker,
        kinematics=kinematics,
        init_qpos=pre_grasp_qpos,  # pre-grasp pose -> goal gripper pos, rot
        goal_pos=gripper_position,  # Final grasp position
        goal_rot=gripper_rot,  # Final grasp orientation
        resolution=cartesian_resolution,
        n_step=cartesian_n_step,
        max_iter=cartesian_max_iter,
        threshold=cartesian_threshold,
    )

    # Collect the full path
    path_rrt = rrtstar_planner.path
    path_cartesian = cartesian_planner.path

    # Full path including pre/post grasp and return to initial
    full_planned_path: list[npt.NDArray] = (
        # Initial waiting pose
        [initial_qpos] * 10
        + path_rrt
        + path_cartesian
        + [pre_grasp_qpos] * 5  # Pre-grasp pose
        + list(reversed(path_cartesian))
        + list(reversed(path_rrt))
        + [initial_qpos] * 10
        # # Return to initial pose
    )

    if log:
        # Print or visualize the path
        print("Full Planned Path: total steps", len(full_planned_path))
        for step in full_planned_path:
            print(step)

    return full_planned_path


test_path = get_grasp_path(MODEL, MODEL_DATA, log=True)
# Out:
# 5.5802337271544625e-08
# Full Planned Path: total steps 1053
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.037 -0.014 -0.04  -1.566 -0.08   1.59  -0.787]
# [ 0.106 -0.02  -0.014 -1.571 -0.098  1.595 -0.852]
# [ 0.161 -0.001  0.    -1.552 -0.045  1.637 -0.89 ]
# [ 0.159  0.066  0.015 -1.559 -0.051  1.704 -0.863]
# [ 0.214  0.038  0.049 -1.53  -0.002  1.745 -0.855]
# [ 0.204  0.109  0.058 -1.542 -0.016  1.806 -0.828]
# [ 0.193  0.18   0.068 -1.553 -0.029  1.868 -0.802]
# [ 0.183  0.25   0.078 -1.564 -0.042  1.93  -0.775]
# [ 0.172  0.321  0.087 -1.576 -0.055  1.991 -0.749]
# [ 0.161  0.392  0.097 -1.587 -0.068  2.053 -0.722]
# [ 0.151  0.462  0.106 -1.598 -0.081  2.115 -0.696]
# [ 0.14   0.533  0.116 -1.61  -0.094  2.176 -0.67 ]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.188 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.188 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.189 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.189 -0.665]
# [ 0.138  0.547  0.117 -1.613 -0.096  2.189 -0.665]
# [ 0.138  0.547  0.117 -1.613 -0.096  2.19  -0.665]
# [ 0.138  0.547  0.117 -1.613 -0.096  2.19  -0.665]
# [ 0.138  0.548  0.117 -1.613 -0.096  2.191 -0.665]
# [ 0.138  0.548  0.117 -1.613 -0.096  2.191 -0.665]
# [ 0.138  0.548  0.117 -1.614 -0.096  2.192 -0.665]
# [ 0.138  0.549  0.117 -1.614 -0.096  2.192 -0.665]
# [ 0.138  0.549  0.117 -1.614 -0.097  2.193 -0.665]
# [ 0.139  0.549  0.117 -1.614 -0.097  2.193 -0.665]
# [ 0.139  0.549  0.117 -1.614 -0.097  2.194 -0.665]
# [ 0.139  0.55   0.117 -1.614 -0.097  2.194 -0.665]
# [ 0.139  0.55   0.117 -1.615 -0.097  2.195 -0.665]
# [ 0.139  0.55   0.117 -1.615 -0.097  2.195 -0.665]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.196 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.196 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.196 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.197 -0.664]
# [ 0.139  0.552  0.117 -1.615 -0.097  2.197 -0.664]
# [ 0.139  0.552  0.117 -1.616 -0.097  2.198 -0.664]
# [ 0.139  0.552  0.117 -1.616 -0.097  2.198 -0.664]
# [ 0.139  0.553  0.117 -1.616 -0.097  2.199 -0.664]
# [ 0.139  0.553  0.117 -1.616 -0.097  2.199 -0.664]
# [ 0.139  0.553  0.117 -1.616 -0.097  2.2   -0.664]
# [ 0.139  0.554  0.117 -1.616 -0.097  2.2   -0.664]
# [ 0.139  0.554  0.117 -1.617 -0.097  2.201 -0.664]
# [ 0.139  0.554  0.117 -1.617 -0.097  2.201 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.097  2.202 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.098  2.202 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.098  2.202 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.098  2.203 -0.664]
# [ 0.139  0.556  0.117 -1.618 -0.098  2.203 -0.664]
# [ 0.139  0.556  0.117 -1.618 -0.098  2.204 -0.664]
# [ 0.139  0.556  0.117 -1.618 -0.098  2.204 -0.664]
# [ 0.139  0.557  0.117 -1.618 -0.098  2.205 -0.664]
# [ 0.139  0.557  0.116 -1.618 -0.098  2.205 -0.664]
# [ 0.139  0.557  0.116 -1.618 -0.098  2.206 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.206 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.207 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.207 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.208 -0.664]
# [ 0.139  0.559  0.116 -1.619 -0.098  2.208 -0.663]
# [ 0.139  0.559  0.116 -1.619 -0.098  2.208 -0.663]
# [ 0.139  0.559  0.116 -1.619 -0.098  2.209 -0.663]
# [ 0.139  0.56   0.116 -1.62  -0.098  2.209 -0.663]
# [ 0.139  0.56   0.116 -1.62  -0.098  2.21  -0.663]
# [ 0.139  0.56   0.116 -1.62  -0.098  2.21  -0.663]
# [ 0.139  0.561  0.116 -1.62  -0.098  2.211 -0.663]
# [ 0.139  0.561  0.116 -1.62  -0.099  2.211 -0.663]
# [ 0.139  0.561  0.116 -1.62  -0.099  2.212 -0.663]
# [ 0.139  0.562  0.116 -1.62  -0.099  2.212 -0.663]
# [ 0.139  0.562  0.116 -1.621 -0.099  2.213 -0.663]
# [ 0.139  0.562  0.116 -1.621 -0.099  2.213 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.213 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.214 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.214 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.215 -0.663]
# [ 0.139  0.564  0.116 -1.621 -0.099  2.215 -0.663]
# [ 0.139  0.564  0.116 -1.622 -0.099  2.216 -0.663]
# [ 0.139  0.564  0.116 -1.622 -0.099  2.216 -0.663]
# [ 0.139  0.565  0.116 -1.622 -0.099  2.217 -0.663]
# [ 0.139  0.565  0.116 -1.622 -0.099  2.217 -0.663]
# [ 0.139  0.565  0.116 -1.622 -0.099  2.218 -0.663]
# [ 0.139  0.566  0.116 -1.622 -0.099  2.218 -0.663]
# [ 0.139  0.566  0.116 -1.622 -0.099  2.218 -0.663]
# [ 0.139  0.566  0.116 -1.623 -0.099  2.219 -0.663]
# [ 0.139  0.567  0.116 -1.623 -0.099  2.219 -0.663]
# [ 0.139  0.567  0.115 -1.623 -0.099  2.22  -0.663]
# [ 0.139  0.567  0.115 -1.623 -0.1    2.22  -0.662]
# [ 0.139  0.568  0.115 -1.623 -0.1    2.221 -0.662]
# [ 0.14   0.568  0.115 -1.623 -0.1    2.221 -0.662]
# [ 0.14   0.568  0.115 -1.623 -0.1    2.222 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.222 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.223 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.223 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.223 -0.662]
# [ 0.14   0.57   0.115 -1.624 -0.1    2.224 -0.662]
# [ 0.14   0.57   0.115 -1.624 -0.1    2.224 -0.662]
# [ 0.14   0.57   0.115 -1.624 -0.1    2.225 -0.662]
# [ 0.14   0.571  0.115 -1.625 -0.1    2.225 -0.662]
# [ 0.14   0.571  0.115 -1.625 -0.1    2.226 -0.662]
# [ 0.14   0.571  0.115 -1.625 -0.1    2.226 -0.662]
# [ 0.14   0.572  0.115 -1.625 -0.1    2.227 -0.662]
# [ 0.14   0.572  0.115 -1.625 -0.1    2.227 -0.662]
# [ 0.14   0.572  0.115 -1.625 -0.1    2.227 -0.662]
# [ 0.14   0.573  0.115 -1.625 -0.1    2.228 -0.662]
# [ 0.14   0.573  0.115 -1.625 -0.1    2.228 -0.662]
# [ 0.14   0.573  0.115 -1.626 -0.1    2.229 -0.662]
# [ 0.14   0.574  0.115 -1.626 -0.101  2.229 -0.662]
# [ 0.14   0.574  0.115 -1.626 -0.101  2.23  -0.662]
# [ 0.14   0.574  0.115 -1.626 -0.101  2.23  -0.662]
# [ 0.14   0.575  0.115 -1.626 -0.101  2.231 -0.662]
# [ 0.14   0.575  0.115 -1.626 -0.101  2.231 -0.662]
# [ 0.14   0.575  0.115 -1.626 -0.101  2.232 -0.662]
# [ 0.14   0.576  0.115 -1.626 -0.101  2.232 -0.661]
# [ 0.14   0.576  0.115 -1.627 -0.101  2.232 -0.661]
# [ 0.14   0.576  0.115 -1.627 -0.101  2.233 -0.661]
# [ 0.14   0.577  0.115 -1.627 -0.101  2.233 -0.661]
# [ 0.14   0.577  0.115 -1.627 -0.101  2.234 -0.661]
# [ 0.14   0.577  0.114 -1.627 -0.101  2.234 -0.661]
# [ 0.14   0.578  0.114 -1.627 -0.101  2.235 -0.661]
# [ 0.14   0.578  0.114 -1.627 -0.101  2.235 -0.661]
# [ 0.14   0.578  0.114 -1.627 -0.101  2.236 -0.661]
# [ 0.14   0.579  0.114 -1.628 -0.101  2.236 -0.661]
# [ 0.14   0.579  0.114 -1.628 -0.101  2.236 -0.661]
# [ 0.14   0.579  0.114 -1.628 -0.101  2.237 -0.661]
# [ 0.14   0.58   0.114 -1.628 -0.101  2.237 -0.661]
# [ 0.14   0.58   0.114 -1.628 -0.102  2.238 -0.661]
# [ 0.14   0.58   0.114 -1.628 -0.102  2.238 -0.661]
# [ 0.14   0.581  0.114 -1.628 -0.102  2.239 -0.661]
# [ 0.14   0.581  0.114 -1.628 -0.102  2.239 -0.661]
# [ 0.14   0.581  0.114 -1.629 -0.102  2.24  -0.661]
# [ 0.14   0.581  0.114 -1.629 -0.102  2.24  -0.661]
# [ 0.14   0.582  0.114 -1.629 -0.102  2.24  -0.661]
# [ 0.14   0.582  0.114 -1.629 -0.102  2.241 -0.661]
# [ 0.14   0.582  0.114 -1.629 -0.102  2.241 -0.661]
# [ 0.14   0.583  0.114 -1.629 -0.102  2.242 -0.661]
# [ 0.14   0.583  0.114 -1.629 -0.102  2.242 -0.661]
# [ 0.14   0.583  0.114 -1.629 -0.102  2.243 -0.661]
# [ 0.14   0.584  0.114 -1.629 -0.102  2.243 -0.661]
# [ 0.14   0.584  0.114 -1.63  -0.102  2.244 -0.661]
# [ 0.14   0.584  0.114 -1.63  -0.102  2.244 -0.66 ]
# [ 0.14   0.585  0.114 -1.63  -0.102  2.244 -0.66 ]
# [ 0.14   0.585  0.114 -1.63  -0.102  2.245 -0.66 ]
# [ 0.141  0.585  0.114 -1.63  -0.102  2.245 -0.66 ]
# [ 0.141  0.586  0.114 -1.63  -0.102  2.246 -0.66 ]
# [ 0.141  0.586  0.114 -1.63  -0.103  2.246 -0.66 ]
# [ 0.141  0.586  0.114 -1.63  -0.103  2.247 -0.66 ]
# [ 0.141  0.587  0.114 -1.63  -0.103  2.247 -0.66 ]
# [ 0.141  0.587  0.113 -1.631 -0.103  2.248 -0.66 ]
# [ 0.141  0.587  0.113 -1.631 -0.103  2.248 -0.66 ]
# [ 0.141  0.588  0.113 -1.631 -0.103  2.248 -0.66 ]
# [ 0.141  0.588  0.113 -1.631 -0.103  2.249 -0.66 ]
# [ 0.141  0.589  0.113 -1.631 -0.103  2.249 -0.66 ]
# [ 0.141  0.589  0.113 -1.631 -0.103  2.25  -0.66 ]
# [ 0.141  0.589  0.113 -1.631 -0.103  2.25  -0.66 ]
# [ 0.141  0.59   0.113 -1.631 -0.103  2.251 -0.66 ]
# [ 0.141  0.59   0.113 -1.631 -0.103  2.251 -0.66 ]
# [ 0.141  0.59   0.113 -1.631 -0.103  2.252 -0.66 ]
# [ 0.141  0.591  0.113 -1.632 -0.103  2.252 -0.66 ]
# [ 0.141  0.591  0.113 -1.632 -0.103  2.252 -0.66 ]
# [ 0.141  0.591  0.113 -1.632 -0.103  2.253 -0.66 ]
# [ 0.141  0.592  0.113 -1.632 -0.103  2.253 -0.66 ]
# [ 0.141  0.592  0.113 -1.632 -0.103  2.254 -0.66 ]
# [ 0.141  0.592  0.113 -1.632 -0.103  2.254 -0.66 ]
# [ 0.141  0.593  0.113 -1.632 -0.103  2.255 -0.66 ]
# [ 0.141  0.593  0.113 -1.632 -0.104  2.255 -0.66 ]
# [ 0.141  0.593  0.113 -1.632 -0.104  2.255 -0.659]
# [ 0.141  0.594  0.113 -1.632 -0.104  2.256 -0.659]
# [ 0.141  0.594  0.113 -1.633 -0.104  2.256 -0.659]
# [ 0.141  0.594  0.113 -1.633 -0.104  2.257 -0.659]
# [ 0.141  0.595  0.113 -1.633 -0.104  2.257 -0.659]
# [ 0.141  0.595  0.113 -1.633 -0.104  2.258 -0.659]
# [ 0.141  0.595  0.113 -1.633 -0.104  2.258 -0.659]
# [ 0.141  0.596  0.113 -1.633 -0.104  2.259 -0.659]
# [ 0.141  0.596  0.113 -1.633 -0.104  2.259 -0.659]
# [ 0.141  0.596  0.113 -1.633 -0.104  2.259 -0.659]
# [ 0.141  0.597  0.112 -1.633 -0.104  2.26  -0.659]
# [ 0.141  0.597  0.112 -1.633 -0.104  2.26  -0.659]
# [ 0.141  0.597  0.112 -1.634 -0.104  2.261 -0.659]
# [ 0.141  0.598  0.112 -1.634 -0.104  2.261 -0.659]
# [ 0.141  0.598  0.112 -1.634 -0.104  2.262 -0.659]
# [ 0.141  0.598  0.112 -1.634 -0.104  2.262 -0.659]
# [ 0.141  0.599  0.112 -1.634 -0.104  2.262 -0.659]
# [ 0.141  0.599  0.112 -1.634 -0.104  2.263 -0.659]
# [ 0.141  0.599  0.112 -1.634 -0.105  2.263 -0.659]
# [ 0.141  0.6    0.112 -1.634 -0.105  2.264 -0.659]
# [ 0.141  0.6    0.112 -1.634 -0.105  2.264 -0.659]
# [ 0.141  0.6    0.112 -1.634 -0.105  2.265 -0.659]
# [ 0.141  0.601  0.112 -1.634 -0.105  2.265 -0.659]
# [ 0.141  0.601  0.112 -1.635 -0.105  2.266 -0.659]
# [ 0.141  0.602  0.112 -1.635 -0.105  2.266 -0.659]
# [ 0.142  0.602  0.112 -1.635 -0.105  2.266 -0.659]
# [ 0.142  0.602  0.112 -1.635 -0.105  2.267 -0.658]
# [ 0.142  0.603  0.112 -1.635 -0.105  2.267 -0.658]
# [ 0.142  0.603  0.112 -1.635 -0.105  2.268 -0.658]
# [ 0.142  0.603  0.112 -1.635 -0.105  2.268 -0.658]
# [ 0.142  0.604  0.112 -1.635 -0.105  2.269 -0.658]
# [ 0.142  0.604  0.112 -1.635 -0.105  2.269 -0.658]
# [ 0.142  0.604  0.112 -1.635 -0.105  2.269 -0.658]
# [ 0.142  0.605  0.112 -1.635 -0.105  2.27  -0.658]
# [ 0.142  0.605  0.112 -1.635 -0.105  2.27  -0.658]
# [ 0.142  0.605  0.112 -1.636 -0.105  2.271 -0.658]
# [ 0.142  0.606  0.112 -1.636 -0.105  2.271 -0.658]
# [ 0.142  0.606  0.112 -1.636 -0.106  2.272 -0.658]
# [ 0.142  0.606  0.111 -1.636 -0.106  2.272 -0.658]
# [ 0.142  0.607  0.111 -1.636 -0.106  2.272 -0.658]
# [ 0.142  0.607  0.111 -1.636 -0.106  2.273 -0.658]
# [ 0.142  0.607  0.111 -1.636 -0.106  2.273 -0.658]
# [ 0.142  0.608  0.111 -1.636 -0.106  2.274 -0.658]
# [ 0.142  0.608  0.111 -1.636 -0.106  2.274 -0.658]
# [ 0.142  0.609  0.111 -1.636 -0.106  2.275 -0.658]
# [ 0.142  0.609  0.111 -1.636 -0.106  2.275 -0.658]
# [ 0.142  0.609  0.111 -1.636 -0.106  2.275 -0.658]
# [ 0.142  0.61   0.111 -1.636 -0.106  2.276 -0.658]
# [ 0.142  0.61   0.111 -1.637 -0.106  2.276 -0.658]
# [ 0.142  0.61   0.111 -1.637 -0.106  2.277 -0.658]
# [ 0.142  0.611  0.111 -1.637 -0.106  2.277 -0.658]
# [ 0.142  0.611  0.111 -1.637 -0.106  2.278 -0.658]
# [ 0.142  0.611  0.111 -1.637 -0.106  2.278 -0.657]
# [ 0.142  0.612  0.111 -1.637 -0.106  2.278 -0.657]
# [ 0.142  0.612  0.111 -1.637 -0.106  2.279 -0.657]
# [ 0.142  0.612  0.111 -1.637 -0.106  2.279 -0.657]
# [ 0.142  0.613  0.111 -1.637 -0.107  2.28  -0.657]
# [ 0.142  0.613  0.111 -1.637 -0.107  2.28  -0.657]
# [ 0.142  0.614  0.111 -1.637 -0.107  2.281 -0.657]
# [ 0.142  0.614  0.111 -1.637 -0.107  2.281 -0.657]
# [ 0.142  0.614  0.111 -1.637 -0.107  2.281 -0.657]
# [ 0.142  0.615  0.111 -1.637 -0.107  2.282 -0.657]
# [ 0.142  0.615  0.111 -1.638 -0.107  2.282 -0.657]
# [ 0.142  0.615  0.111 -1.638 -0.107  2.283 -0.657]
# [ 0.142  0.616  0.111 -1.638 -0.107  2.283 -0.657]
# [ 0.142  0.616  0.111 -1.638 -0.107  2.284 -0.657]
# [ 0.142  0.616  0.11  -1.638 -0.107  2.284 -0.657]
# [ 0.142  0.617  0.11  -1.638 -0.107  2.284 -0.657]
# [ 0.142  0.617  0.11  -1.638 -0.107  2.285 -0.657]
# [ 0.142  0.618  0.11  -1.638 -0.107  2.285 -0.657]
# [ 0.143  0.618  0.11  -1.638 -0.107  2.286 -0.657]
# [ 0.143  0.618  0.11  -1.638 -0.107  2.286 -0.657]
# [ 0.143  0.619  0.11  -1.638 -0.107  2.287 -0.657]
# [ 0.143  0.619  0.11  -1.638 -0.107  2.287 -0.657]
# [ 0.143  0.619  0.11  -1.638 -0.107  2.287 -0.657]
# [ 0.143  0.62   0.11  -1.638 -0.108  2.288 -0.657]
# [ 0.143  0.62   0.11  -1.638 -0.108  2.288 -0.657]
# [ 0.143  0.62   0.11  -1.639 -0.108  2.289 -0.657]
# [ 0.143  0.621  0.11  -1.639 -0.108  2.289 -0.656]
# [ 0.143  0.621  0.11  -1.639 -0.108  2.29  -0.656]
# [ 0.143  0.622  0.11  -1.639 -0.108  2.29  -0.656]
# [ 0.143  0.622  0.11  -1.639 -0.108  2.29  -0.656]
# [ 0.143  0.622  0.11  -1.639 -0.108  2.291 -0.656]
# [ 0.143  0.623  0.11  -1.639 -0.108  2.291 -0.656]
# [ 0.143  0.623  0.11  -1.639 -0.108  2.292 -0.656]
# [ 0.143  0.623  0.11  -1.639 -0.108  2.292 -0.656]
# [ 0.143  0.624  0.11  -1.639 -0.108  2.292 -0.656]
# [ 0.143  0.624  0.11  -1.639 -0.108  2.293 -0.656]
# [ 0.143  0.624  0.11  -1.639 -0.108  2.293 -0.656]
# [ 0.143  0.625  0.11  -1.639 -0.108  2.294 -0.656]
# [ 0.143  0.625  0.11  -1.639 -0.108  2.294 -0.656]
# [ 0.143  0.626  0.11  -1.639 -0.108  2.295 -0.656]
# [ 0.143  0.626  0.109 -1.639 -0.108  2.295 -0.656]
# [ 0.143  0.626  0.109 -1.639 -0.108  2.295 -0.656]
# [ 0.143  0.627  0.109 -1.639 -0.109  2.296 -0.656]
# [ 0.143  0.627  0.109 -1.64  -0.109  2.296 -0.656]
# [ 0.143  0.627  0.109 -1.64  -0.109  2.297 -0.656]
# [ 0.143  0.628  0.109 -1.64  -0.109  2.297 -0.656]
# [ 0.143  0.628  0.109 -1.64  -0.109  2.298 -0.656]
# [ 0.143  0.628  0.109 -1.64  -0.109  2.298 -0.656]
# [ 0.143  0.629  0.109 -1.64  -0.109  2.298 -0.656]
# [ 0.143  0.629  0.109 -1.64  -0.109  2.299 -0.656]
# [ 0.143  0.63   0.109 -1.64  -0.109  2.299 -0.656]
# [ 0.143  0.63   0.109 -1.64  -0.109  2.3   -0.656]
# [ 0.143  0.63   0.109 -1.64  -0.109  2.3   -0.656]
# [ 0.143  0.631  0.109 -1.64  -0.109  2.3   -0.655]
# [ 0.143  0.631  0.109 -1.64  -0.109  2.301 -0.655]
# [ 0.143  0.631  0.109 -1.64  -0.109  2.301 -0.655]
# [ 0.143  0.632  0.109 -1.64  -0.109  2.302 -0.655]
# [ 0.143  0.632  0.109 -1.64  -0.109  2.302 -0.655]
# [ 0.143  0.633  0.109 -1.64  -0.109  2.303 -0.655]
# [ 0.143  0.633  0.109 -1.64  -0.109  2.303 -0.655]
# [ 0.144  0.633  0.109 -1.64  -0.109  2.303 -0.655]
# [ 0.144  0.634  0.109 -1.64  -0.11   2.304 -0.655]
# [ 0.144  0.634  0.109 -1.64  -0.11   2.304 -0.655]
# [ 0.144  0.634  0.109 -1.64  -0.11   2.305 -0.655]
# [ 0.144  0.635  0.109 -1.641 -0.11   2.305 -0.655]
# [ 0.144  0.635  0.109 -1.641 -0.11   2.305 -0.655]
# [ 0.144  0.636  0.108 -1.641 -0.11   2.306 -0.655]
# [ 0.144  0.636  0.108 -1.641 -0.11   2.306 -0.655]
# [ 0.144  0.636  0.108 -1.641 -0.11   2.307 -0.655]
# [ 0.144  0.637  0.108 -1.641 -0.11   2.307 -0.655]
# [ 0.144  0.637  0.108 -1.641 -0.11   2.308 -0.655]
# [ 0.144  0.637  0.108 -1.641 -0.11   2.308 -0.655]
# [ 0.144  0.638  0.108 -1.641 -0.11   2.308 -0.655]
# [ 0.144  0.638  0.108 -1.641 -0.11   2.309 -0.655]
# [ 0.144  0.639  0.108 -1.641 -0.11   2.309 -0.655]
# [ 0.144  0.639  0.108 -1.641 -0.11   2.31  -0.655]
# [ 0.144  0.639  0.108 -1.641 -0.11   2.31  -0.655]
# [ 0.144  0.64   0.108 -1.641 -0.11   2.31  -0.655]
# [ 0.144  0.64   0.108 -1.641 -0.11   2.311 -0.655]
# [ 0.144  0.64   0.108 -1.641 -0.11   2.311 -0.654]
# [ 0.144  0.641  0.108 -1.641 -0.111  2.312 -0.654]
# [ 0.144  0.641  0.108 -1.641 -0.111  2.312 -0.654]
# [ 0.144  0.642  0.108 -1.641 -0.111  2.313 -0.654]
# [ 0.144  0.642  0.108 -1.641 -0.111  2.313 -0.654]
# [ 0.144  0.642  0.108 -1.641 -0.111  2.313 -0.654]
# [ 0.144  0.643  0.108 -1.641 -0.111  2.314 -0.654]
# [ 0.144  0.643  0.108 -1.641 -0.111  2.314 -0.654]
# [ 0.144  0.644  0.108 -1.641 -0.111  2.315 -0.654]
# [ 0.144  0.644  0.108 -1.641 -0.111  2.315 -0.654]
# [ 0.144  0.644  0.108 -1.641 -0.111  2.315 -0.654]
# [ 0.144  0.645  0.108 -1.641 -0.111  2.316 -0.654]
# [ 0.144  0.645  0.107 -1.641 -0.111  2.316 -0.654]
# [ 0.144  0.645  0.107 -1.642 -0.111  2.317 -0.654]
# [ 0.144  0.646  0.107 -1.642 -0.111  2.317 -0.654]
# [ 0.144  0.646  0.107 -1.642 -0.111  2.317 -0.654]
# [ 0.144  0.647  0.107 -1.642 -0.111  2.318 -0.654]
# [ 0.144  0.647  0.107 -1.642 -0.111  2.318 -0.654]
# [ 0.144  0.647  0.107 -1.642 -0.111  2.319 -0.654]
# [ 0.144  0.648  0.107 -1.642 -0.112  2.319 -0.654]
# [ 0.144  0.648  0.107 -1.642 -0.112  2.319 -0.654]
# [ 0.145  0.649  0.107 -1.642 -0.112  2.32  -0.654]
# [ 0.145  0.649  0.107 -1.642 -0.112  2.32  -0.654]
# [ 0.145  0.649  0.107 -1.642 -0.112  2.321 -0.654]
# [ 0.145  0.65   0.107 -1.642 -0.112  2.321 -0.654]
# [ 0.145  0.65   0.107 -1.642 -0.112  2.322 -0.654]
# [ 0.145  0.65   0.107 -1.642 -0.112  2.322 -0.653]
# [ 0.145  0.651  0.107 -1.642 -0.112  2.322 -0.653]
# [ 0.145  0.651  0.107 -1.642 -0.112  2.323 -0.653]
# [ 0.145  0.652  0.107 -1.642 -0.112  2.323 -0.653]
# [ 0.145  0.652  0.107 -1.642 -0.112  2.324 -0.653]
# [ 0.145  0.652  0.107 -1.642 -0.112  2.324 -0.653]
# [ 0.145  0.653  0.107 -1.642 -0.112  2.324 -0.653]
# [ 0.145  0.653  0.107 -1.642 -0.112  2.325 -0.653]
# [ 0.145  0.654  0.107 -1.642 -0.112  2.325 -0.653]
# [ 0.145  0.654  0.107 -1.642 -0.112  2.326 -0.653]
# [ 0.145  0.654  0.107 -1.642 -0.112  2.326 -0.653]
# [ 0.145  0.655  0.106 -1.642 -0.112  2.326 -0.653]
# [ 0.145  0.655  0.106 -1.642 -0.113  2.327 -0.653]
# [ 0.145  0.656  0.106 -1.642 -0.113  2.327 -0.653]
# [ 0.145  0.656  0.106 -1.642 -0.113  2.328 -0.653]
# [ 0.145  0.656  0.106 -1.642 -0.113  2.328 -0.653]
# [ 0.145  0.657  0.106 -1.642 -0.113  2.328 -0.653]
# [ 0.145  0.657  0.106 -1.642 -0.113  2.329 -0.653]
# [ 0.145  0.657  0.106 -1.642 -0.113  2.329 -0.653]
# [ 0.145  0.658  0.106 -1.642 -0.113  2.33  -0.653]
# [ 0.145  0.658  0.106 -1.642 -0.113  2.33  -0.653]
# [ 0.145  0.659  0.106 -1.642 -0.113  2.33  -0.653]
# [ 0.145  0.659  0.106 -1.642 -0.113  2.331 -0.653]
# [ 0.145  0.659  0.106 -1.642 -0.113  2.331 -0.653]
# [ 0.145  0.66   0.106 -1.642 -0.113  2.332 -0.653]
# [ 0.145  0.66   0.106 -1.642 -0.113  2.332 -0.653]
# [ 0.145  0.661  0.106 -1.642 -0.113  2.332 -0.653]
# [ 0.145  0.661  0.106 -1.642 -0.113  2.333 -0.652]
# [ 0.145  0.661  0.106 -1.642 -0.113  2.333 -0.652]
# [ 0.145  0.662  0.106 -1.642 -0.113  2.334 -0.652]
# [ 0.145  0.662  0.106 -1.642 -0.113  2.334 -0.652]
# [ 0.145  0.663  0.106 -1.642 -0.114  2.334 -0.652]
# [ 0.146  0.663  0.106 -1.642 -0.114  2.335 -0.652]
# [ 0.146  0.663  0.106 -1.642 -0.114  2.335 -0.652]
# [ 0.146  0.664  0.106 -1.642 -0.114  2.336 -0.652]
# [ 0.146  0.664  0.105 -1.642 -0.114  2.336 -0.652]
# [ 0.146  0.665  0.105 -1.642 -0.114  2.336 -0.652]
# [ 0.146  0.665  0.105 -1.642 -0.114  2.337 -0.652]
# [ 0.146  0.665  0.105 -1.642 -0.114  2.337 -0.652]
# [ 0.146  0.666  0.105 -1.642 -0.114  2.338 -0.652]
# [ 0.146  0.666  0.105 -1.642 -0.114  2.338 -0.652]
# [ 0.146  0.667  0.105 -1.642 -0.114  2.338 -0.652]
# [ 0.146  0.667  0.105 -1.642 -0.114  2.339 -0.652]
# [ 0.146  0.667  0.105 -1.642 -0.114  2.339 -0.652]
# [ 0.146  0.668  0.105 -1.642 -0.114  2.34  -0.652]
# [ 0.146  0.668  0.105 -1.642 -0.114  2.34  -0.652]
# [ 0.146  0.669  0.105 -1.642 -0.114  2.34  -0.652]
# [ 0.146  0.669  0.105 -1.642 -0.114  2.341 -0.652]
# [ 0.146  0.669  0.105 -1.642 -0.114  2.341 -0.652]
# [ 0.146  0.67   0.105 -1.642 -0.114  2.342 -0.652]
# [ 0.146  0.67   0.105 -1.642 -0.115  2.342 -0.652]
# [ 0.146  0.671  0.105 -1.642 -0.115  2.342 -0.652]
# [ 0.146  0.671  0.105 -1.642 -0.115  2.343 -0.652]
# [ 0.146  0.671  0.105 -1.642 -0.115  2.343 -0.651]
# [ 0.146  0.672  0.105 -1.642 -0.115  2.344 -0.651]
# [ 0.146  0.672  0.105 -1.642 -0.115  2.344 -0.651]
# [ 0.146  0.673  0.105 -1.642 -0.115  2.344 -0.651]
# [ 0.146  0.673  0.105 -1.642 -0.115  2.345 -0.651]
# [ 0.146  0.673  0.105 -1.642 -0.115  2.345 -0.651]
# [ 0.146  0.674  0.104 -1.642 -0.115  2.346 -0.651]
# [ 0.146  0.674  0.104 -1.642 -0.115  2.346 -0.651]
# [ 0.146  0.675  0.104 -1.642 -0.115  2.346 -0.651]
# [ 0.146  0.675  0.104 -1.642 -0.115  2.347 -0.651]
# [ 0.146  0.675  0.104 -1.642 -0.115  2.347 -0.651]
# [ 0.146  0.676  0.104 -1.642 -0.115  2.348 -0.651]
# [ 0.146  0.676  0.104 -1.642 -0.115  2.348 -0.651]
# [ 0.146  0.677  0.104 -1.642 -0.115  2.348 -0.651]
# [ 0.146  0.677  0.104 -1.642 -0.115  2.349 -0.651]
# [ 0.146  0.677  0.104 -1.642 -0.115  2.349 -0.651]
# [ 0.147  0.678  0.104 -1.642 -0.115  2.35  -0.651]
# [ 0.147  0.678  0.104 -1.642 -0.116  2.35  -0.651]
# [ 0.147  0.679  0.104 -1.642 -0.116  2.35  -0.651]
# [ 0.147  0.679  0.104 -1.642 -0.116  2.351 -0.651]
# [ 0.147  0.679  0.104 -1.642 -0.116  2.351 -0.651]
# [ 0.147  0.68   0.104 -1.642 -0.116  2.352 -0.651]
# [ 0.147  0.68   0.104 -1.642 -0.116  2.352 -0.651]
# [ 0.147  0.681  0.104 -1.642 -0.116  2.352 -0.651]
# [ 0.147  0.681  0.104 -1.642 -0.116  2.353 -0.651]
# [ 0.147  0.681  0.104 -1.642 -0.116  2.353 -0.651]
# [ 0.147  0.682  0.104 -1.642 -0.116  2.354 -0.651]
# [ 0.147  0.682  0.104 -1.642 -0.116  2.354 -0.65 ]
# [ 0.147  0.683  0.104 -1.642 -0.116  2.354 -0.65 ]
# [ 0.147  0.683  0.103 -1.642 -0.116  2.355 -0.65 ]
# [ 0.147  0.684  0.103 -1.642 -0.116  2.355 -0.65 ]
# [ 0.147  0.684  0.103 -1.642 -0.116  2.355 -0.65 ]
# [ 0.147  0.684  0.103 -1.642 -0.116  2.356 -0.65 ]
# [ 0.147  0.685  0.103 -1.642 -0.116  2.356 -0.65 ]
# [ 0.147  0.685  0.103 -1.642 -0.116  2.357 -0.65 ]
# [ 0.147  0.686  0.103 -1.642 -0.116  2.357 -0.65 ]
# [ 0.147  0.686  0.103 -1.642 -0.117  2.357 -0.65 ]
# [ 0.147  0.686  0.103 -1.642 -0.117  2.358 -0.65 ]
# [ 0.147  0.687  0.103 -1.642 -0.117  2.358 -0.65 ]
# [ 0.147  0.687  0.103 -1.642 -0.117  2.359 -0.65 ]
# [ 0.147  0.688  0.103 -1.642 -0.117  2.359 -0.65 ]
# [ 0.147  0.688  0.103 -1.642 -0.117  2.359 -0.65 ]
# [ 0.147  0.688  0.103 -1.642 -0.117  2.36  -0.65 ]
# [ 0.147  0.689  0.103 -1.642 -0.117  2.36  -0.65 ]
# [ 0.147  0.689  0.103 -1.642 -0.117  2.361 -0.65 ]
# [ 0.147  0.69   0.103 -1.642 -0.117  2.361 -0.65 ]
# [ 0.147  0.69   0.103 -1.642 -0.117  2.361 -0.65 ]
# [ 0.147  0.691  0.103 -1.642 -0.117  2.362 -0.65 ]
# [ 0.147  0.691  0.103 -1.642 -0.117  2.362 -0.65 ]
# [ 0.147  0.691  0.103 -1.642 -0.117  2.362 -0.65 ]
# [ 0.148  0.692  0.103 -1.642 -0.117  2.363 -0.65 ]
# [ 0.148  0.692  0.103 -1.641 -0.117  2.363 -0.65 ]
# [ 0.148  0.693  0.102 -1.641 -0.117  2.364 -0.65 ]
# [ 0.148  0.693  0.102 -1.641 -0.117  2.364 -0.65 ]
# [ 0.148  0.693  0.102 -1.641 -0.117  2.364 -0.649]
# [ 0.148  0.694  0.102 -1.641 -0.118  2.365 -0.649]
# [ 0.148  0.694  0.102 -1.641 -0.118  2.365 -0.649]
# [ 0.148  0.695  0.102 -1.641 -0.118  2.366 -0.649]
# [ 0.148  0.695  0.102 -1.641 -0.118  2.366 -0.649]
# [ 0.148  0.695  0.102 -1.641 -0.118  2.366 -0.649]
# [ 0.148  0.696  0.102 -1.641 -0.118  2.367 -0.649]
# [ 0.148  0.696  0.102 -1.641 -0.118  2.367 -0.649]
# [ 0.148  0.697  0.102 -1.641 -0.118  2.367 -0.649]
# [ 0.148  0.697  0.102 -1.641 -0.118  2.368 -0.649]
# [ 0.148  0.698  0.102 -1.641 -0.118  2.368 -0.649]
# [ 0.148  0.698  0.102 -1.641 -0.118  2.369 -0.649]
# [ 0.148  0.698  0.102 -1.641 -0.118  2.369 -0.649]
# [ 0.148  0.699  0.102 -1.641 -0.118  2.369 -0.649]
# [ 0.148  0.699  0.102 -1.641 -0.118  2.37  -0.649]
# [ 0.148  0.7    0.102 -1.641 -0.118  2.37  -0.649]
# [ 0.148  0.7    0.102 -1.641 -0.118  2.371 -0.649]
# [ 0.148  0.701  0.102 -1.641 -0.118  2.371 -0.649]
# [ 0.148  0.701  0.102 -1.641 -0.118  2.371 -0.649]
# [ 0.148  0.701  0.102 -1.641 -0.118  2.372 -0.649]
# [ 0.148  0.702  0.102 -1.641 -0.118  2.372 -0.649]
# [ 0.148  0.702  0.101 -1.641 -0.119  2.372 -0.649]
# [ 0.148  0.703  0.101 -1.641 -0.119  2.373 -0.649]
# [ 0.148  0.703  0.101 -1.641 -0.119  2.373 -0.649]
# [ 0.148  0.703  0.101 -1.641 -0.119  2.374 -0.649]
# [ 0.148  0.704  0.101 -1.64  -0.119  2.374 -0.649]
# [ 0.148  0.704  0.101 -1.64  -0.119  2.374 -0.649]
# [ 0.148  0.705  0.101 -1.64  -0.119  2.375 -0.648]
# [ 0.148  0.705  0.101 -1.64  -0.119  2.375 -0.648]
# [ 0.148  0.706  0.101 -1.64  -0.119  2.375 -0.648]
# [ 0.149  0.706  0.101 -1.64  -0.119  2.376 -0.648]
# [ 0.149  0.706  0.101 -1.64  -0.119  2.376 -0.648]
# [ 0.149  0.707  0.101 -1.64  -0.119  2.377 -0.648]
# [ 0.149  0.707  0.101 -1.64  -0.119  2.377 -0.648]
# [ 0.149  0.708  0.101 -1.64  -0.119  2.377 -0.648]
# [ 0.149  0.708  0.101 -1.64  -0.119  2.378 -0.648]
# [ 0.149  0.709  0.101 -1.64  -0.119  2.378 -0.648]
# [ 0.149  0.709  0.101 -1.64  -0.119  2.378 -0.648]
# [ 0.149  0.709  0.101 -1.64  -0.119  2.379 -0.648]
# [ 0.149  0.71   0.101 -1.64  -0.119  2.379 -0.648]
# [ 0.149  0.71   0.101 -1.64  -0.12   2.38  -0.648]
# [ 0.149  0.711  0.101 -1.64  -0.12   2.38  -0.648]
# [ 0.149  0.711  0.101 -1.64  -0.12   2.38  -0.648]
# [ 0.149  0.712  0.1   -1.64  -0.12   2.381 -0.648]
# [ 0.149  0.712  0.1   -1.64  -0.12   2.381 -0.648]
# [ 0.149  0.712  0.1   -1.64  -0.12   2.381 -0.648]
# [ 0.149  0.713  0.1   -1.639 -0.12   2.382 -0.648]
# [ 0.149  0.713  0.1   -1.639 -0.12   2.382 -0.648]
# [ 0.149  0.714  0.1   -1.639 -0.12   2.383 -0.648]
# [ 0.149  0.714  0.1   -1.639 -0.12   2.383 -0.648]
# [ 0.149  0.715  0.1   -1.639 -0.12   2.383 -0.648]
# [ 0.149  0.715  0.1   -1.639 -0.12   2.384 -0.648]
# [ 0.149  0.715  0.1   -1.639 -0.12   2.384 -0.648]
# [ 0.149  0.716  0.1   -1.639 -0.12   2.384 -0.648]
# [ 0.149  0.716  0.1   -1.639 -0.12   2.385 -0.648]
# [ 0.149  0.717  0.1   -1.639 -0.12   2.385 -0.647]
# [ 0.149  0.717  0.1   -1.639 -0.12   2.386 -0.647]
# [ 0.149  0.718  0.1   -1.639 -0.12   2.386 -0.647]
# [ 0.149  0.718  0.1   -1.639 -0.12   2.386 -0.647]
# [ 0.149  0.718  0.1   -1.639 -0.12   2.387 -0.647]
# [ 0.149  0.719  0.1   -1.639 -0.121  2.387 -0.647]
# [ 0.149  0.719  0.1   -1.639 -0.121  2.387 -0.647]
# [ 0.149  0.72   0.1   -1.639 -0.121  2.388 -0.647]
# [ 0.15   0.72   0.1   -1.639 -0.121  2.388 -0.647]
# [ 0.15   0.721  0.1   -1.638 -0.121  2.389 -0.647]
# [ 0.15   0.721  0.099 -1.638 -0.121  2.389 -0.647]
# [ 0.15   0.721  0.099 -1.638 -0.121  2.389 -0.647]
# [ 0.15   0.722  0.099 -1.638 -0.121  2.39  -0.647]
# [ 0.15   0.722  0.099 -1.638 -0.121  2.39  -0.647]
# [ 0.15   0.723  0.099 -1.638 -0.121  2.39  -0.647]
# [ 0.15   0.723  0.099 -1.638 -0.121  2.391 -0.647]
# [ 0.15   0.724  0.099 -1.638 -0.121  2.391 -0.647]
# [ 0.15   0.724  0.099 -1.638 -0.121  2.392 -0.647]
# [ 0.15   0.724  0.099 -1.638 -0.121  2.392 -0.647]
# [ 0.15   0.725  0.099 -1.638 -0.121  2.392 -0.647]
# [ 0.15   0.725  0.099 -1.638 -0.121  2.393 -0.647]
# [ 0.15   0.726  0.099 -1.638 -0.121  2.393 -0.647]
# [ 0.15   0.726  0.099 -1.638 -0.121  2.393 -0.647]
# [ 0.15   0.727  0.099 -1.638 -0.121  2.394 -0.647]
# [ 0.15   0.727  0.099 -1.637 -0.121  2.394 -0.647]
# [ 0.15   0.728  0.099 -1.637 -0.122  2.394 -0.647]
# [ 0.15   0.728  0.099 -1.637 -0.122  2.395 -0.647]
# [ 0.15   0.728  0.099 -1.637 -0.122  2.395 -0.647]
# [ 0.15   0.729  0.099 -1.637 -0.122  2.396 -0.646]
# [ 0.15   0.729  0.099 -1.637 -0.122  2.396 -0.646]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.15   0.729  0.099 -1.637 -0.122  2.396 -0.646]
# [ 0.15   0.729  0.099 -1.637 -0.122  2.396 -0.646]
# [ 0.15   0.728  0.099 -1.637 -0.122  2.395 -0.647]
# [ 0.15   0.728  0.099 -1.637 -0.122  2.395 -0.647]
# [ 0.15   0.728  0.099 -1.637 -0.122  2.394 -0.647]
# [ 0.15   0.727  0.099 -1.637 -0.121  2.394 -0.647]
# [ 0.15   0.727  0.099 -1.638 -0.121  2.394 -0.647]
# [ 0.15   0.726  0.099 -1.638 -0.121  2.393 -0.647]
# [ 0.15   0.726  0.099 -1.638 -0.121  2.393 -0.647]
# [ 0.15   0.725  0.099 -1.638 -0.121  2.393 -0.647]
# [ 0.15   0.725  0.099 -1.638 -0.121  2.392 -0.647]
# [ 0.15   0.724  0.099 -1.638 -0.121  2.392 -0.647]
# [ 0.15   0.724  0.099 -1.638 -0.121  2.392 -0.647]
# [ 0.15   0.724  0.099 -1.638 -0.121  2.391 -0.647]
# [ 0.15   0.723  0.099 -1.638 -0.121  2.391 -0.647]
# [ 0.15   0.723  0.099 -1.638 -0.121  2.39  -0.647]
# [ 0.15   0.722  0.099 -1.638 -0.121  2.39  -0.647]
# [ 0.15   0.722  0.099 -1.638 -0.121  2.39  -0.647]
# [ 0.15   0.721  0.099 -1.638 -0.121  2.389 -0.647]
# [ 0.15   0.721  0.099 -1.638 -0.121  2.389 -0.647]
# [ 0.15   0.721  0.1   -1.638 -0.121  2.389 -0.647]
# [ 0.15   0.72   0.1   -1.639 -0.121  2.388 -0.647]
# [ 0.149  0.72   0.1   -1.639 -0.121  2.388 -0.647]
# [ 0.149  0.719  0.1   -1.639 -0.121  2.387 -0.647]
# [ 0.149  0.719  0.1   -1.639 -0.121  2.387 -0.647]
# [ 0.149  0.718  0.1   -1.639 -0.12   2.387 -0.647]
# [ 0.149  0.718  0.1   -1.639 -0.12   2.386 -0.647]
# [ 0.149  0.718  0.1   -1.639 -0.12   2.386 -0.647]
# [ 0.149  0.717  0.1   -1.639 -0.12   2.386 -0.647]
# [ 0.149  0.717  0.1   -1.639 -0.12   2.385 -0.647]
# [ 0.149  0.716  0.1   -1.639 -0.12   2.385 -0.648]
# [ 0.149  0.716  0.1   -1.639 -0.12   2.384 -0.648]
# [ 0.149  0.715  0.1   -1.639 -0.12   2.384 -0.648]
# [ 0.149  0.715  0.1   -1.639 -0.12   2.384 -0.648]
# [ 0.149  0.715  0.1   -1.639 -0.12   2.383 -0.648]
# [ 0.149  0.714  0.1   -1.639 -0.12   2.383 -0.648]
# [ 0.149  0.714  0.1   -1.639 -0.12   2.383 -0.648]
# [ 0.149  0.713  0.1   -1.639 -0.12   2.382 -0.648]
# [ 0.149  0.713  0.1   -1.639 -0.12   2.382 -0.648]
# [ 0.149  0.712  0.1   -1.64  -0.12   2.381 -0.648]
# [ 0.149  0.712  0.1   -1.64  -0.12   2.381 -0.648]
# [ 0.149  0.712  0.1   -1.64  -0.12   2.381 -0.648]
# [ 0.149  0.711  0.101 -1.64  -0.12   2.38  -0.648]
# [ 0.149  0.711  0.101 -1.64  -0.12   2.38  -0.648]
# [ 0.149  0.71   0.101 -1.64  -0.12   2.38  -0.648]
# [ 0.149  0.71   0.101 -1.64  -0.119  2.379 -0.648]
# [ 0.149  0.709  0.101 -1.64  -0.119  2.379 -0.648]
# [ 0.149  0.709  0.101 -1.64  -0.119  2.378 -0.648]
# [ 0.149  0.709  0.101 -1.64  -0.119  2.378 -0.648]
# [ 0.149  0.708  0.101 -1.64  -0.119  2.378 -0.648]
# [ 0.149  0.708  0.101 -1.64  -0.119  2.377 -0.648]
# [ 0.149  0.707  0.101 -1.64  -0.119  2.377 -0.648]
# [ 0.149  0.707  0.101 -1.64  -0.119  2.377 -0.648]
# [ 0.149  0.706  0.101 -1.64  -0.119  2.376 -0.648]
# [ 0.149  0.706  0.101 -1.64  -0.119  2.376 -0.648]
# [ 0.148  0.706  0.101 -1.64  -0.119  2.375 -0.648]
# [ 0.148  0.705  0.101 -1.64  -0.119  2.375 -0.648]
# [ 0.148  0.705  0.101 -1.64  -0.119  2.375 -0.648]
# [ 0.148  0.704  0.101 -1.64  -0.119  2.374 -0.649]
# [ 0.148  0.704  0.101 -1.64  -0.119  2.374 -0.649]
# [ 0.148  0.703  0.101 -1.641 -0.119  2.374 -0.649]
# [ 0.148  0.703  0.101 -1.641 -0.119  2.373 -0.649]
# [ 0.148  0.703  0.101 -1.641 -0.119  2.373 -0.649]
# [ 0.148  0.702  0.101 -1.641 -0.119  2.372 -0.649]
# [ 0.148  0.702  0.102 -1.641 -0.118  2.372 -0.649]
# [ 0.148  0.701  0.102 -1.641 -0.118  2.372 -0.649]
# [ 0.148  0.701  0.102 -1.641 -0.118  2.371 -0.649]
# [ 0.148  0.701  0.102 -1.641 -0.118  2.371 -0.649]
# [ 0.148  0.7    0.102 -1.641 -0.118  2.371 -0.649]
# [ 0.148  0.7    0.102 -1.641 -0.118  2.37  -0.649]
# [ 0.148  0.699  0.102 -1.641 -0.118  2.37  -0.649]
# [ 0.148  0.699  0.102 -1.641 -0.118  2.369 -0.649]
# [ 0.148  0.698  0.102 -1.641 -0.118  2.369 -0.649]
# [ 0.148  0.698  0.102 -1.641 -0.118  2.369 -0.649]
# [ 0.148  0.698  0.102 -1.641 -0.118  2.368 -0.649]
# [ 0.148  0.697  0.102 -1.641 -0.118  2.368 -0.649]
# [ 0.148  0.697  0.102 -1.641 -0.118  2.367 -0.649]
# [ 0.148  0.696  0.102 -1.641 -0.118  2.367 -0.649]
# [ 0.148  0.696  0.102 -1.641 -0.118  2.367 -0.649]
# [ 0.148  0.695  0.102 -1.641 -0.118  2.366 -0.649]
# [ 0.148  0.695  0.102 -1.641 -0.118  2.366 -0.649]
# [ 0.148  0.695  0.102 -1.641 -0.118  2.366 -0.649]
# [ 0.148  0.694  0.102 -1.641 -0.118  2.365 -0.649]
# [ 0.148  0.694  0.102 -1.641 -0.118  2.365 -0.649]
# [ 0.148  0.693  0.102 -1.641 -0.117  2.364 -0.649]
# [ 0.148  0.693  0.102 -1.641 -0.117  2.364 -0.65 ]
# [ 0.148  0.693  0.102 -1.641 -0.117  2.364 -0.65 ]
# [ 0.148  0.692  0.103 -1.641 -0.117  2.363 -0.65 ]
# [ 0.148  0.692  0.103 -1.642 -0.117  2.363 -0.65 ]
# [ 0.147  0.691  0.103 -1.642 -0.117  2.362 -0.65 ]
# [ 0.147  0.691  0.103 -1.642 -0.117  2.362 -0.65 ]
# [ 0.147  0.691  0.103 -1.642 -0.117  2.362 -0.65 ]
# [ 0.147  0.69   0.103 -1.642 -0.117  2.361 -0.65 ]
# [ 0.147  0.69   0.103 -1.642 -0.117  2.361 -0.65 ]
# [ 0.147  0.689  0.103 -1.642 -0.117  2.361 -0.65 ]
# [ 0.147  0.689  0.103 -1.642 -0.117  2.36  -0.65 ]
# [ 0.147  0.688  0.103 -1.642 -0.117  2.36  -0.65 ]
# [ 0.147  0.688  0.103 -1.642 -0.117  2.359 -0.65 ]
# [ 0.147  0.688  0.103 -1.642 -0.117  2.359 -0.65 ]
# [ 0.147  0.687  0.103 -1.642 -0.117  2.359 -0.65 ]
# [ 0.147  0.687  0.103 -1.642 -0.117  2.358 -0.65 ]
# [ 0.147  0.686  0.103 -1.642 -0.117  2.358 -0.65 ]
# [ 0.147  0.686  0.103 -1.642 -0.117  2.357 -0.65 ]
# [ 0.147  0.686  0.103 -1.642 -0.116  2.357 -0.65 ]
# [ 0.147  0.685  0.103 -1.642 -0.116  2.357 -0.65 ]
# [ 0.147  0.685  0.103 -1.642 -0.116  2.356 -0.65 ]
# [ 0.147  0.684  0.103 -1.642 -0.116  2.356 -0.65 ]
# [ 0.147  0.684  0.103 -1.642 -0.116  2.355 -0.65 ]
# [ 0.147  0.684  0.103 -1.642 -0.116  2.355 -0.65 ]
# [ 0.147  0.683  0.103 -1.642 -0.116  2.355 -0.65 ]
# [ 0.147  0.683  0.104 -1.642 -0.116  2.354 -0.65 ]
# [ 0.147  0.682  0.104 -1.642 -0.116  2.354 -0.65 ]
# [ 0.147  0.682  0.104 -1.642 -0.116  2.354 -0.651]
# [ 0.147  0.681  0.104 -1.642 -0.116  2.353 -0.651]
# [ 0.147  0.681  0.104 -1.642 -0.116  2.353 -0.651]
# [ 0.147  0.681  0.104 -1.642 -0.116  2.352 -0.651]
# [ 0.147  0.68   0.104 -1.642 -0.116  2.352 -0.651]
# [ 0.147  0.68   0.104 -1.642 -0.116  2.352 -0.651]
# [ 0.147  0.679  0.104 -1.642 -0.116  2.351 -0.651]
# [ 0.147  0.679  0.104 -1.642 -0.116  2.351 -0.651]
# [ 0.147  0.679  0.104 -1.642 -0.116  2.35  -0.651]
# [ 0.147  0.678  0.104 -1.642 -0.116  2.35  -0.651]
# [ 0.147  0.678  0.104 -1.642 -0.115  2.35  -0.651]
# [ 0.146  0.677  0.104 -1.642 -0.115  2.349 -0.651]
# [ 0.146  0.677  0.104 -1.642 -0.115  2.349 -0.651]
# [ 0.146  0.677  0.104 -1.642 -0.115  2.348 -0.651]
# [ 0.146  0.676  0.104 -1.642 -0.115  2.348 -0.651]
# [ 0.146  0.676  0.104 -1.642 -0.115  2.348 -0.651]
# [ 0.146  0.675  0.104 -1.642 -0.115  2.347 -0.651]
# [ 0.146  0.675  0.104 -1.642 -0.115  2.347 -0.651]
# [ 0.146  0.675  0.104 -1.642 -0.115  2.346 -0.651]
# [ 0.146  0.674  0.104 -1.642 -0.115  2.346 -0.651]
# [ 0.146  0.674  0.104 -1.642 -0.115  2.346 -0.651]
# [ 0.146  0.673  0.105 -1.642 -0.115  2.345 -0.651]
# [ 0.146  0.673  0.105 -1.642 -0.115  2.345 -0.651]
# [ 0.146  0.673  0.105 -1.642 -0.115  2.344 -0.651]
# [ 0.146  0.672  0.105 -1.642 -0.115  2.344 -0.651]
# [ 0.146  0.672  0.105 -1.642 -0.115  2.344 -0.651]
# [ 0.146  0.671  0.105 -1.642 -0.115  2.343 -0.651]
# [ 0.146  0.671  0.105 -1.642 -0.115  2.343 -0.652]
# [ 0.146  0.671  0.105 -1.642 -0.115  2.342 -0.652]
# [ 0.146  0.67   0.105 -1.642 -0.115  2.342 -0.652]
# [ 0.146  0.67   0.105 -1.642 -0.114  2.342 -0.652]
# [ 0.146  0.669  0.105 -1.642 -0.114  2.341 -0.652]
# [ 0.146  0.669  0.105 -1.642 -0.114  2.341 -0.652]
# [ 0.146  0.669  0.105 -1.642 -0.114  2.34  -0.652]
# [ 0.146  0.668  0.105 -1.642 -0.114  2.34  -0.652]
# [ 0.146  0.668  0.105 -1.642 -0.114  2.34  -0.652]
# [ 0.146  0.667  0.105 -1.642 -0.114  2.339 -0.652]
# [ 0.146  0.667  0.105 -1.642 -0.114  2.339 -0.652]
# [ 0.146  0.667  0.105 -1.642 -0.114  2.338 -0.652]
# [ 0.146  0.666  0.105 -1.642 -0.114  2.338 -0.652]
# [ 0.146  0.666  0.105 -1.642 -0.114  2.338 -0.652]
# [ 0.146  0.665  0.105 -1.642 -0.114  2.337 -0.652]
# [ 0.146  0.665  0.105 -1.642 -0.114  2.337 -0.652]
# [ 0.146  0.665  0.105 -1.642 -0.114  2.336 -0.652]
# [ 0.146  0.664  0.105 -1.642 -0.114  2.336 -0.652]
# [ 0.146  0.664  0.106 -1.642 -0.114  2.336 -0.652]
# [ 0.146  0.663  0.106 -1.642 -0.114  2.335 -0.652]
# [ 0.146  0.663  0.106 -1.642 -0.114  2.335 -0.652]
# [ 0.145  0.663  0.106 -1.642 -0.114  2.334 -0.652]
# [ 0.145  0.662  0.106 -1.642 -0.113  2.334 -0.652]
# [ 0.145  0.662  0.106 -1.642 -0.113  2.334 -0.652]
# [ 0.145  0.661  0.106 -1.642 -0.113  2.333 -0.652]
# [ 0.145  0.661  0.106 -1.642 -0.113  2.333 -0.652]
# [ 0.145  0.661  0.106 -1.642 -0.113  2.332 -0.653]
# [ 0.145  0.66   0.106 -1.642 -0.113  2.332 -0.653]
# [ 0.145  0.66   0.106 -1.642 -0.113  2.332 -0.653]
# [ 0.145  0.659  0.106 -1.642 -0.113  2.331 -0.653]
# [ 0.145  0.659  0.106 -1.642 -0.113  2.331 -0.653]
# [ 0.145  0.659  0.106 -1.642 -0.113  2.33  -0.653]
# [ 0.145  0.658  0.106 -1.642 -0.113  2.33  -0.653]
# [ 0.145  0.658  0.106 -1.642 -0.113  2.33  -0.653]
# [ 0.145  0.657  0.106 -1.642 -0.113  2.329 -0.653]
# [ 0.145  0.657  0.106 -1.642 -0.113  2.329 -0.653]
# [ 0.145  0.657  0.106 -1.642 -0.113  2.328 -0.653]
# [ 0.145  0.656  0.106 -1.642 -0.113  2.328 -0.653]
# [ 0.145  0.656  0.106 -1.642 -0.113  2.328 -0.653]
# [ 0.145  0.656  0.106 -1.642 -0.113  2.327 -0.653]
# [ 0.145  0.655  0.106 -1.642 -0.113  2.327 -0.653]
# [ 0.145  0.655  0.106 -1.642 -0.112  2.326 -0.653]
# [ 0.145  0.654  0.107 -1.642 -0.112  2.326 -0.653]
# [ 0.145  0.654  0.107 -1.642 -0.112  2.326 -0.653]
# [ 0.145  0.654  0.107 -1.642 -0.112  2.325 -0.653]
# [ 0.145  0.653  0.107 -1.642 -0.112  2.325 -0.653]
# [ 0.145  0.653  0.107 -1.642 -0.112  2.324 -0.653]
# [ 0.145  0.652  0.107 -1.642 -0.112  2.324 -0.653]
# [ 0.145  0.652  0.107 -1.642 -0.112  2.324 -0.653]
# [ 0.145  0.652  0.107 -1.642 -0.112  2.323 -0.653]
# [ 0.145  0.651  0.107 -1.642 -0.112  2.323 -0.653]
# [ 0.145  0.651  0.107 -1.642 -0.112  2.322 -0.653]
# [ 0.145  0.65   0.107 -1.642 -0.112  2.322 -0.653]
# [ 0.145  0.65   0.107 -1.642 -0.112  2.322 -0.654]
# [ 0.145  0.65   0.107 -1.642 -0.112  2.321 -0.654]
# [ 0.145  0.649  0.107 -1.642 -0.112  2.321 -0.654]
# [ 0.145  0.649  0.107 -1.642 -0.112  2.32  -0.654]
# [ 0.145  0.649  0.107 -1.642 -0.112  2.32  -0.654]
# [ 0.144  0.648  0.107 -1.642 -0.112  2.319 -0.654]
# [ 0.144  0.648  0.107 -1.642 -0.112  2.319 -0.654]
# [ 0.144  0.647  0.107 -1.642 -0.111  2.319 -0.654]
# [ 0.144  0.647  0.107 -1.642 -0.111  2.318 -0.654]
# [ 0.144  0.647  0.107 -1.642 -0.111  2.318 -0.654]
# [ 0.144  0.646  0.107 -1.642 -0.111  2.317 -0.654]
# [ 0.144  0.646  0.107 -1.642 -0.111  2.317 -0.654]
# [ 0.144  0.645  0.107 -1.642 -0.111  2.317 -0.654]
# [ 0.144  0.645  0.107 -1.641 -0.111  2.316 -0.654]
# [ 0.144  0.645  0.108 -1.641 -0.111  2.316 -0.654]
# [ 0.144  0.644  0.108 -1.641 -0.111  2.315 -0.654]
# [ 0.144  0.644  0.108 -1.641 -0.111  2.315 -0.654]
# [ 0.144  0.644  0.108 -1.641 -0.111  2.315 -0.654]
# [ 0.144  0.643  0.108 -1.641 -0.111  2.314 -0.654]
# [ 0.144  0.643  0.108 -1.641 -0.111  2.314 -0.654]
# [ 0.144  0.642  0.108 -1.641 -0.111  2.313 -0.654]
# [ 0.144  0.642  0.108 -1.641 -0.111  2.313 -0.654]
# [ 0.144  0.642  0.108 -1.641 -0.111  2.313 -0.654]
# [ 0.144  0.641  0.108 -1.641 -0.111  2.312 -0.654]
# [ 0.144  0.641  0.108 -1.641 -0.111  2.312 -0.654]
# [ 0.144  0.64   0.108 -1.641 -0.11   2.311 -0.654]
# [ 0.144  0.64   0.108 -1.641 -0.11   2.311 -0.655]
# [ 0.144  0.64   0.108 -1.641 -0.11   2.31  -0.655]
# [ 0.144  0.639  0.108 -1.641 -0.11   2.31  -0.655]
# [ 0.144  0.639  0.108 -1.641 -0.11   2.31  -0.655]
# [ 0.144  0.639  0.108 -1.641 -0.11   2.309 -0.655]
# [ 0.144  0.638  0.108 -1.641 -0.11   2.309 -0.655]
# [ 0.144  0.638  0.108 -1.641 -0.11   2.308 -0.655]
# [ 0.144  0.637  0.108 -1.641 -0.11   2.308 -0.655]
# [ 0.144  0.637  0.108 -1.641 -0.11   2.308 -0.655]
# [ 0.144  0.637  0.108 -1.641 -0.11   2.307 -0.655]
# [ 0.144  0.636  0.108 -1.641 -0.11   2.307 -0.655]
# [ 0.144  0.636  0.108 -1.641 -0.11   2.306 -0.655]
# [ 0.144  0.636  0.108 -1.641 -0.11   2.306 -0.655]
# [ 0.144  0.635  0.109 -1.641 -0.11   2.305 -0.655]
# [ 0.144  0.635  0.109 -1.641 -0.11   2.305 -0.655]
# [ 0.144  0.634  0.109 -1.64  -0.11   2.305 -0.655]
# [ 0.144  0.634  0.109 -1.64  -0.11   2.304 -0.655]
# [ 0.144  0.634  0.109 -1.64  -0.11   2.304 -0.655]
# [ 0.144  0.633  0.109 -1.64  -0.109  2.303 -0.655]
# [ 0.143  0.633  0.109 -1.64  -0.109  2.303 -0.655]
# [ 0.143  0.633  0.109 -1.64  -0.109  2.303 -0.655]
# [ 0.143  0.632  0.109 -1.64  -0.109  2.302 -0.655]
# [ 0.143  0.632  0.109 -1.64  -0.109  2.302 -0.655]
# [ 0.143  0.631  0.109 -1.64  -0.109  2.301 -0.655]
# [ 0.143  0.631  0.109 -1.64  -0.109  2.301 -0.655]
# [ 0.143  0.631  0.109 -1.64  -0.109  2.3   -0.655]
# [ 0.143  0.63   0.109 -1.64  -0.109  2.3   -0.656]
# [ 0.143  0.63   0.109 -1.64  -0.109  2.3   -0.656]
# [ 0.143  0.63   0.109 -1.64  -0.109  2.299 -0.656]
# [ 0.143  0.629  0.109 -1.64  -0.109  2.299 -0.656]
# [ 0.143  0.629  0.109 -1.64  -0.109  2.298 -0.656]
# [ 0.143  0.628  0.109 -1.64  -0.109  2.298 -0.656]
# [ 0.143  0.628  0.109 -1.64  -0.109  2.298 -0.656]
# [ 0.143  0.628  0.109 -1.64  -0.109  2.297 -0.656]
# [ 0.143  0.627  0.109 -1.64  -0.109  2.297 -0.656]
# [ 0.143  0.627  0.109 -1.64  -0.109  2.296 -0.656]
# [ 0.143  0.627  0.109 -1.639 -0.109  2.296 -0.656]
# [ 0.143  0.626  0.109 -1.639 -0.108  2.295 -0.656]
# [ 0.143  0.626  0.109 -1.639 -0.108  2.295 -0.656]
# [ 0.143  0.626  0.11  -1.639 -0.108  2.295 -0.656]
# [ 0.143  0.625  0.11  -1.639 -0.108  2.294 -0.656]
# [ 0.143  0.625  0.11  -1.639 -0.108  2.294 -0.656]
# [ 0.143  0.624  0.11  -1.639 -0.108  2.293 -0.656]
# [ 0.143  0.624  0.11  -1.639 -0.108  2.293 -0.656]
# [ 0.143  0.624  0.11  -1.639 -0.108  2.292 -0.656]
# [ 0.143  0.623  0.11  -1.639 -0.108  2.292 -0.656]
# [ 0.143  0.623  0.11  -1.639 -0.108  2.292 -0.656]
# [ 0.143  0.623  0.11  -1.639 -0.108  2.291 -0.656]
# [ 0.143  0.622  0.11  -1.639 -0.108  2.291 -0.656]
# [ 0.143  0.622  0.11  -1.639 -0.108  2.29  -0.656]
# [ 0.143  0.622  0.11  -1.639 -0.108  2.29  -0.656]
# [ 0.143  0.621  0.11  -1.639 -0.108  2.29  -0.656]
# [ 0.143  0.621  0.11  -1.639 -0.108  2.289 -0.656]
# [ 0.143  0.62   0.11  -1.639 -0.108  2.289 -0.657]
# [ 0.143  0.62   0.11  -1.638 -0.108  2.288 -0.657]
# [ 0.143  0.62   0.11  -1.638 -0.108  2.288 -0.657]
# [ 0.143  0.619  0.11  -1.638 -0.107  2.287 -0.657]
# [ 0.143  0.619  0.11  -1.638 -0.107  2.287 -0.657]
# [ 0.143  0.619  0.11  -1.638 -0.107  2.287 -0.657]
# [ 0.143  0.618  0.11  -1.638 -0.107  2.286 -0.657]
# [ 0.143  0.618  0.11  -1.638 -0.107  2.286 -0.657]
# [ 0.142  0.618  0.11  -1.638 -0.107  2.285 -0.657]
# [ 0.142  0.617  0.11  -1.638 -0.107  2.285 -0.657]
# [ 0.142  0.617  0.11  -1.638 -0.107  2.284 -0.657]
# [ 0.142  0.616  0.11  -1.638 -0.107  2.284 -0.657]
# [ 0.142  0.616  0.111 -1.638 -0.107  2.284 -0.657]
# [ 0.142  0.616  0.111 -1.638 -0.107  2.283 -0.657]
# [ 0.142  0.615  0.111 -1.638 -0.107  2.283 -0.657]
# [ 0.142  0.615  0.111 -1.638 -0.107  2.282 -0.657]
# [ 0.142  0.615  0.111 -1.637 -0.107  2.282 -0.657]
# [ 0.142  0.614  0.111 -1.637 -0.107  2.281 -0.657]
# [ 0.142  0.614  0.111 -1.637 -0.107  2.281 -0.657]
# [ 0.142  0.614  0.111 -1.637 -0.107  2.281 -0.657]
# [ 0.142  0.613  0.111 -1.637 -0.107  2.28  -0.657]
# [ 0.142  0.613  0.111 -1.637 -0.107  2.28  -0.657]
# [ 0.142  0.612  0.111 -1.637 -0.106  2.279 -0.657]
# [ 0.142  0.612  0.111 -1.637 -0.106  2.279 -0.657]
# [ 0.142  0.612  0.111 -1.637 -0.106  2.278 -0.657]
# [ 0.142  0.611  0.111 -1.637 -0.106  2.278 -0.657]
# [ 0.142  0.611  0.111 -1.637 -0.106  2.278 -0.658]
# [ 0.142  0.611  0.111 -1.637 -0.106  2.277 -0.658]
# [ 0.142  0.61   0.111 -1.637 -0.106  2.277 -0.658]
# [ 0.142  0.61   0.111 -1.637 -0.106  2.276 -0.658]
# [ 0.142  0.61   0.111 -1.636 -0.106  2.276 -0.658]
# [ 0.142  0.609  0.111 -1.636 -0.106  2.275 -0.658]
# [ 0.142  0.609  0.111 -1.636 -0.106  2.275 -0.658]
# [ 0.142  0.609  0.111 -1.636 -0.106  2.275 -0.658]
# [ 0.142  0.608  0.111 -1.636 -0.106  2.274 -0.658]
# [ 0.142  0.608  0.111 -1.636 -0.106  2.274 -0.658]
# [ 0.142  0.607  0.111 -1.636 -0.106  2.273 -0.658]
# [ 0.142  0.607  0.111 -1.636 -0.106  2.273 -0.658]
# [ 0.142  0.607  0.111 -1.636 -0.106  2.272 -0.658]
# [ 0.142  0.606  0.111 -1.636 -0.106  2.272 -0.658]
# [ 0.142  0.606  0.112 -1.636 -0.106  2.272 -0.658]
# [ 0.142  0.606  0.112 -1.636 -0.105  2.271 -0.658]
# [ 0.142  0.605  0.112 -1.636 -0.105  2.271 -0.658]
# [ 0.142  0.605  0.112 -1.635 -0.105  2.27  -0.658]
# [ 0.142  0.605  0.112 -1.635 -0.105  2.27  -0.658]
# [ 0.142  0.604  0.112 -1.635 -0.105  2.269 -0.658]
# [ 0.142  0.604  0.112 -1.635 -0.105  2.269 -0.658]
# [ 0.142  0.604  0.112 -1.635 -0.105  2.269 -0.658]
# [ 0.142  0.603  0.112 -1.635 -0.105  2.268 -0.658]
# [ 0.142  0.603  0.112 -1.635 -0.105  2.268 -0.658]
# [ 0.142  0.603  0.112 -1.635 -0.105  2.267 -0.658]
# [ 0.142  0.602  0.112 -1.635 -0.105  2.267 -0.658]
# [ 0.142  0.602  0.112 -1.635 -0.105  2.266 -0.659]
# [ 0.141  0.602  0.112 -1.635 -0.105  2.266 -0.659]
# [ 0.141  0.601  0.112 -1.635 -0.105  2.266 -0.659]
# [ 0.141  0.601  0.112 -1.634 -0.105  2.265 -0.659]
# [ 0.141  0.6    0.112 -1.634 -0.105  2.265 -0.659]
# [ 0.141  0.6    0.112 -1.634 -0.105  2.264 -0.659]
# [ 0.141  0.6    0.112 -1.634 -0.105  2.264 -0.659]
# [ 0.141  0.599  0.112 -1.634 -0.105  2.263 -0.659]
# [ 0.141  0.599  0.112 -1.634 -0.104  2.263 -0.659]
# [ 0.141  0.599  0.112 -1.634 -0.104  2.262 -0.659]
# [ 0.141  0.598  0.112 -1.634 -0.104  2.262 -0.659]
# [ 0.141  0.598  0.112 -1.634 -0.104  2.262 -0.659]
# [ 0.141  0.598  0.112 -1.634 -0.104  2.261 -0.659]
# [ 0.141  0.597  0.112 -1.634 -0.104  2.261 -0.659]
# [ 0.141  0.597  0.112 -1.633 -0.104  2.26  -0.659]
# [ 0.141  0.597  0.112 -1.633 -0.104  2.26  -0.659]
# [ 0.141  0.596  0.113 -1.633 -0.104  2.259 -0.659]
# [ 0.141  0.596  0.113 -1.633 -0.104  2.259 -0.659]
# [ 0.141  0.596  0.113 -1.633 -0.104  2.259 -0.659]
# [ 0.141  0.595  0.113 -1.633 -0.104  2.258 -0.659]
# [ 0.141  0.595  0.113 -1.633 -0.104  2.258 -0.659]
# [ 0.141  0.595  0.113 -1.633 -0.104  2.257 -0.659]
# [ 0.141  0.594  0.113 -1.633 -0.104  2.257 -0.659]
# [ 0.141  0.594  0.113 -1.633 -0.104  2.256 -0.659]
# [ 0.141  0.594  0.113 -1.632 -0.104  2.256 -0.659]
# [ 0.141  0.593  0.113 -1.632 -0.104  2.255 -0.659]
# [ 0.141  0.593  0.113 -1.632 -0.104  2.255 -0.66 ]
# [ 0.141  0.593  0.113 -1.632 -0.103  2.255 -0.66 ]
# [ 0.141  0.592  0.113 -1.632 -0.103  2.254 -0.66 ]
# [ 0.141  0.592  0.113 -1.632 -0.103  2.254 -0.66 ]
# [ 0.141  0.592  0.113 -1.632 -0.103  2.253 -0.66 ]
# [ 0.141  0.591  0.113 -1.632 -0.103  2.253 -0.66 ]
# [ 0.141  0.591  0.113 -1.632 -0.103  2.252 -0.66 ]
# [ 0.141  0.591  0.113 -1.632 -0.103  2.252 -0.66 ]
# [ 0.141  0.59   0.113 -1.631 -0.103  2.252 -0.66 ]
# [ 0.141  0.59   0.113 -1.631 -0.103  2.251 -0.66 ]
# [ 0.141  0.59   0.113 -1.631 -0.103  2.251 -0.66 ]
# [ 0.141  0.589  0.113 -1.631 -0.103  2.25  -0.66 ]
# [ 0.141  0.589  0.113 -1.631 -0.103  2.25  -0.66 ]
# [ 0.141  0.589  0.113 -1.631 -0.103  2.249 -0.66 ]
# [ 0.141  0.588  0.113 -1.631 -0.103  2.249 -0.66 ]
# [ 0.141  0.588  0.113 -1.631 -0.103  2.248 -0.66 ]
# [ 0.141  0.587  0.113 -1.631 -0.103  2.248 -0.66 ]
# [ 0.141  0.587  0.113 -1.631 -0.103  2.248 -0.66 ]
# [ 0.141  0.587  0.114 -1.63  -0.103  2.247 -0.66 ]
# [ 0.141  0.586  0.114 -1.63  -0.103  2.247 -0.66 ]
# [ 0.141  0.586  0.114 -1.63  -0.103  2.246 -0.66 ]
# [ 0.141  0.586  0.114 -1.63  -0.102  2.246 -0.66 ]
# [ 0.141  0.585  0.114 -1.63  -0.102  2.245 -0.66 ]
# [ 0.14   0.585  0.114 -1.63  -0.102  2.245 -0.66 ]
# [ 0.14   0.585  0.114 -1.63  -0.102  2.244 -0.66 ]
# [ 0.14   0.584  0.114 -1.63  -0.102  2.244 -0.66 ]
# [ 0.14   0.584  0.114 -1.63  -0.102  2.244 -0.661]
# [ 0.14   0.584  0.114 -1.629 -0.102  2.243 -0.661]
# [ 0.14   0.583  0.114 -1.629 -0.102  2.243 -0.661]
# [ 0.14   0.583  0.114 -1.629 -0.102  2.242 -0.661]
# [ 0.14   0.583  0.114 -1.629 -0.102  2.242 -0.661]
# [ 0.14   0.582  0.114 -1.629 -0.102  2.241 -0.661]
# [ 0.14   0.582  0.114 -1.629 -0.102  2.241 -0.661]
# [ 0.14   0.582  0.114 -1.629 -0.102  2.24  -0.661]
# [ 0.14   0.581  0.114 -1.629 -0.102  2.24  -0.661]
# [ 0.14   0.581  0.114 -1.629 -0.102  2.24  -0.661]
# [ 0.14   0.581  0.114 -1.628 -0.102  2.239 -0.661]
# [ 0.14   0.581  0.114 -1.628 -0.102  2.239 -0.661]
# [ 0.14   0.58   0.114 -1.628 -0.102  2.238 -0.661]
# [ 0.14   0.58   0.114 -1.628 -0.102  2.238 -0.661]
# [ 0.14   0.58   0.114 -1.628 -0.101  2.237 -0.661]
# [ 0.14   0.579  0.114 -1.628 -0.101  2.237 -0.661]
# [ 0.14   0.579  0.114 -1.628 -0.101  2.236 -0.661]
# [ 0.14   0.579  0.114 -1.628 -0.101  2.236 -0.661]
# [ 0.14   0.578  0.114 -1.627 -0.101  2.236 -0.661]
# [ 0.14   0.578  0.114 -1.627 -0.101  2.235 -0.661]
# [ 0.14   0.578  0.114 -1.627 -0.101  2.235 -0.661]
# [ 0.14   0.577  0.114 -1.627 -0.101  2.234 -0.661]
# [ 0.14   0.577  0.115 -1.627 -0.101  2.234 -0.661]
# [ 0.14   0.577  0.115 -1.627 -0.101  2.233 -0.661]
# [ 0.14   0.576  0.115 -1.627 -0.101  2.233 -0.661]
# [ 0.14   0.576  0.115 -1.627 -0.101  2.232 -0.661]
# [ 0.14   0.576  0.115 -1.626 -0.101  2.232 -0.661]
# [ 0.14   0.575  0.115 -1.626 -0.101  2.232 -0.662]
# [ 0.14   0.575  0.115 -1.626 -0.101  2.231 -0.662]
# [ 0.14   0.575  0.115 -1.626 -0.101  2.231 -0.662]
# [ 0.14   0.574  0.115 -1.626 -0.101  2.23  -0.662]
# [ 0.14   0.574  0.115 -1.626 -0.101  2.23  -0.662]
# [ 0.14   0.574  0.115 -1.626 -0.101  2.229 -0.662]
# [ 0.14   0.573  0.115 -1.626 -0.1    2.229 -0.662]
# [ 0.14   0.573  0.115 -1.625 -0.1    2.228 -0.662]
# [ 0.14   0.573  0.115 -1.625 -0.1    2.228 -0.662]
# [ 0.14   0.572  0.115 -1.625 -0.1    2.227 -0.662]
# [ 0.14   0.572  0.115 -1.625 -0.1    2.227 -0.662]
# [ 0.14   0.572  0.115 -1.625 -0.1    2.227 -0.662]
# [ 0.14   0.571  0.115 -1.625 -0.1    2.226 -0.662]
# [ 0.14   0.571  0.115 -1.625 -0.1    2.226 -0.662]
# [ 0.14   0.571  0.115 -1.625 -0.1    2.225 -0.662]
# [ 0.14   0.57   0.115 -1.624 -0.1    2.225 -0.662]
# [ 0.14   0.57   0.115 -1.624 -0.1    2.224 -0.662]
# [ 0.14   0.57   0.115 -1.624 -0.1    2.224 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.223 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.223 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.223 -0.662]
# [ 0.14   0.569  0.115 -1.624 -0.1    2.222 -0.662]
# [ 0.14   0.568  0.115 -1.623 -0.1    2.222 -0.662]
# [ 0.14   0.568  0.115 -1.623 -0.1    2.221 -0.662]
# [ 0.139  0.568  0.115 -1.623 -0.1    2.221 -0.662]
# [ 0.139  0.567  0.115 -1.623 -0.1    2.22  -0.662]
# [ 0.139  0.567  0.115 -1.623 -0.099  2.22  -0.663]
# [ 0.139  0.567  0.116 -1.623 -0.099  2.219 -0.663]
# [ 0.139  0.566  0.116 -1.623 -0.099  2.219 -0.663]
# [ 0.139  0.566  0.116 -1.622 -0.099  2.218 -0.663]
# [ 0.139  0.566  0.116 -1.622 -0.099  2.218 -0.663]
# [ 0.139  0.565  0.116 -1.622 -0.099  2.218 -0.663]
# [ 0.139  0.565  0.116 -1.622 -0.099  2.217 -0.663]
# [ 0.139  0.565  0.116 -1.622 -0.099  2.217 -0.663]
# [ 0.139  0.564  0.116 -1.622 -0.099  2.216 -0.663]
# [ 0.139  0.564  0.116 -1.622 -0.099  2.216 -0.663]
# [ 0.139  0.564  0.116 -1.621 -0.099  2.215 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.215 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.214 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.214 -0.663]
# [ 0.139  0.563  0.116 -1.621 -0.099  2.213 -0.663]
# [ 0.139  0.562  0.116 -1.621 -0.099  2.213 -0.663]
# [ 0.139  0.562  0.116 -1.621 -0.099  2.213 -0.663]
# [ 0.139  0.562  0.116 -1.62  -0.099  2.212 -0.663]
# [ 0.139  0.561  0.116 -1.62  -0.099  2.212 -0.663]
# [ 0.139  0.561  0.116 -1.62  -0.099  2.211 -0.663]
# [ 0.139  0.561  0.116 -1.62  -0.098  2.211 -0.663]
# [ 0.139  0.56   0.116 -1.62  -0.098  2.21  -0.663]
# [ 0.139  0.56   0.116 -1.62  -0.098  2.21  -0.663]
# [ 0.139  0.56   0.116 -1.62  -0.098  2.209 -0.663]
# [ 0.139  0.559  0.116 -1.619 -0.098  2.209 -0.663]
# [ 0.139  0.559  0.116 -1.619 -0.098  2.208 -0.663]
# [ 0.139  0.559  0.116 -1.619 -0.098  2.208 -0.663]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.208 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.207 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.207 -0.664]
# [ 0.139  0.558  0.116 -1.619 -0.098  2.206 -0.664]
# [ 0.139  0.557  0.116 -1.618 -0.098  2.206 -0.664]
# [ 0.139  0.557  0.116 -1.618 -0.098  2.205 -0.664]
# [ 0.139  0.557  0.117 -1.618 -0.098  2.205 -0.664]
# [ 0.139  0.556  0.117 -1.618 -0.098  2.204 -0.664]
# [ 0.139  0.556  0.117 -1.618 -0.098  2.204 -0.664]
# [ 0.139  0.556  0.117 -1.618 -0.098  2.203 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.098  2.203 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.098  2.202 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.098  2.202 -0.664]
# [ 0.139  0.555  0.117 -1.617 -0.097  2.202 -0.664]
# [ 0.139  0.554  0.117 -1.617 -0.097  2.201 -0.664]
# [ 0.139  0.554  0.117 -1.617 -0.097  2.201 -0.664]
# [ 0.139  0.554  0.117 -1.616 -0.097  2.2   -0.664]
# [ 0.139  0.553  0.117 -1.616 -0.097  2.2   -0.664]
# [ 0.139  0.553  0.117 -1.616 -0.097  2.199 -0.664]
# [ 0.139  0.553  0.117 -1.616 -0.097  2.199 -0.664]
# [ 0.139  0.552  0.117 -1.616 -0.097  2.198 -0.664]
# [ 0.139  0.552  0.117 -1.616 -0.097  2.198 -0.664]
# [ 0.139  0.552  0.117 -1.615 -0.097  2.197 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.197 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.196 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.196 -0.664]
# [ 0.139  0.551  0.117 -1.615 -0.097  2.196 -0.664]
# [ 0.139  0.55   0.117 -1.615 -0.097  2.195 -0.665]
# [ 0.139  0.55   0.117 -1.615 -0.097  2.195 -0.665]
# [ 0.139  0.55   0.117 -1.614 -0.097  2.194 -0.665]
# [ 0.139  0.549  0.117 -1.614 -0.097  2.194 -0.665]
# [ 0.139  0.549  0.117 -1.614 -0.097  2.193 -0.665]
# [ 0.138  0.549  0.117 -1.614 -0.097  2.193 -0.665]
# [ 0.138  0.549  0.117 -1.614 -0.096  2.192 -0.665]
# [ 0.138  0.548  0.117 -1.614 -0.096  2.192 -0.665]
# [ 0.138  0.548  0.117 -1.613 -0.096  2.191 -0.665]
# [ 0.138  0.548  0.117 -1.613 -0.096  2.191 -0.665]
# [ 0.138  0.547  0.117 -1.613 -0.096  2.19  -0.665]
# [ 0.138  0.547  0.117 -1.613 -0.096  2.19  -0.665]
# [ 0.138  0.547  0.117 -1.613 -0.096  2.189 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.189 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.189 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.188 -0.665]
# [ 0.138  0.546  0.118 -1.612 -0.096  2.188 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.138  0.545  0.118 -1.612 -0.096  2.187 -0.665]
# [ 0.14   0.533  0.116 -1.61  -0.094  2.176 -0.67 ]
# [ 0.151  0.462  0.106 -1.598 -0.081  2.115 -0.696]
# [ 0.161  0.392  0.097 -1.587 -0.068  2.053 -0.722]
# [ 0.172  0.321  0.087 -1.576 -0.055  1.991 -0.749]
# [ 0.183  0.25   0.078 -1.564 -0.042  1.93  -0.775]
# [ 0.193  0.18   0.068 -1.553 -0.029  1.868 -0.802]
# [ 0.204  0.109  0.058 -1.542 -0.016  1.806 -0.828]
# [ 0.214  0.038  0.049 -1.53  -0.002  1.745 -0.855]
# [ 0.159  0.066  0.015 -1.559 -0.051  1.704 -0.863]
# [ 0.161 -0.001  0.    -1.552 -0.045  1.637 -0.89 ]
# [ 0.106 -0.02  -0.014 -1.571 -0.098  1.595 -0.852]
# [ 0.037 -0.014 -0.04  -1.566 -0.08   1.59  -0.787]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]
# [ 0.     0.     0.    -1.571  0.     1.571 -0.785]

# %% [markdown]
# # Problem 4. [40pt] Control a robot to follow the paths.
#
# You will use path planning algorithms and a `PID` controller to simulate the robot's movements along these paths. The solution involves:
#
# ### Initializing the robot and controller.
# ### Following the paths.
# ### Simulating and visualizing the robot's movements.

# %%
def simulate_path(
    model: mujoco.MjModel,
    model_data: mujoco.MjData,
    path: list[npt.NDArray],
    controller: PIDController,
    error_threshold: float = 0.07,
    frame_rate: int = 15,
):
    """
    Simulate the gripper following the planned path.

    Parameters:
        model: MuJoCo model object.
        data: MuJoCo data object.
        path: List of waypoints (joint configurations).
        controller: PID controller object.
    """
    # Initialize a list to store frames for the video
    frames = []

    joint_ids, actuator_addresses = get_joint_actuator_ids_adress(model)
    qpos_adrs = get_joint_qpos_addresses(model, joint_ids)

    # Iterate through each waypoint in the path
    for qpos_idx, curr_qpos in enumerate(path):
        # Reset the controller with the current simulation time
        controller.reset(model_data.time)
        # Set the target position for the controller
        controller.x_trgt = curr_qpos

        while True:
            # Copy the current joint positions
            x_curr = model_data.qpos[qpos_adrs].copy()

            # Update the controller with the current positions and time
            controller.update(x_curr, model_data.time)

            # Set the control inputs for the actuators
            model_data.ctrl[actuator_addresses] = controller.out()

            # Step the simulation forward
            mujoco.mj_step(model, model_data)

            # Render and save frames
            if len(frames) < model_data.time * frame_rate:
                renderer.update_scene(model_data, camera="sideview")
                pixels = renderer.render()
                frames.append(pixels)

            # Break if the current error is small enough
            if np.sum(np.abs(controller.err_curr)) < error_threshold:
                print(f"Reached waypoint calculated: {qpos_idx + 1}/{len(path)}")
                break

    return frames


def test_problem5():
    actuator_address = get_joint_actuator_ids_adress(MODEL)[1]

    # 1. Define a controller
    pid_controller = PIDController(
        k_p=1000,
        k_i=0.5,
        k_d=50,
        dim=7,
        out_min=MODEL.actuator_ctrlrange[actuator_address, 0],
        out_max=MODEL.actuator_ctrlrange[actuator_address, 1],
    )

    # 2. Get grasp path
    grasp_path = get_grasp_path(
        MODEL,
        MODEL_DATA,
        rr_start_threshold=0.001,
        rrt_start_max_iter=1000,
        rrt_start_eta=0.01,
    )
    # 3. Simulate paths and collect frames
    frames = simulate_path(
        MODEL,
        MODEL_DATA,
        grasp_path,
        pid_controller,
        error_threshold=0.07,
        frame_rate=5,
    )

    FRAME_RATE = 60
    # 4. Display video.
    media.show_video(frames, fps=FRAME_RATE)


test_problem5()
# Out:
# 8.079557761628037e-06
# Reached waypoint calculated: 1/1241
# Reached waypoint calculated: 2/1241
# Reached waypoint calculated: 3/1241
# Reached waypoint calculated: 4/1241
# Reached waypoint calculated: 5/1241
# Reached waypoint calculated: 6/1241
# Reached waypoint calculated: 7/1241
# Reached waypoint calculated: 8/1241
# Reached waypoint calculated: 9/1241
# Reached waypoint calculated: 10/1241
# Reached waypoint calculated: 11/1241
# Reached waypoint calculated: 12/1241
# Reached waypoint calculated: 13/1241
# Reached waypoint calculated: 14/1241
# Reached waypoint calculated: 15/1241
# Reached waypoint calculated: 16/1241
# Reached waypoint calculated: 17/1241
# Reached waypoint calculated: 18/1241
# Reached waypoint calculated: 19/1241
# Reached waypoint calculated: 20/1241
# Reached waypoint calculated: 21/1241
# Reached waypoint calculated: 22/1241
# Reached waypoint calculated: 23/1241
# Reached waypoint calculated: 24/1241
# Reached waypoint calculated: 25/1241
# Reached waypoint calculated: 26/1241
# Reached waypoint calculated: 27/1241
# Reached waypoint calculated: 28/1241
# Reached waypoint calculated: 29/1241
# Reached waypoint calculated: 30/1241
# Reached waypoint calculated: 31/1241
# Reached waypoint calculated: 32/1241
# Reached waypoint calculated: 33/1241
# Reached waypoint calculated: 34/1241
# Reached waypoint calculated: 35/1241
# Reached waypoint calculated: 36/1241
# Reached waypoint calculated: 37/1241
# Reached waypoint calculated: 38/1241
# Reached waypoint calculated: 39/1241
# Reached waypoint calculated: 40/1241
# Reached waypoint calculated: 41/1241
# Reached waypoint calculated: 42/1241
# Reached waypoint calculated: 43/1241
# Reached waypoint calculated: 44/1241
# Reached waypoint calculated: 45/1241
# Reached waypoint calculated: 46/1241
# Reached waypoint calculated: 47/1241
# Reached waypoint calculated: 48/1241
# Reached waypoint calculated: 49/1241
# Reached waypoint calculated: 50/1241
# Reached waypoint calculated: 51/1241
# Reached waypoint calculated: 52/1241
# Reached waypoint calculated: 53/1241
# Reached waypoint calculated: 54/1241
# Reached waypoint calculated: 55/1241
# Reached waypoint calculated: 56/1241
# Reached waypoint calculated: 57/1241
# Reached waypoint calculated: 58/1241
# Reached waypoint calculated: 59/1241
# Reached waypoint calculated: 60/1241
# Reached waypoint calculated: 61/1241
# Reached waypoint calculated: 62/1241
# Reached waypoint calculated: 63/1241
# Reached waypoint calculated: 64/1241
# Reached waypoint calculated: 65/1241
# Reached waypoint calculated: 66/1241
# Reached waypoint calculated: 67/1241
# Reached waypoint calculated: 68/1241
# Reached waypoint calculated: 69/1241
# Reached waypoint calculated: 70/1241
# Reached waypoint calculated: 71/1241
# Reached waypoint calculated: 72/1241
# Reached waypoint calculated: 73/1241
# Reached waypoint calculated: 74/1241
# Reached waypoint calculated: 75/1241
# Reached waypoint calculated: 76/1241
# Reached waypoint calculated: 77/1241
# Reached waypoint calculated: 78/1241
# Reached waypoint calculated: 79/1241
# Reached waypoint calculated: 80/1241
# Reached waypoint calculated: 81/1241
# Reached waypoint calculated: 82/1241
# Reached waypoint calculated: 83/1241
# Reached waypoint calculated: 84/1241
# Reached waypoint calculated: 85/1241
# Reached waypoint calculated: 86/1241
# Reached waypoint calculated: 87/1241
# Reached waypoint calculated: 88/1241
# Reached waypoint calculated: 89/1241
# Reached waypoint calculated: 90/1241
# Reached waypoint calculated: 91/1241
# Reached waypoint calculated: 92/1241
# Reached waypoint calculated: 93/1241
# Reached waypoint calculated: 94/1241
# Reached waypoint calculated: 95/1241
# Reached waypoint calculated: 96/1241
# Reached waypoint calculated: 97/1241
# Reached waypoint calculated: 98/1241
# Reached waypoint calculated: 99/1241
# Reached waypoint calculated: 100/1241
# Reached waypoint calculated: 101/1241
# Reached waypoint calculated: 102/1241
# Reached waypoint calculated: 103/1241
# Reached waypoint calculated: 104/1241
# Reached waypoint calculated: 105/1241
# Reached waypoint calculated: 106/1241
# Reached waypoint calculated: 107/1241
# Reached waypoint calculated: 108/1241
# Reached waypoint calculated: 109/1241
# Reached waypoint calculated: 110/1241
# Reached waypoint calculated: 111/1241
# Reached waypoint calculated: 112/1241
# Reached waypoint calculated: 113/1241
# Reached waypoint calculated: 114/1241
# Reached waypoint calculated: 115/1241
# Reached waypoint calculated: 116/1241
# Reached waypoint calculated: 117/1241
# Reached waypoint calculated: 118/1241
# Reached waypoint calculated: 119/1241
# Reached waypoint calculated: 120/1241
# Reached waypoint calculated: 121/1241
# Reached waypoint calculated: 122/1241
# Reached waypoint calculated: 123/1241
# Reached waypoint calculated: 124/1241
# Reached waypoint calculated: 125/1241
# Reached waypoint calculated: 126/1241
# Reached waypoint calculated: 127/1241
# Reached waypoint calculated: 128/1241
# Reached waypoint calculated: 129/1241
# Reached waypoint calculated: 130/1241
# Reached waypoint calculated: 131/1241
# Reached waypoint calculated: 132/1241
# Reached waypoint calculated: 133/1241
# Reached waypoint calculated: 134/1241
# Reached waypoint calculated: 135/1241
# Reached waypoint calculated: 136/1241
# Reached waypoint calculated: 137/1241
# Reached waypoint calculated: 138/1241
# Reached waypoint calculated: 139/1241
# Reached waypoint calculated: 140/1241
# Reached waypoint calculated: 141/1241
# Reached waypoint calculated: 142/1241
# Reached waypoint calculated: 143/1241
# Reached waypoint calculated: 144/1241
# Reached waypoint calculated: 145/1241
# Reached waypoint calculated: 146/1241
# Reached waypoint calculated: 147/1241
# Reached waypoint calculated: 148/1241
# Reached waypoint calculated: 149/1241
# Reached waypoint calculated: 150/1241
# Reached waypoint calculated: 151/1241
# Reached waypoint calculated: 152/1241
# Reached waypoint calculated: 153/1241
# Reached waypoint calculated: 154/1241
# Reached waypoint calculated: 155/1241
# Reached waypoint calculated: 156/1241
# Reached waypoint calculated: 157/1241
# Reached waypoint calculated: 158/1241
# Reached waypoint calculated: 159/1241
# Reached waypoint calculated: 160/1241
# Reached waypoint calculated: 161/1241
# Reached waypoint calculated: 162/1241
# Reached waypoint calculated: 163/1241
# Reached waypoint calculated: 164/1241
# Reached waypoint calculated: 165/1241
# Reached waypoint calculated: 166/1241
# Reached waypoint calculated: 167/1241
# Reached waypoint calculated: 168/1241
# Reached waypoint calculated: 169/1241
# Reached waypoint calculated: 170/1241
# Reached waypoint calculated: 171/1241
# Reached waypoint calculated: 172/1241
# Reached waypoint calculated: 173/1241
# Reached waypoint calculated: 174/1241
# Reached waypoint calculated: 175/1241
# Reached waypoint calculated: 176/1241
# Reached waypoint calculated: 177/1241
# Reached waypoint calculated: 178/1241
# Reached waypoint calculated: 179/1241
# Reached waypoint calculated: 180/1241
# Reached waypoint calculated: 181/1241
# Reached waypoint calculated: 182/1241
# Reached waypoint calculated: 183/1241
# Reached waypoint calculated: 184/1241
# Reached waypoint calculated: 185/1241
# Reached waypoint calculated: 186/1241
# Reached waypoint calculated: 187/1241
# Reached waypoint calculated: 188/1241
# Reached waypoint calculated: 189/1241
# Reached waypoint calculated: 190/1241
# Reached waypoint calculated: 191/1241
# Reached waypoint calculated: 192/1241
# Reached waypoint calculated: 193/1241
# Reached waypoint calculated: 194/1241
# Reached waypoint calculated: 195/1241
# Reached waypoint calculated: 196/1241
# Reached waypoint calculated: 197/1241
# Reached waypoint calculated: 198/1241
# Reached waypoint calculated: 199/1241
# Reached waypoint calculated: 200/1241
# Reached waypoint calculated: 201/1241
# Reached waypoint calculated: 202/1241
# Reached waypoint calculated: 203/1241
# Reached waypoint calculated: 204/1241
# Reached waypoint calculated: 205/1241
# Reached waypoint calculated: 206/1241
# Reached waypoint calculated: 207/1241
# Reached waypoint calculated: 208/1241
# Reached waypoint calculated: 209/1241
# Reached waypoint calculated: 210/1241
# Reached waypoint calculated: 211/1241
# Reached waypoint calculated: 212/1241
# Reached waypoint calculated: 213/1241
# Reached waypoint calculated: 214/1241
# Reached waypoint calculated: 215/1241
# Reached waypoint calculated: 216/1241
# Reached waypoint calculated: 217/1241
# Reached waypoint calculated: 218/1241
# Reached waypoint calculated: 219/1241
# Reached waypoint calculated: 220/1241
# Reached waypoint calculated: 221/1241
# Reached waypoint calculated: 222/1241
# Reached waypoint calculated: 223/1241
# Reached waypoint calculated: 224/1241
# Reached waypoint calculated: 225/1241
# Reached waypoint calculated: 226/1241
# Reached waypoint calculated: 227/1241
# Reached waypoint calculated: 228/1241
# Reached waypoint calculated: 229/1241
# Reached waypoint calculated: 230/1241
# Reached waypoint calculated: 231/1241
# Reached waypoint calculated: 232/1241
# Reached waypoint calculated: 233/1241
# Reached waypoint calculated: 234/1241
# Reached waypoint calculated: 235/1241
# Reached waypoint calculated: 236/1241
# Reached waypoint calculated: 237/1241
# Reached waypoint calculated: 238/1241
# Reached waypoint calculated: 239/1241
# Reached waypoint calculated: 240/1241
# Reached waypoint calculated: 241/1241
# Reached waypoint calculated: 242/1241
# Reached waypoint calculated: 243/1241
# Reached waypoint calculated: 244/1241
# Reached waypoint calculated: 245/1241
# Reached waypoint calculated: 246/1241
# Reached waypoint calculated: 247/1241
# Reached waypoint calculated: 248/1241
# Reached waypoint calculated: 249/1241
# Reached waypoint calculated: 250/1241
# Reached waypoint calculated: 251/1241
# Reached waypoint calculated: 252/1241
# Reached waypoint calculated: 253/1241
# Reached waypoint calculated: 254/1241
# Reached waypoint calculated: 255/1241
# Reached waypoint calculated: 256/1241
# Reached waypoint calculated: 257/1241
# Reached waypoint calculated: 258/1241
# Reached waypoint calculated: 259/1241
# Reached waypoint calculated: 260/1241
# Reached waypoint calculated: 261/1241
# Reached waypoint calculated: 262/1241
# Reached waypoint calculated: 263/1241
# Reached waypoint calculated: 264/1241
# Reached waypoint calculated: 265/1241
# Reached waypoint calculated: 266/1241
# Reached waypoint calculated: 267/1241
# Reached waypoint calculated: 268/1241
# Reached waypoint calculated: 269/1241
# Reached waypoint calculated: 270/1241
# Reached waypoint calculated: 271/1241
# Reached waypoint calculated: 272/1241
# Reached waypoint calculated: 273/1241
# Reached waypoint calculated: 274/1241
# Reached waypoint calculated: 275/1241
# Reached waypoint calculated: 276/1241
# Reached waypoint calculated: 277/1241
# Reached waypoint calculated: 278/1241
# Reached waypoint calculated: 279/1241
# Reached waypoint calculated: 280/1241
# Reached waypoint calculated: 281/1241
# Reached waypoint calculated: 282/1241
# Reached waypoint calculated: 283/1241
# Reached waypoint calculated: 284/1241
# Reached waypoint calculated: 285/1241
# Reached waypoint calculated: 286/1241
# Reached waypoint calculated: 287/1241
# Reached waypoint calculated: 288/1241
# Reached waypoint calculated: 289/1241
# Reached waypoint calculated: 290/1241
# Reached waypoint calculated: 291/1241
# Reached waypoint calculated: 292/1241
# Reached waypoint calculated: 293/1241
# Reached waypoint calculated: 294/1241
# Reached waypoint calculated: 295/1241
# Reached waypoint calculated: 296/1241
# Reached waypoint calculated: 297/1241
# Reached waypoint calculated: 298/1241
# Reached waypoint calculated: 299/1241
# Reached waypoint calculated: 300/1241
# Reached waypoint calculated: 301/1241
# Reached waypoint calculated: 302/1241
# Reached waypoint calculated: 303/1241
# Reached waypoint calculated: 304/1241
# Reached waypoint calculated: 305/1241
# Reached waypoint calculated: 306/1241
# Reached waypoint calculated: 307/1241
# Reached waypoint calculated: 308/1241
# Reached waypoint calculated: 309/1241
# Reached waypoint calculated: 310/1241
# Reached waypoint calculated: 311/1241
# Reached waypoint calculated: 312/1241
# Reached waypoint calculated: 313/1241
# Reached waypoint calculated: 314/1241
# Reached waypoint calculated: 315/1241
# Reached waypoint calculated: 316/1241
# Reached waypoint calculated: 317/1241
# Reached waypoint calculated: 318/1241
# Reached waypoint calculated: 319/1241
# Reached waypoint calculated: 320/1241
# Reached waypoint calculated: 321/1241
# Reached waypoint calculated: 322/1241
# Reached waypoint calculated: 323/1241
# Reached waypoint calculated: 324/1241
# Reached waypoint calculated: 325/1241
# Reached waypoint calculated: 326/1241
# Reached waypoint calculated: 327/1241
# Reached waypoint calculated: 328/1241
# Reached waypoint calculated: 329/1241
# Reached waypoint calculated: 330/1241
# Reached waypoint calculated: 331/1241
# Reached waypoint calculated: 332/1241
# Reached waypoint calculated: 333/1241
# Reached waypoint calculated: 334/1241
# Reached waypoint calculated: 335/1241
# Reached waypoint calculated: 336/1241
# Reached waypoint calculated: 337/1241
# Reached waypoint calculated: 338/1241
# Reached waypoint calculated: 339/1241
# Reached waypoint calculated: 340/1241
# Reached waypoint calculated: 341/1241
# Reached waypoint calculated: 342/1241
# Reached waypoint calculated: 343/1241
# Reached waypoint calculated: 344/1241
# Reached waypoint calculated: 345/1241
# Reached waypoint calculated: 346/1241
# Reached waypoint calculated: 347/1241
# Reached waypoint calculated: 348/1241
# Reached waypoint calculated: 349/1241
# Reached waypoint calculated: 350/1241
# Reached waypoint calculated: 351/1241
# Reached waypoint calculated: 352/1241
# Reached waypoint calculated: 353/1241
# Reached waypoint calculated: 354/1241
# Reached waypoint calculated: 355/1241
# Reached waypoint calculated: 356/1241
# Reached waypoint calculated: 357/1241
# Reached waypoint calculated: 358/1241
# Reached waypoint calculated: 359/1241
# Reached waypoint calculated: 360/1241
# Reached waypoint calculated: 361/1241
# Reached waypoint calculated: 362/1241
# Reached waypoint calculated: 363/1241
# Reached waypoint calculated: 364/1241
# Reached waypoint calculated: 365/1241
# Reached waypoint calculated: 366/1241
# Reached waypoint calculated: 367/1241
# Reached waypoint calculated: 368/1241
# Reached waypoint calculated: 369/1241
# Reached waypoint calculated: 370/1241
# Reached waypoint calculated: 371/1241
# Reached waypoint calculated: 372/1241
# Reached waypoint calculated: 373/1241
# Reached waypoint calculated: 374/1241
# Reached waypoint calculated: 375/1241
# Reached waypoint calculated: 376/1241
# Reached waypoint calculated: 377/1241
# Reached waypoint calculated: 378/1241
# Reached waypoint calculated: 379/1241
# Reached waypoint calculated: 380/1241
# Reached waypoint calculated: 381/1241
# Reached waypoint calculated: 382/1241
# Reached waypoint calculated: 383/1241
# Reached waypoint calculated: 384/1241
# Reached waypoint calculated: 385/1241
# Reached waypoint calculated: 386/1241
# Reached waypoint calculated: 387/1241
# Reached waypoint calculated: 388/1241
# Reached waypoint calculated: 389/1241
# Reached waypoint calculated: 390/1241
# Reached waypoint calculated: 391/1241
# Reached waypoint calculated: 392/1241
# Reached waypoint calculated: 393/1241
# Reached waypoint calculated: 394/1241
# Reached waypoint calculated: 395/1241
# Reached waypoint calculated: 396/1241
# Reached waypoint calculated: 397/1241
# Reached waypoint calculated: 398/1241
# Reached waypoint calculated: 399/1241
# Reached waypoint calculated: 400/1241
# Reached waypoint calculated: 401/1241
# Reached waypoint calculated: 402/1241
# Reached waypoint calculated: 403/1241
# Reached waypoint calculated: 404/1241
# Reached waypoint calculated: 405/1241
# Reached waypoint calculated: 406/1241
# Reached waypoint calculated: 407/1241
# Reached waypoint calculated: 408/1241
# Reached waypoint calculated: 409/1241
# Reached waypoint calculated: 410/1241
# Reached waypoint calculated: 411/1241
# Reached waypoint calculated: 412/1241
# Reached waypoint calculated: 413/1241
# Reached waypoint calculated: 414/1241
# Reached waypoint calculated: 415/1241
# Reached waypoint calculated: 416/1241
# Reached waypoint calculated: 417/1241
# Reached waypoint calculated: 418/1241
# Reached waypoint calculated: 419/1241
# Reached waypoint calculated: 420/1241
# Reached waypoint calculated: 421/1241
# Reached waypoint calculated: 422/1241
# Reached waypoint calculated: 423/1241
# Reached waypoint calculated: 424/1241
# Reached waypoint calculated: 425/1241
# Reached waypoint calculated: 426/1241
# Reached waypoint calculated: 427/1241
# Reached waypoint calculated: 428/1241
# Reached waypoint calculated: 429/1241
# Reached waypoint calculated: 430/1241
# Reached waypoint calculated: 431/1241
# Reached waypoint calculated: 432/1241
# Reached waypoint calculated: 433/1241
# Reached waypoint calculated: 434/1241
# Reached waypoint calculated: 435/1241
# Reached waypoint calculated: 436/1241
# Reached waypoint calculated: 437/1241
# Reached waypoint calculated: 438/1241
# Reached waypoint calculated: 439/1241
# Reached waypoint calculated: 440/1241
# Reached waypoint calculated: 441/1241
# Reached waypoint calculated: 442/1241
# Reached waypoint calculated: 443/1241
# Reached waypoint calculated: 444/1241
# Reached waypoint calculated: 445/1241
# Reached waypoint calculated: 446/1241
# Reached waypoint calculated: 447/1241
# Reached waypoint calculated: 448/1241
# Reached waypoint calculated: 449/1241
# Reached waypoint calculated: 450/1241
# Reached waypoint calculated: 451/1241
# Reached waypoint calculated: 452/1241
# Reached waypoint calculated: 453/1241
# Reached waypoint calculated: 454/1241
# Reached waypoint calculated: 455/1241
# Reached waypoint calculated: 456/1241
# Reached waypoint calculated: 457/1241
# Reached waypoint calculated: 458/1241
# Reached waypoint calculated: 459/1241
# Reached waypoint calculated: 460/1241
# Reached waypoint calculated: 461/1241
# Reached waypoint calculated: 462/1241
# Reached waypoint calculated: 463/1241
# Reached waypoint calculated: 464/1241
# Reached waypoint calculated: 465/1241
# Reached waypoint calculated: 466/1241
# Reached waypoint calculated: 467/1241
# Reached waypoint calculated: 468/1241
# Reached waypoint calculated: 469/1241
# Reached waypoint calculated: 470/1241
# Reached waypoint calculated: 471/1241
# Reached waypoint calculated: 472/1241
# Reached waypoint calculated: 473/1241
# Reached waypoint calculated: 474/1241
# Reached waypoint calculated: 475/1241
# Reached waypoint calculated: 476/1241
# Reached waypoint calculated: 477/1241
# Reached waypoint calculated: 478/1241
# Reached waypoint calculated: 479/1241
# Reached waypoint calculated: 480/1241
# Reached waypoint calculated: 481/1241
# Reached waypoint calculated: 482/1241
# Reached waypoint calculated: 483/1241
# Reached waypoint calculated: 484/1241
# Reached waypoint calculated: 485/1241
# Reached waypoint calculated: 486/1241
# Reached waypoint calculated: 487/1241
# Reached waypoint calculated: 488/1241
# Reached waypoint calculated: 489/1241
# Reached waypoint calculated: 490/1241
# Reached waypoint calculated: 491/1241
# Reached waypoint calculated: 492/1241
# Reached waypoint calculated: 493/1241
# Reached waypoint calculated: 494/1241
# Reached waypoint calculated: 495/1241
# Reached waypoint calculated: 496/1241
# Reached waypoint calculated: 497/1241
# Reached waypoint calculated: 498/1241
# Reached waypoint calculated: 499/1241
# Reached waypoint calculated: 500/1241
# Reached waypoint calculated: 501/1241
# Reached waypoint calculated: 502/1241
# Reached waypoint calculated: 503/1241
# Reached waypoint calculated: 504/1241
# Reached waypoint calculated: 505/1241
# Reached waypoint calculated: 506/1241
# Reached waypoint calculated: 507/1241
# Reached waypoint calculated: 508/1241
# Reached waypoint calculated: 509/1241
# Reached waypoint calculated: 510/1241
# Reached waypoint calculated: 511/1241
# Reached waypoint calculated: 512/1241
# Reached waypoint calculated: 513/1241
# Reached waypoint calculated: 514/1241
# Reached waypoint calculated: 515/1241
# Reached waypoint calculated: 516/1241
# Reached waypoint calculated: 517/1241
# Reached waypoint calculated: 518/1241
# Reached waypoint calculated: 519/1241
# Reached waypoint calculated: 520/1241
# Reached waypoint calculated: 521/1241
# Reached waypoint calculated: 522/1241
# Reached waypoint calculated: 523/1241
# Reached waypoint calculated: 524/1241
# Reached waypoint calculated: 525/1241
# Reached waypoint calculated: 526/1241
# Reached waypoint calculated: 527/1241
# Reached waypoint calculated: 528/1241
# Reached waypoint calculated: 529/1241
# Reached waypoint calculated: 530/1241
# Reached waypoint calculated: 531/1241
# Reached waypoint calculated: 532/1241
# Reached waypoint calculated: 533/1241
# Reached waypoint calculated: 534/1241
# Reached waypoint calculated: 535/1241
# Reached waypoint calculated: 536/1241
# Reached waypoint calculated: 537/1241
# Reached waypoint calculated: 538/1241
# Reached waypoint calculated: 539/1241
# Reached waypoint calculated: 540/1241
# Reached waypoint calculated: 541/1241
# Reached waypoint calculated: 542/1241
# Reached waypoint calculated: 543/1241
# Reached waypoint calculated: 544/1241
# Reached waypoint calculated: 545/1241
# Reached waypoint calculated: 546/1241
# Reached waypoint calculated: 547/1241
# Reached waypoint calculated: 548/1241
# Reached waypoint calculated: 549/1241
# Reached waypoint calculated: 550/1241
# Reached waypoint calculated: 551/1241
# Reached waypoint calculated: 552/1241
# Reached waypoint calculated: 553/1241
# Reached waypoint calculated: 554/1241
# Reached waypoint calculated: 555/1241
# Reached waypoint calculated: 556/1241
# Reached waypoint calculated: 557/1241
# Reached waypoint calculated: 558/1241
# Reached waypoint calculated: 559/1241
# Reached waypoint calculated: 560/1241
# Reached waypoint calculated: 561/1241
# Reached waypoint calculated: 562/1241
# Reached waypoint calculated: 563/1241
# Reached waypoint calculated: 564/1241
# Reached waypoint calculated: 565/1241
# Reached waypoint calculated: 566/1241
# Reached waypoint calculated: 567/1241
# Reached waypoint calculated: 568/1241
# Reached waypoint calculated: 569/1241
# Reached waypoint calculated: 570/1241
# Reached waypoint calculated: 571/1241
# Reached waypoint calculated: 572/1241
# Reached waypoint calculated: 573/1241
# Reached waypoint calculated: 574/1241
# Reached waypoint calculated: 575/1241
# Reached waypoint calculated: 576/1241
# Reached waypoint calculated: 577/1241
# Reached waypoint calculated: 578/1241
# Reached waypoint calculated: 579/1241
# Reached waypoint calculated: 580/1241
# Reached waypoint calculated: 581/1241
# Reached waypoint calculated: 582/1241
# Reached waypoint calculated: 583/1241
# Reached waypoint calculated: 584/1241
# Reached waypoint calculated: 585/1241
# Reached waypoint calculated: 586/1241
# Reached waypoint calculated: 587/1241
# Reached waypoint calculated: 588/1241
# Reached waypoint calculated: 589/1241
# Reached waypoint calculated: 590/1241
# Reached waypoint calculated: 591/1241
# Reached waypoint calculated: 592/1241
# Reached waypoint calculated: 593/1241
# Reached waypoint calculated: 594/1241
# Reached waypoint calculated: 595/1241
# Reached waypoint calculated: 596/1241
# Reached waypoint calculated: 597/1241
# Reached waypoint calculated: 598/1241
# Reached waypoint calculated: 599/1241
# Reached waypoint calculated: 600/1241
# Reached waypoint calculated: 601/1241
# Reached waypoint calculated: 602/1241
# Reached waypoint calculated: 603/1241
# Reached waypoint calculated: 604/1241
# Reached waypoint calculated: 605/1241
# Reached waypoint calculated: 606/1241
# Reached waypoint calculated: 607/1241
# Reached waypoint calculated: 608/1241
# Reached waypoint calculated: 609/1241
# Reached waypoint calculated: 610/1241
# Reached waypoint calculated: 611/1241
# Reached waypoint calculated: 612/1241
# Reached waypoint calculated: 613/1241
# Reached waypoint calculated: 614/1241
# Reached waypoint calculated: 615/1241
# Reached waypoint calculated: 616/1241
# Reached waypoint calculated: 617/1241
# Reached waypoint calculated: 618/1241
# Reached waypoint calculated: 619/1241
# Reached waypoint calculated: 620/1241
# Reached waypoint calculated: 621/1241
# Reached waypoint calculated: 622/1241
# Reached waypoint calculated: 623/1241
# Reached waypoint calculated: 624/1241
# Reached waypoint calculated: 625/1241
# Reached waypoint calculated: 626/1241
# Reached waypoint calculated: 627/1241
# Reached waypoint calculated: 628/1241
# Reached waypoint calculated: 629/1241
# Reached waypoint calculated: 630/1241
# Reached waypoint calculated: 631/1241
# Reached waypoint calculated: 632/1241
# Reached waypoint calculated: 633/1241
# Reached waypoint calculated: 634/1241
# Reached waypoint calculated: 635/1241
# Reached waypoint calculated: 636/1241
# Reached waypoint calculated: 637/1241
# Reached waypoint calculated: 638/1241
# Reached waypoint calculated: 639/1241
# Reached waypoint calculated: 640/1241
# Reached waypoint calculated: 641/1241
# Reached waypoint calculated: 642/1241
# Reached waypoint calculated: 643/1241
# Reached waypoint calculated: 644/1241
# Reached waypoint calculated: 645/1241
# Reached waypoint calculated: 646/1241
# Reached waypoint calculated: 647/1241
# Reached waypoint calculated: 648/1241
# Reached waypoint calculated: 649/1241
# Reached waypoint calculated: 650/1241
# Reached waypoint calculated: 651/1241
# Reached waypoint calculated: 652/1241
# Reached waypoint calculated: 653/1241
# Reached waypoint calculated: 654/1241
# Reached waypoint calculated: 655/1241
# Reached waypoint calculated: 656/1241
# Reached waypoint calculated: 657/1241
# Reached waypoint calculated: 658/1241
# Reached waypoint calculated: 659/1241
# Reached waypoint calculated: 660/1241
# Reached waypoint calculated: 661/1241
# Reached waypoint calculated: 662/1241
# Reached waypoint calculated: 663/1241
# Reached waypoint calculated: 664/1241
# Reached waypoint calculated: 665/1241
# Reached waypoint calculated: 666/1241
# Reached waypoint calculated: 667/1241
# Reached waypoint calculated: 668/1241
# Reached waypoint calculated: 669/1241
# Reached waypoint calculated: 670/1241
# Reached waypoint calculated: 671/1241
# Reached waypoint calculated: 672/1241
# Reached waypoint calculated: 673/1241
# Reached waypoint calculated: 674/1241
# Reached waypoint calculated: 675/1241
# Reached waypoint calculated: 676/1241
# Reached waypoint calculated: 677/1241
# Reached waypoint calculated: 678/1241
# Reached waypoint calculated: 679/1241
# Reached waypoint calculated: 680/1241
# Reached waypoint calculated: 681/1241
# Reached waypoint calculated: 682/1241
# Reached waypoint calculated: 683/1241
# Reached waypoint calculated: 684/1241
# Reached waypoint calculated: 685/1241
# Reached waypoint calculated: 686/1241
# Reached waypoint calculated: 687/1241
# Reached waypoint calculated: 688/1241
# Reached waypoint calculated: 689/1241
# Reached waypoint calculated: 690/1241
# Reached waypoint calculated: 691/1241
# Reached waypoint calculated: 692/1241
# Reached waypoint calculated: 693/1241
# Reached waypoint calculated: 694/1241
# Reached waypoint calculated: 695/1241
# Reached waypoint calculated: 696/1241
# Reached waypoint calculated: 697/1241
# Reached waypoint calculated: 698/1241
# Reached waypoint calculated: 699/1241
# Reached waypoint calculated: 700/1241
# Reached waypoint calculated: 701/1241
# Reached waypoint calculated: 702/1241
# Reached waypoint calculated: 703/1241
# Reached waypoint calculated: 704/1241
# Reached waypoint calculated: 705/1241
# Reached waypoint calculated: 706/1241
# Reached waypoint calculated: 707/1241
# Reached waypoint calculated: 708/1241
# Reached waypoint calculated: 709/1241
# Reached waypoint calculated: 710/1241
# Reached waypoint calculated: 711/1241
# Reached waypoint calculated: 712/1241
# Reached waypoint calculated: 713/1241
# Reached waypoint calculated: 714/1241
# Reached waypoint calculated: 715/1241
# Reached waypoint calculated: 716/1241
# Reached waypoint calculated: 717/1241
# Reached waypoint calculated: 718/1241
# Reached waypoint calculated: 719/1241
# Reached waypoint calculated: 720/1241
# Reached waypoint calculated: 721/1241
# Reached waypoint calculated: 722/1241
# Reached waypoint calculated: 723/1241
# Reached waypoint calculated: 724/1241
# Reached waypoint calculated: 725/1241
# Reached waypoint calculated: 726/1241
# Reached waypoint calculated: 727/1241
# Reached waypoint calculated: 728/1241
# Reached waypoint calculated: 729/1241
# Reached waypoint calculated: 730/1241
# Reached waypoint calculated: 731/1241
# Reached waypoint calculated: 732/1241
# Reached waypoint calculated: 733/1241
# Reached waypoint calculated: 734/1241
# Reached waypoint calculated: 735/1241
# Reached waypoint calculated: 736/1241
# Reached waypoint calculated: 737/1241
# Reached waypoint calculated: 738/1241
# Reached waypoint calculated: 739/1241
# Reached waypoint calculated: 740/1241
# Reached waypoint calculated: 741/1241
# Reached waypoint calculated: 742/1241
# Reached waypoint calculated: 743/1241
# Reached waypoint calculated: 744/1241
# Reached waypoint calculated: 745/1241
# Reached waypoint calculated: 746/1241
# Reached waypoint calculated: 747/1241
# Reached waypoint calculated: 748/1241
# Reached waypoint calculated: 749/1241
# Reached waypoint calculated: 750/1241
# Reached waypoint calculated: 751/1241
# Reached waypoint calculated: 752/1241
# Reached waypoint calculated: 753/1241
# Reached waypoint calculated: 754/1241
# Reached waypoint calculated: 755/1241
# Reached waypoint calculated: 756/1241
# Reached waypoint calculated: 757/1241
# Reached waypoint calculated: 758/1241
# Reached waypoint calculated: 759/1241
# Reached waypoint calculated: 760/1241
# Reached waypoint calculated: 761/1241
# Reached waypoint calculated: 762/1241
# Reached waypoint calculated: 763/1241
# Reached waypoint calculated: 764/1241
# Reached waypoint calculated: 765/1241
# Reached waypoint calculated: 766/1241
# Reached waypoint calculated: 767/1241
# Reached waypoint calculated: 768/1241
# Reached waypoint calculated: 769/1241
# Reached waypoint calculated: 770/1241
# Reached waypoint calculated: 771/1241
# Reached waypoint calculated: 772/1241
# Reached waypoint calculated: 773/1241
# Reached waypoint calculated: 774/1241
# Reached waypoint calculated: 775/1241
# Reached waypoint calculated: 776/1241
# Reached waypoint calculated: 777/1241
# Reached waypoint calculated: 778/1241
# Reached waypoint calculated: 779/1241
# Reached waypoint calculated: 780/1241
# Reached waypoint calculated: 781/1241
# Reached waypoint calculated: 782/1241
# Reached waypoint calculated: 783/1241
# Reached waypoint calculated: 784/1241
# Reached waypoint calculated: 785/1241
# Reached waypoint calculated: 786/1241
# Reached waypoint calculated: 787/1241
# Reached waypoint calculated: 788/1241
# Reached waypoint calculated: 789/1241
# Reached waypoint calculated: 790/1241
# Reached waypoint calculated: 791/1241
# Reached waypoint calculated: 792/1241
# Reached waypoint calculated: 793/1241
# Reached waypoint calculated: 794/1241
# Reached waypoint calculated: 795/1241
# Reached waypoint calculated: 796/1241
# Reached waypoint calculated: 797/1241
# Reached waypoint calculated: 798/1241
# Reached waypoint calculated: 799/1241
# Reached waypoint calculated: 800/1241
# Reached waypoint calculated: 801/1241
# Reached waypoint calculated: 802/1241
# Reached waypoint calculated: 803/1241
# Reached waypoint calculated: 804/1241
# Reached waypoint calculated: 805/1241
# Reached waypoint calculated: 806/1241
# Reached waypoint calculated: 807/1241
# Reached waypoint calculated: 808/1241
# Reached waypoint calculated: 809/1241
# Reached waypoint calculated: 810/1241
# Reached waypoint calculated: 811/1241
# Reached waypoint calculated: 812/1241
# Reached waypoint calculated: 813/1241
# Reached waypoint calculated: 814/1241
# Reached waypoint calculated: 815/1241
# Reached waypoint calculated: 816/1241
# Reached waypoint calculated: 817/1241
# Reached waypoint calculated: 818/1241
# Reached waypoint calculated: 819/1241
# Reached waypoint calculated: 820/1241
# Reached waypoint calculated: 821/1241
# Reached waypoint calculated: 822/1241
# Reached waypoint calculated: 823/1241
# Reached waypoint calculated: 824/1241
# Reached waypoint calculated: 825/1241
# Reached waypoint calculated: 826/1241
# Reached waypoint calculated: 827/1241
# Reached waypoint calculated: 828/1241
# Reached waypoint calculated: 829/1241
# Reached waypoint calculated: 830/1241
# Reached waypoint calculated: 831/1241
# Reached waypoint calculated: 832/1241
# Reached waypoint calculated: 833/1241
# Reached waypoint calculated: 834/1241
# Reached waypoint calculated: 835/1241
# Reached waypoint calculated: 836/1241
# Reached waypoint calculated: 837/1241
# Reached waypoint calculated: 838/1241
# Reached waypoint calculated: 839/1241
# Reached waypoint calculated: 840/1241
# Reached waypoint calculated: 841/1241
# Reached waypoint calculated: 842/1241
# Reached waypoint calculated: 843/1241
# Reached waypoint calculated: 844/1241
# Reached waypoint calculated: 845/1241
# Reached waypoint calculated: 846/1241
# Reached waypoint calculated: 847/1241
# Reached waypoint calculated: 848/1241
# Reached waypoint calculated: 849/1241
# Reached waypoint calculated: 850/1241
# Reached waypoint calculated: 851/1241
# Reached waypoint calculated: 852/1241
# Reached waypoint calculated: 853/1241
# Reached waypoint calculated: 854/1241
# Reached waypoint calculated: 855/1241
# Reached waypoint calculated: 856/1241
# Reached waypoint calculated: 857/1241
# Reached waypoint calculated: 858/1241
# Reached waypoint calculated: 859/1241
# Reached waypoint calculated: 860/1241
# Reached waypoint calculated: 861/1241
# Reached waypoint calculated: 862/1241
# Reached waypoint calculated: 863/1241
# Reached waypoint calculated: 864/1241
# Reached waypoint calculated: 865/1241
# Reached waypoint calculated: 866/1241
# Reached waypoint calculated: 867/1241
# Reached waypoint calculated: 868/1241
# Reached waypoint calculated: 869/1241
# Reached waypoint calculated: 870/1241
# Reached waypoint calculated: 871/1241
# Reached waypoint calculated: 872/1241
# Reached waypoint calculated: 873/1241
# Reached waypoint calculated: 874/1241
# Reached waypoint calculated: 875/1241
# Reached waypoint calculated: 876/1241
# Reached waypoint calculated: 877/1241
# Reached waypoint calculated: 878/1241
# Reached waypoint calculated: 879/1241
# Reached waypoint calculated: 880/1241
# Reached waypoint calculated: 881/1241
# Reached waypoint calculated: 882/1241
# Reached waypoint calculated: 883/1241
# Reached waypoint calculated: 884/1241
# Reached waypoint calculated: 885/1241
# Reached waypoint calculated: 886/1241
# Reached waypoint calculated: 887/1241
# Reached waypoint calculated: 888/1241
# Reached waypoint calculated: 889/1241
# Reached waypoint calculated: 890/1241
# Reached waypoint calculated: 891/1241
# Reached waypoint calculated: 892/1241
# Reached waypoint calculated: 893/1241
# Reached waypoint calculated: 894/1241
# Reached waypoint calculated: 895/1241
# Reached waypoint calculated: 896/1241
# Reached waypoint calculated: 897/1241
# Reached waypoint calculated: 898/1241
# Reached waypoint calculated: 899/1241
# Reached waypoint calculated: 900/1241
# Reached waypoint calculated: 901/1241
# Reached waypoint calculated: 902/1241
# Reached waypoint calculated: 903/1241
# Reached waypoint calculated: 904/1241
# Reached waypoint calculated: 905/1241
# Reached waypoint calculated: 906/1241
# Reached waypoint calculated: 907/1241
# Reached waypoint calculated: 908/1241
# Reached waypoint calculated: 909/1241
# Reached waypoint calculated: 910/1241
# Reached waypoint calculated: 911/1241
# Reached waypoint calculated: 912/1241
# Reached waypoint calculated: 913/1241
# Reached waypoint calculated: 914/1241
# Reached waypoint calculated: 915/1241
# Reached waypoint calculated: 916/1241
# Reached waypoint calculated: 917/1241
# Reached waypoint calculated: 918/1241
# Reached waypoint calculated: 919/1241
# Reached waypoint calculated: 920/1241
# Reached waypoint calculated: 921/1241
# Reached waypoint calculated: 922/1241
# Reached waypoint calculated: 923/1241
# Reached waypoint calculated: 924/1241
# Reached waypoint calculated: 925/1241
# Reached waypoint calculated: 926/1241
# Reached waypoint calculated: 927/1241
# Reached waypoint calculated: 928/1241
# Reached waypoint calculated: 929/1241
# Reached waypoint calculated: 930/1241
# Reached waypoint calculated: 931/1241
# Reached waypoint calculated: 932/1241
# Reached waypoint calculated: 933/1241
# Reached waypoint calculated: 934/1241
# Reached waypoint calculated: 935/1241
# Reached waypoint calculated: 936/1241
# Reached waypoint calculated: 937/1241
# Reached waypoint calculated: 938/1241
# Reached waypoint calculated: 939/1241
# Reached waypoint calculated: 940/1241
# Reached waypoint calculated: 941/1241
# Reached waypoint calculated: 942/1241
# Reached waypoint calculated: 943/1241
# Reached waypoint calculated: 944/1241
# Reached waypoint calculated: 945/1241
# Reached waypoint calculated: 946/1241
# Reached waypoint calculated: 947/1241
# Reached waypoint calculated: 948/1241
# Reached waypoint calculated: 949/1241
# Reached waypoint calculated: 950/1241
# Reached waypoint calculated: 951/1241
# Reached waypoint calculated: 952/1241
# Reached waypoint calculated: 953/1241
# Reached waypoint calculated: 954/1241
# Reached waypoint calculated: 955/1241
# Reached waypoint calculated: 956/1241
# Reached waypoint calculated: 957/1241
# Reached waypoint calculated: 958/1241
# Reached waypoint calculated: 959/1241
# Reached waypoint calculated: 960/1241
# Reached waypoint calculated: 961/1241
# Reached waypoint calculated: 962/1241
# Reached waypoint calculated: 963/1241
# Reached waypoint calculated: 964/1241
# Reached waypoint calculated: 965/1241
# Reached waypoint calculated: 966/1241
# Reached waypoint calculated: 967/1241
# Reached waypoint calculated: 968/1241
# Reached waypoint calculated: 969/1241
# Reached waypoint calculated: 970/1241
# Reached waypoint calculated: 971/1241
# Reached waypoint calculated: 972/1241
# Reached waypoint calculated: 973/1241
# Reached waypoint calculated: 974/1241
# Reached waypoint calculated: 975/1241
# Reached waypoint calculated: 976/1241
# Reached waypoint calculated: 977/1241
# Reached waypoint calculated: 978/1241
# Reached waypoint calculated: 979/1241
# Reached waypoint calculated: 980/1241
# Reached waypoint calculated: 981/1241
# Reached waypoint calculated: 982/1241
# Reached waypoint calculated: 983/1241
# Reached waypoint calculated: 984/1241
# Reached waypoint calculated: 985/1241
# Reached waypoint calculated: 986/1241
# Reached waypoint calculated: 987/1241
# Reached waypoint calculated: 988/1241
# Reached waypoint calculated: 989/1241
# Reached waypoint calculated: 990/1241
# Reached waypoint calculated: 991/1241
# Reached waypoint calculated: 992/1241
# Reached waypoint calculated: 993/1241
# Reached waypoint calculated: 994/1241
# Reached waypoint calculated: 995/1241
# Reached waypoint calculated: 996/1241
# Reached waypoint calculated: 997/1241
# Reached waypoint calculated: 998/1241
# Reached waypoint calculated: 999/1241
# Reached waypoint calculated: 1000/1241
# Reached waypoint calculated: 1001/1241
# Reached waypoint calculated: 1002/1241
# Reached waypoint calculated: 1003/1241
# Reached waypoint calculated: 1004/1241
# Reached waypoint calculated: 1005/1241
# Reached waypoint calculated: 1006/1241
# Reached waypoint calculated: 1007/1241
# Reached waypoint calculated: 1008/1241
# Reached waypoint calculated: 1009/1241
# Reached waypoint calculated: 1010/1241
# Reached waypoint calculated: 1011/1241
# Reached waypoint calculated: 1012/1241
# Reached waypoint calculated: 1013/1241
# Reached waypoint calculated: 1014/1241
# Reached waypoint calculated: 1015/1241
# Reached waypoint calculated: 1016/1241
# Reached waypoint calculated: 1017/1241
# Reached waypoint calculated: 1018/1241
# Reached waypoint calculated: 1019/1241
# Reached waypoint calculated: 1020/1241
# Reached waypoint calculated: 1021/1241
# Reached waypoint calculated: 1022/1241
# Reached waypoint calculated: 1023/1241
# Reached waypoint calculated: 1024/1241
# Reached waypoint calculated: 1025/1241
# Reached waypoint calculated: 1026/1241
# Reached waypoint calculated: 1027/1241
# Reached waypoint calculated: 1028/1241
# Reached waypoint calculated: 1029/1241
# Reached waypoint calculated: 1030/1241
# Reached waypoint calculated: 1031/1241
# Reached waypoint calculated: 1032/1241
# Reached waypoint calculated: 1033/1241
# Reached waypoint calculated: 1034/1241
# Reached waypoint calculated: 1035/1241
# Reached waypoint calculated: 1036/1241
# Reached waypoint calculated: 1037/1241
# Reached waypoint calculated: 1038/1241
# Reached waypoint calculated: 1039/1241
# Reached waypoint calculated: 1040/1241
# Reached waypoint calculated: 1041/1241
# Reached waypoint calculated: 1042/1241
# Reached waypoint calculated: 1043/1241
# Reached waypoint calculated: 1044/1241
# Reached waypoint calculated: 1045/1241
# Reached waypoint calculated: 1046/1241
# Reached waypoint calculated: 1047/1241
# Reached waypoint calculated: 1048/1241
# Reached waypoint calculated: 1049/1241
# Reached waypoint calculated: 1050/1241
# Reached waypoint calculated: 1051/1241
# Reached waypoint calculated: 1052/1241
# Reached waypoint calculated: 1053/1241
# Reached waypoint calculated: 1054/1241
# Reached waypoint calculated: 1055/1241
# Reached waypoint calculated: 1056/1241
# Reached waypoint calculated: 1057/1241
# Reached waypoint calculated: 1058/1241
# Reached waypoint calculated: 1059/1241
# Reached waypoint calculated: 1060/1241
# Reached waypoint calculated: 1061/1241
# Reached waypoint calculated: 1062/1241
# Reached waypoint calculated: 1063/1241
# Reached waypoint calculated: 1064/1241
# Reached waypoint calculated: 1065/1241
# Reached waypoint calculated: 1066/1241
# Reached waypoint calculated: 1067/1241
# Reached waypoint calculated: 1068/1241
# Reached waypoint calculated: 1069/1241
# Reached waypoint calculated: 1070/1241
# Reached waypoint calculated: 1071/1241
# Reached waypoint calculated: 1072/1241
# Reached waypoint calculated: 1073/1241
# Reached waypoint calculated: 1074/1241
# Reached waypoint calculated: 1075/1241
# Reached waypoint calculated: 1076/1241
# Reached waypoint calculated: 1077/1241
# Reached waypoint calculated: 1078/1241
# Reached waypoint calculated: 1079/1241
# Reached waypoint calculated: 1080/1241
# Reached waypoint calculated: 1081/1241
# Reached waypoint calculated: 1082/1241
# Reached waypoint calculated: 1083/1241
# Reached waypoint calculated: 1084/1241
# Reached waypoint calculated: 1085/1241
# Reached waypoint calculated: 1086/1241
# Reached waypoint calculated: 1087/1241
# Reached waypoint calculated: 1088/1241
# Reached waypoint calculated: 1089/1241
# Reached waypoint calculated: 1090/1241
# Reached waypoint calculated: 1091/1241
# Reached waypoint calculated: 1092/1241
# Reached waypoint calculated: 1093/1241
# Reached waypoint calculated: 1094/1241
# Reached waypoint calculated: 1095/1241
# Reached waypoint calculated: 1096/1241
# Reached waypoint calculated: 1097/1241
# Reached waypoint calculated: 1098/1241
# Reached waypoint calculated: 1099/1241
# Reached waypoint calculated: 1100/1241
# Reached waypoint calculated: 1101/1241
# Reached waypoint calculated: 1102/1241
# Reached waypoint calculated: 1103/1241
# Reached waypoint calculated: 1104/1241
# Reached waypoint calculated: 1105/1241
# Reached waypoint calculated: 1106/1241
# Reached waypoint calculated: 1107/1241
# Reached waypoint calculated: 1108/1241
# Reached waypoint calculated: 1109/1241
# Reached waypoint calculated: 1110/1241
# Reached waypoint calculated: 1111/1241
# Reached waypoint calculated: 1112/1241
# Reached waypoint calculated: 1113/1241
# Reached waypoint calculated: 1114/1241
# Reached waypoint calculated: 1115/1241
# Reached waypoint calculated: 1116/1241
# Reached waypoint calculated: 1117/1241
# Reached waypoint calculated: 1118/1241
# Reached waypoint calculated: 1119/1241
# Reached waypoint calculated: 1120/1241
# Reached waypoint calculated: 1121/1241
# Reached waypoint calculated: 1122/1241
# Reached waypoint calculated: 1123/1241
# Reached waypoint calculated: 1124/1241
# Reached waypoint calculated: 1125/1241
# Reached waypoint calculated: 1126/1241
# Reached waypoint calculated: 1127/1241
# Reached waypoint calculated: 1128/1241
# Reached waypoint calculated: 1129/1241
# Reached waypoint calculated: 1130/1241
# Reached waypoint calculated: 1131/1241
# Reached waypoint calculated: 1132/1241
# Reached waypoint calculated: 1133/1241
# Reached waypoint calculated: 1134/1241
# Reached waypoint calculated: 1135/1241
# Reached waypoint calculated: 1136/1241
# Reached waypoint calculated: 1137/1241
# Reached waypoint calculated: 1138/1241
# Reached waypoint calculated: 1139/1241
# Reached waypoint calculated: 1140/1241
# Reached waypoint calculated: 1141/1241
# Reached waypoint calculated: 1142/1241
# Reached waypoint calculated: 1143/1241
# Reached waypoint calculated: 1144/1241
# Reached waypoint calculated: 1145/1241
# Reached waypoint calculated: 1146/1241
# Reached waypoint calculated: 1147/1241
# Reached waypoint calculated: 1148/1241
# Reached waypoint calculated: 1149/1241
# Reached waypoint calculated: 1150/1241
# Reached waypoint calculated: 1151/1241
# Reached waypoint calculated: 1152/1241
# Reached waypoint calculated: 1153/1241
# Reached waypoint calculated: 1154/1241
# Reached waypoint calculated: 1155/1241
# Reached waypoint calculated: 1156/1241
# Reached waypoint calculated: 1157/1241
# Reached waypoint calculated: 1158/1241
# Reached waypoint calculated: 1159/1241
# Reached waypoint calculated: 1160/1241
# Reached waypoint calculated: 1161/1241
# Reached waypoint calculated: 1162/1241
# Reached waypoint calculated: 1163/1241
# Reached waypoint calculated: 1164/1241
# Reached waypoint calculated: 1165/1241
# Reached waypoint calculated: 1166/1241
# Reached waypoint calculated: 1167/1241
# Reached waypoint calculated: 1168/1241
# Reached waypoint calculated: 1169/1241
# Reached waypoint calculated: 1170/1241
# Reached waypoint calculated: 1171/1241
# Reached waypoint calculated: 1172/1241
# Reached waypoint calculated: 1173/1241
# Reached waypoint calculated: 1174/1241
# Reached waypoint calculated: 1175/1241
# Reached waypoint calculated: 1176/1241
# Reached waypoint calculated: 1177/1241
# Reached waypoint calculated: 1178/1241
# Reached waypoint calculated: 1179/1241
# Reached waypoint calculated: 1180/1241
# Reached waypoint calculated: 1181/1241
# Reached waypoint calculated: 1182/1241
# Reached waypoint calculated: 1183/1241
# Reached waypoint calculated: 1184/1241
# Reached waypoint calculated: 1185/1241
# Reached waypoint calculated: 1186/1241
# Reached waypoint calculated: 1187/1241
# Reached waypoint calculated: 1188/1241
# Reached waypoint calculated: 1189/1241
# Reached waypoint calculated: 1190/1241
# Reached waypoint calculated: 1191/1241
# Reached waypoint calculated: 1192/1241
# Reached waypoint calculated: 1193/1241
# Reached waypoint calculated: 1194/1241
# Reached waypoint calculated: 1195/1241
# Reached waypoint calculated: 1196/1241
# Reached waypoint calculated: 1197/1241
# Reached waypoint calculated: 1198/1241
# Reached waypoint calculated: 1199/1241
# Reached waypoint calculated: 1200/1241
# Reached waypoint calculated: 1201/1241
# Reached waypoint calculated: 1202/1241
# Reached waypoint calculated: 1203/1241
# Reached waypoint calculated: 1204/1241
# Reached waypoint calculated: 1205/1241
# Reached waypoint calculated: 1206/1241
# Reached waypoint calculated: 1207/1241
# Reached waypoint calculated: 1208/1241
# Reached waypoint calculated: 1209/1241
# Reached waypoint calculated: 1210/1241
# Reached waypoint calculated: 1211/1241
# Reached waypoint calculated: 1212/1241
# Reached waypoint calculated: 1213/1241
# Reached waypoint calculated: 1214/1241
# Reached waypoint calculated: 1215/1241
# Reached waypoint calculated: 1216/1241
# Reached waypoint calculated: 1217/1241
# Reached waypoint calculated: 1218/1241
# Reached waypoint calculated: 1219/1241
# Reached waypoint calculated: 1220/1241
# Reached waypoint calculated: 1221/1241
# Reached waypoint calculated: 1222/1241
# Reached waypoint calculated: 1223/1241
# Reached waypoint calculated: 1224/1241
# Reached waypoint calculated: 1225/1241
# Reached waypoint calculated: 1226/1241
# Reached waypoint calculated: 1227/1241
# Reached waypoint calculated: 1228/1241
# Reached waypoint calculated: 1229/1241
# Reached waypoint calculated: 1230/1241
# Reached waypoint calculated: 1231/1241
# Reached waypoint calculated: 1232/1241
# Reached waypoint calculated: 1233/1241
# Reached waypoint calculated: 1234/1241
# Reached waypoint calculated: 1235/1241
# Reached waypoint calculated: 1236/1241
# Reached waypoint calculated: 1237/1241
# Reached waypoint calculated: 1238/1241
# Reached waypoint calculated: 1239/1241
# Reached waypoint calculated: 1240/1241
# Reached waypoint calculated: 1241/1241
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
